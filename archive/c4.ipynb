# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time

import torch.nn as nn

# %%
def decode_to_code(encoded_circuit):
    weight_idx = 0
    for encoded_gate in encoded_circuit:
        wire2  = encoded_gate % 10
        wire1 = (encoded_gate // 10) % 10
        gate = (encoded_gate // 100) % 10

        if gate == 1:
            print(f"qml.RX(weights[{weight_idx}], wires={wire1})")
            weight_idx += 1
        elif gate == 2:
            print(f"qml.RZ(weights[{weight_idx}], wires={wire1})")
            weight_idx += 1
        elif gate == 3:
            print(f"qml.CNOT(wires=[{wire1}, {wire2}])")
        elif gate == 4:
            print(f"qml.Hadamard(wires={wire1})")
            
c =  [122, 303, 200, 312, 320, 203, 233, 403]

decode_to_code(c)
# Out:
# qml.RX(weights[0], wires=2)
# qml.CNOT(wires=[0, 3])
# qml.RZ(weights[1], wires=0)
# qml.CNOT(wires=[1, 2])
# qml.CNOT(wires=[2, 0])
# qml.RZ(weights[2], wires=0)
# qml.RZ(weights[3], wires=3)
# qml.Hadamard(wires=0)

# %%
n_train    = 500 
n_test     = 100
batch_size = 32
lr         = 0.01
gamma      = 0.96

num_qubits = 4
repetitions = 1
n_weights = 2 * repetitions

n_epochs = 20

resized_x = 14
resized_y = resized_x

# %%
dev = qml.device('lightning.qubit', wires=4)

@qml.qnode(dev,interface="torch", diff_method="adjoint")
def circuit(inputs, weights):
    # Encoding of 4 classical input values
    for j in range(num_qubits):
        qml.RY(np.pi * inputs[j], wires=j)

    for i in range (repetitions):
        qml.CNOT(wires=[0, 2])
        qml.CNOT(wires=[1, 3])
        qml.Hadamard(wires=2)
        qml.CNOT(wires=[2, 1])
        qml.RZ(weights[0], wires=0)
        qml.Hadamard(wires=3)
        qml.CNOT(wires=[3, 0])
        qml.Hadamard(wires=2)
        qml.RX(weights[1], wires=0)
        qml.Hadamard(wires=0)
    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(num_qubits)]

# %%
def load_dataset(n_train, n_test, batch_size):
    """
    Loads train & test sets from MNIST with user-specified sizes.

    Args:
        n_train (int): Desired number of samples in the training set.
        n_test (int): Desired number of samples in the testing set.
        batch_size (int): Batch size for the DataLoaders.

    Returns:
        tuple: (train_loader, test_loader) where each loader is a
               torch.utils.data.DataLoader.
    """
    # Define transformations for the dataset
    transform = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.5,), (0.5,)),
                                    transforms.Lambda(lambda img: F.interpolate(img.unsqueeze(0), size=(resized_x, resized_y), 
                                        mode='bilinear', align_corners=False).squeeze(0))])

    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    # Subset the datasets to the desired number of samples
    train_subset = torch.utils.data.Subset(train_dataset, range(n_train))
    test_subset = torch.utils.data.Subset(test_dataset, range(n_test))

    # Create DataLoaders for training and testing sets
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, pin_memory=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, pin_memory=True)

    print("Number of training samples:", len(train_subset))
    print("Number of test samples:", len(test_subset))

    return train_loader, test_loader

# %%
qlayer = qml.qnn.TorchLayer(circuit, {"weights": (n_weights,)})
fig, ax = qml.draw_mpl(circuit)([1.0,4,54,44], [1,2,3,4,5,123,2,23,1,1,1,1,1,1])
fig.show()
# Out:
# /var/folders/pc/01wnjzvx01n_gqvkhmw2_9nr0000gn/T/ipykernel_13425/3623739010.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def extract_image_patches(x):
    # Do TF 'SAME' Padding
    B, C, H, W = x.shape  
    #x = torch.arange(B*C*H*W).view(B, C, H, W)
    kernel_h, kernel_w = 2, 2
    stride = 2

    patches = x.unfold(2, kernel_h, stride).unfold(3, kernel_w, stride)
      
    patches = patches.contiguous().view(B, H // stride, W // stride, -1)

    return patches.reshape(-1, 4)

# %%
dim = resized_x // 2
class HQNN(nn.Module):
    def __init__(self):
        super(HQNN, self).__init__()

        # Quanvolutional layer (Maps 1 input channel to 4 output channels)
        self.quanv = qlayer

        # Fully connected layer to perform the final classification
        self.fc1 = nn.Linear(dim * dim * 4, 10)  # Assuming 10 output classes

    def forward(self, input):
        patches = extract_image_patches(input)  

        quanvoluted_patches = torch.stack([self.quanv(patch) for patch in patches])
        x = quanvoluted_patches.reshape(input.shape[0], dim, dim, 4)

        x = x.view(-1, dim * dim * 4)  # Flatten for the fully connected layer
        x = self.fc1(x)
        x = F.softmax(x, dim=1)  # Apply softmax
        return x

# %%
loss_fn = F.cross_entropy
train_loader, test_loader = load_dataset(n_train, n_test, batch_size)
# Out:
# Number of training samples: 500
# Number of test samples: 100

# %%
def append_data_to_markdown_table(file_path, circuit, lr, gamma, batch_size, val_loss, val_acc):
    """
    Appends variables to an existing Markdown table in a file, formatting floats to 3 decimal places.

    Args:
        file_path (str): The path to the Markdown file.
        lr (float): The learning rate value.
        gamma (float): The gamma value.
        batch_size (int): The batch size value.
        val_loss (float): The validation loss value.
        val_acc (float): The validation accuracy value.
    """

    with open(file_path, 'a') as f:  # Open the file in append mode
        row = f"| {circuit} | {lr} | {gamma:.2f} | {batch_size} | {val_loss:.3f} | {val_acc:.2f} |\n"
        f.write(row)  # Write the new row of data
        
lr_values    = [0.01, 0.01, 0.007, 0.007, 0.005, 0.005, 0.003, 0.003]
gamma_values = [0.98, 0.96, 0.96, 0.98, 0.98, 0.96, 0.98, 0.96] 

for lr, gamma in zip(lr_values, gamma_values):
    for _ in range(3):
        model = HQNN() 
        optimizer = torch.optim.Adam(model.parameters(), lr =lr)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma) 
        for epoch in range(n_epochs):
            # ---- Training Phase ----
            running_loss = 0.0 
            correct = 0  
            total = 0
            train_losses = []
            test_losses = []
            start_time = time.time()
            for i, (images, labels) in enumerate(train_loader):
                # --- 2. Forward Pass ---
                outputs = model(images)

                # --- 3. Loss Calculation ---
                loss = loss_fn(outputs, labels)
                train_losses.append(loss.item())
                # --- 4. Backpropagation and Optimization ---
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()  
                train_losses.append(loss.item())  # Store loss for each batch

                # Accuracy calculation for the epoch
                _, predicted = torch.max(outputs.data, 1) 
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            scheduler.step() 

            # Print statistics for the epoch
            epoch_loss = sum(train_losses) / len(train_losses)  
            epoch_acc = 100 * correct / total 

            current_lr = scheduler.get_last_lr()[0]  

            # Periodic Evaluation and Logging
            print(f'[i] Epoch {epoch + 1}\n\tLoss: {epoch_loss:.4f}\tAccuracy: {epoch_acc :.2f}%\n\tElapsed Time: {time.time() - start_time:.2f}s')
            print(f'\tLearning Rate: {current_lr}\n')

        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():  # Disable gradients for evaluation
            val_correct = 0
            val_total = 0

            for images, labels in test_loader:
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                test_losses.append(loss.item())

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = sum(test_losses) / len(test_losses)
        val_acc = 100 * val_correct / val_total 

        print(f'[i] Val Loss: {val_loss:.4f}\t Val Accuracy: {val_acc :.2f}%')
        append_data_to_markdown_table("results500.md", "circ4_SE", lr, gamma, batch_size, val_loss, val_acc)
# Out:
# [i] Epoch 1
# 	Loss: 2.2851	Accuracy: 26.60%
# 	Elapsed Time: 19.88s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.2145	Accuracy: 56.60%
# 	Elapsed Time: 20.39s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.1357	Accuracy: 60.80%
# 	Elapsed Time: 20.37s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.0622	Accuracy: 63.20%
# 	Elapsed Time: 20.04s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 2.0040	Accuracy: 65.60%
# 	Elapsed Time: 19.91s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.9574	Accuracy: 68.40%
# 	Elapsed Time: 20.54s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.9243	Accuracy: 71.00%
# 	Elapsed Time: 20.05s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.8953	Accuracy: 72.20%
# 	Elapsed Time: 20.02s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8712	Accuracy: 73.00%
# 	Elapsed Time: 20.05s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8529	Accuracy: 73.80%
# 	Elapsed Time: 20.07s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8335	Accuracy: 74.40%
# 	Elapsed Time: 20.19s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8196	Accuracy: 75.60%
# 	Elapsed Time: 20.21s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.8097	Accuracy: 76.40%
# 	Elapsed Time: 19.80s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.7968	Accuracy: 77.20%
# 	Elapsed Time: 19.86s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.7864	Accuracy: 77.60%
# 	Elapsed Time: 20.18s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.7736	Accuracy: 78.20%
# 	Elapsed Time: 19.98s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.7682	Accuracy: 78.00%
# 	Elapsed Time: 20.63s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.7602	Accuracy: 78.20%
# 	Elapsed Time: 20.24s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.7509	Accuracy: 78.40%
# 	Elapsed Time: 20.46s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.7486	Accuracy: 78.80%
# 	Elapsed Time: 21.08s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 2.0246	 Val Accuracy: 51.00%
# [i] Epoch 1
# 	Loss: 2.2870	Accuracy: 25.00%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.2200	Accuracy: 56.60%
# 	Elapsed Time: 21.33s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.1382	Accuracy: 61.00%
# 	Elapsed Time: 21.39s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.0656	Accuracy: 63.80%
# 	Elapsed Time: 21.65s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 2.0052	Accuracy: 65.60%
# 	Elapsed Time: 21.45s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.9560	Accuracy: 68.40%
# 	Elapsed Time: 21.73s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.9230	Accuracy: 69.40%
# 	Elapsed Time: 21.72s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.8945	Accuracy: 71.60%
# 	Elapsed Time: 21.52s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8683	Accuracy: 72.20%
# 	Elapsed Time: 21.85s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8521	Accuracy: 73.40%
# 	Elapsed Time: 22.01s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8369	Accuracy: 74.40%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8234	Accuracy: 75.60%
# 	Elapsed Time: 22.02s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.8071	Accuracy: 76.40%
# 	Elapsed Time: 22.09s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.7980	Accuracy: 76.80%
# 	Elapsed Time: 21.75s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.7875	Accuracy: 77.40%
# 	Elapsed Time: 21.58s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.7779	Accuracy: 77.60%
# 	Elapsed Time: 21.71s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.7703	Accuracy: 77.80%
# 	Elapsed Time: 21.73s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.7605	Accuracy: 78.40%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.7511	Accuracy: 78.60%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.7466	Accuracy: 79.80%
# 	Elapsed Time: 21.73s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 2.0350	 Val Accuracy: 53.00%
# [i] Epoch 1
# 	Loss: 2.2851	Accuracy: 29.80%
# 	Elapsed Time: 21.31s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.2180	Accuracy: 54.80%
# 	Elapsed Time: 21.41s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.1384	Accuracy: 59.20%
# 	Elapsed Time: 21.49s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.0617	Accuracy: 61.80%
# 	Elapsed Time: 21.33s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 2.0055	Accuracy: 64.40%
# 	Elapsed Time: 21.62s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.9613	Accuracy: 66.40%
# 	Elapsed Time: 21.57s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.9235	Accuracy: 67.80%
# 	Elapsed Time: 21.99s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.8924	Accuracy: 70.40%
# 	Elapsed Time: 21.92s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8726	Accuracy: 71.40%
# 	Elapsed Time: 23.49s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8540	Accuracy: 72.60%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8340	Accuracy: 74.00%
# 	Elapsed Time: 21.90s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8214	Accuracy: 74.80%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.8082	Accuracy: 75.60%
# 	Elapsed Time: 22.74s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.8004	Accuracy: 76.20%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.7886	Accuracy: 76.20%
# 	Elapsed Time: 22.71s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.7815	Accuracy: 77.00%
# 	Elapsed Time: 23.06s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.7699	Accuracy: 77.20%
# 	Elapsed Time: 23.32s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.7622	Accuracy: 77.60%
# 	Elapsed Time: 23.07s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.7595	Accuracy: 78.00%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.7506	Accuracy: 78.60%
# 	Elapsed Time: 22.52s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 2.0364	 Val Accuracy: 47.00%
# [i] Epoch 1
# 	Loss: 2.2873	Accuracy: 27.40%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.2190	Accuracy: 60.20%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.1424	Accuracy: 63.80%
# 	Elapsed Time: 26.52s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 2.0702	Accuracy: 64.60%
# 	Elapsed Time: 26.96s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 2.0120	Accuracy: 65.60%
# 	Elapsed Time: 27.13s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9686	Accuracy: 68.60%
# 	Elapsed Time: 24.70s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.9349	Accuracy: 70.00%
# 	Elapsed Time: 24.61s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.9095	Accuracy: 70.80%
# 	Elapsed Time: 23.69s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8902	Accuracy: 71.60%
# 	Elapsed Time: 22.81s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8692	Accuracy: 72.40%
# 	Elapsed Time: 22.54s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.8515	Accuracy: 73.40%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.8416	Accuracy: 73.80%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.8276	Accuracy: 74.80%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.8179	Accuracy: 75.80%
# 	Elapsed Time: 22.19s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.8094	Accuracy: 76.20%
# 	Elapsed Time: 22.13s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.7988	Accuracy: 77.00%
# 	Elapsed Time: 22.13s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.7914	Accuracy: 77.20%
# 	Elapsed Time: 21.85s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.7846	Accuracy: 77.40%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.7783	Accuracy: 77.40%
# 	Elapsed Time: 22.38s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.7744	Accuracy: 77.80%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 2.0399	 Val Accuracy: 46.00%
# [i] Epoch 1
# 	Loss: 2.2862	Accuracy: 26.20%
# 	Elapsed Time: 21.83s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.2167	Accuracy: 55.60%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.1380	Accuracy: 59.40%
# 	Elapsed Time: 21.69s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 2.0657	Accuracy: 62.80%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 2.0119	Accuracy: 66.40%
# 	Elapsed Time: 22.24s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9687	Accuracy: 68.40%
# 	Elapsed Time: 22.29s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.9315	Accuracy: 69.20%
# 	Elapsed Time: 22.14s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.9053	Accuracy: 70.80%
# 	Elapsed Time: 22.04s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8846	Accuracy: 73.00%
# 	Elapsed Time: 22.19s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8643	Accuracy: 73.80%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.8508	Accuracy: 74.60%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.8334	Accuracy: 75.00%
# 	Elapsed Time: 21.89s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.8241	Accuracy: 75.80%
# 	Elapsed Time: 22.27s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.8137	Accuracy: 75.80%
# 	Elapsed Time: 22.24s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.8054	Accuracy: 76.20%
# 	Elapsed Time: 21.89s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.8000	Accuracy: 77.00%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.7882	Accuracy: 77.60%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.7804	Accuracy: 77.80%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.7784	Accuracy: 78.40%
# 	Elapsed Time: 21.84s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.7704	Accuracy: 78.20%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 2.0446	 Val Accuracy: 48.00%
# [i] Epoch 1
# 	Loss: 2.2874	Accuracy: 26.20%
# 	Elapsed Time: 21.27s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.2190	Accuracy: 59.40%
# 	Elapsed Time: 21.53s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.1412	Accuracy: 63.20%
# 	Elapsed Time: 21.91s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 2.0712	Accuracy: 63.60%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 2.0094	Accuracy: 65.60%
# 	Elapsed Time: 22.26s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9663	Accuracy: 67.60%
# 	Elapsed Time: 22.17s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.9313	Accuracy: 69.80%
# 	Elapsed Time: 22.77s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.9059	Accuracy: 70.80%
# 	Elapsed Time: 21.93s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8844	Accuracy: 72.20%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8656	Accuracy: 73.20%
# 	Elapsed Time: 22.11s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.8478	Accuracy: 74.00%
# 	Elapsed Time: 22.19s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.8330	Accuracy: 75.40%
# 	Elapsed Time: 21.98s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.8214	Accuracy: 75.80%
# 	Elapsed Time: 22.28s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.8116	Accuracy: 76.20%
# 	Elapsed Time: 21.86s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.8027	Accuracy: 76.20%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.7962	Accuracy: 76.60%
# 	Elapsed Time: 22.15s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.7900	Accuracy: 77.20%
# 	Elapsed Time: 22.23s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.7826	Accuracy: 77.20%
# 	Elapsed Time: 22.24s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.7777	Accuracy: 77.60%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.7735	Accuracy: 77.60%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 2.0328	 Val Accuracy: 49.00%
# [i] Epoch 1
# 	Loss: 2.2921	Accuracy: 22.60%
# 	Elapsed Time: 21.31s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.2490	Accuracy: 55.20%
# 	Elapsed Time: 21.93s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 2.1973	Accuracy: 62.00%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 2.1432	Accuracy: 64.20%
# 	Elapsed Time: 22.71s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 2.0886	Accuracy: 66.80%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 2.0462	Accuracy: 66.80%
# 	Elapsed Time: 22.28s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 2.0106	Accuracy: 66.80%
# 	Elapsed Time: 22.38s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.9813	Accuracy: 67.80%
# 	Elapsed Time: 22.22s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.9549	Accuracy: 69.00%
# 	Elapsed Time: 22.15s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.9376	Accuracy: 70.60%
# 	Elapsed Time: 22.18s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.9172	Accuracy: 71.40%
# 	Elapsed Time: 22.23s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.9032	Accuracy: 71.00%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.8924	Accuracy: 72.40%
# 	Elapsed Time: 22.52s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.8789	Accuracy: 72.80%
# 	Elapsed Time: 22.10s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.8662	Accuracy: 73.60%
# 	Elapsed Time: 22.29s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.8574	Accuracy: 74.00%
# 	Elapsed Time: 22.22s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.8471	Accuracy: 74.40%
# 	Elapsed Time: 22.19s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.8423	Accuracy: 75.20%
# 	Elapsed Time: 22.28s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.8400	Accuracy: 75.40%
# 	Elapsed Time: 22.16s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.8269	Accuracy: 75.80%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 2.0608	 Val Accuracy: 47.00%
# [i] Epoch 1
# 	Loss: 2.2948	Accuracy: 20.60%
# 	Elapsed Time: 21.66s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.2523	Accuracy: 54.20%
# 	Elapsed Time: 22.08s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 2.2010	Accuracy: 62.80%
# 	Elapsed Time: 22.04s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 2.1475	Accuracy: 63.60%
# 	Elapsed Time: 23.00s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 2.0958	Accuracy: 64.20%
# 	Elapsed Time: 23.05s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 2.0505	Accuracy: 66.00%
# 	Elapsed Time: 22.18s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 2.0166	Accuracy: 67.80%
# 	Elapsed Time: 22.21s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.9837	Accuracy: 69.80%
# 	Elapsed Time: 22.15s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.9589	Accuracy: 70.20%
# 	Elapsed Time: 22.22s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.9389	Accuracy: 70.40%
# 	Elapsed Time: 22.29s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.9198	Accuracy: 71.00%
# 	Elapsed Time: 22.24s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.9033	Accuracy: 72.60%
# 	Elapsed Time: 22.05s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.8903	Accuracy: 73.00%
# 	Elapsed Time: 22.25s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.8777	Accuracy: 73.80%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.8703	Accuracy: 74.20%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.8597	Accuracy: 74.80%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.8497	Accuracy: 75.60%
# 	Elapsed Time: 21.81s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.8433	Accuracy: 75.60%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.8358	Accuracy: 76.00%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.8284	Accuracy: 76.00%
# 	Elapsed Time: 21.75s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 2.0648	 Val Accuracy: 44.00%
# [i] Epoch 1
# 	Loss: 2.2925	Accuracy: 22.40%
# 	Elapsed Time: 21.59s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.2489	Accuracy: 57.80%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 2.1979	Accuracy: 62.80%
# 	Elapsed Time: 21.72s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 2.1427	Accuracy: 62.60%
# 	Elapsed Time: 21.57s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 2.0888	Accuracy: 64.20%
# 	Elapsed Time: 21.64s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 2.0453	Accuracy: 66.00%
# 	Elapsed Time: 21.84s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 2.0066	Accuracy: 67.60%
# 	Elapsed Time: 22.01s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.9823	Accuracy: 68.00%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.9575	Accuracy: 68.40%
# 	Elapsed Time: 22.07s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.9368	Accuracy: 69.40%
# 	Elapsed Time: 21.90s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.9198	Accuracy: 71.20%
# 	Elapsed Time: 21.70s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.9034	Accuracy: 72.20%
# 	Elapsed Time: 21.83s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.8894	Accuracy: 72.40%
# 	Elapsed Time: 21.98s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.8784	Accuracy: 73.20%
# 	Elapsed Time: 22.16s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.8694	Accuracy: 73.40%
# 	Elapsed Time: 22.30s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.8627	Accuracy: 74.00%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.8566	Accuracy: 74.00%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.8434	Accuracy: 74.40%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.8376	Accuracy: 74.80%
# 	Elapsed Time: 22.76s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.8324	Accuracy: 75.20%
# 	Elapsed Time: 25.97s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 2.0611	 Val Accuracy: 43.00%
# [i] Epoch 1
# 	Loss: 2.2911	Accuracy: 28.80%
# 	Elapsed Time: 26.29s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.2474	Accuracy: 58.40%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.1942	Accuracy: 63.40%
# 	Elapsed Time: 22.26s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 2.1384	Accuracy: 64.00%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 2.0842	Accuracy: 64.80%
# 	Elapsed Time: 22.13s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 2.0357	Accuracy: 66.00%
# 	Elapsed Time: 22.17s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.9995	Accuracy: 67.00%
# 	Elapsed Time: 22.20s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.9661	Accuracy: 68.80%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.9421	Accuracy: 70.00%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.9156	Accuracy: 70.20%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.8972	Accuracy: 71.40%
# 	Elapsed Time: 22.41s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.8845	Accuracy: 72.20%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.8682	Accuracy: 73.00%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.8554	Accuracy: 74.20%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.8420	Accuracy: 74.40%
# 	Elapsed Time: 22.12s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.8315	Accuracy: 75.20%
# 	Elapsed Time: 22.10s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.8233	Accuracy: 75.60%
# 	Elapsed Time: 21.99s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.8197	Accuracy: 75.80%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.8083	Accuracy: 76.00%
# 	Elapsed Time: 22.45s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.8013	Accuracy: 76.80%
# 	Elapsed Time: 22.13s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 2.0494	 Val Accuracy: 48.00%
# [i] Epoch 1
# 	Loss: 2.2937	Accuracy: 19.60%
# 	Elapsed Time: 21.62s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.2498	Accuracy: 54.80%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.1969	Accuracy: 62.00%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 2.1402	Accuracy: 63.80%
# 	Elapsed Time: 21.78s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 2.0858	Accuracy: 64.00%
# 	Elapsed Time: 21.61s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 2.0367	Accuracy: 65.40%
# 	Elapsed Time: 22.22s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.9979	Accuracy: 65.80%
# 	Elapsed Time: 21.95s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.9667	Accuracy: 66.80%
# 	Elapsed Time: 22.11s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.9424	Accuracy: 68.40%
# 	Elapsed Time: 21.95s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.9191	Accuracy: 69.60%
# 	Elapsed Time: 22.21s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.8982	Accuracy: 71.00%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.8842	Accuracy: 71.80%
# 	Elapsed Time: 22.35s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.8673	Accuracy: 73.20%
# 	Elapsed Time: 22.25s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.8566	Accuracy: 73.80%
# 	Elapsed Time: 22.61s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.8452	Accuracy: 74.60%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.8387	Accuracy: 75.40%
# 	Elapsed Time: 22.69s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.8255	Accuracy: 75.60%
# 	Elapsed Time: 22.11s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.8188	Accuracy: 76.20%
# 	Elapsed Time: 22.30s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.8119	Accuracy: 76.40%
# 	Elapsed Time: 22.25s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.8061	Accuracy: 76.60%
# 	Elapsed Time: 22.26s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 2.0497	 Val Accuracy: 47.00%
# [i] Epoch 1
# 	Loss: 2.2925	Accuracy: 26.20%
# 	Elapsed Time: 23.03s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.2494	Accuracy: 57.80%
# 	Elapsed Time: 22.72s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.1965	Accuracy: 64.20%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 2.1366	Accuracy: 63.20%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 2.0832	Accuracy: 64.40%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 2.0351	Accuracy: 66.20%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.9994	Accuracy: 66.40%
# 	Elapsed Time: 22.76s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.9683	Accuracy: 68.20%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.9443	Accuracy: 69.20%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.9207	Accuracy: 70.00%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.8998	Accuracy: 72.20%
# 	Elapsed Time: 22.40s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.8846	Accuracy: 72.80%
# 	Elapsed Time: 22.20s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.8692	Accuracy: 74.20%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.8586	Accuracy: 74.40%
# 	Elapsed Time: 21.82s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.8471	Accuracy: 75.00%
# 	Elapsed Time: 21.77s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.8347	Accuracy: 75.80%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.8244	Accuracy: 76.80%
# 	Elapsed Time: 21.91s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.8197	Accuracy: 77.00%
# 	Elapsed Time: 21.67s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.8098	Accuracy: 77.60%
# 	Elapsed Time: 21.66s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.8026	Accuracy: 77.60%
# 	Elapsed Time: 21.58s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 2.0512	 Val Accuracy: 49.00%
# [i] Epoch 1
# 	Loss: 2.2950	Accuracy: 18.40%
# 	Elapsed Time: 21.24s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.2656	Accuracy: 49.40%
# 	Elapsed Time: 21.45s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.2311	Accuracy: 59.80%
# 	Elapsed Time: 21.89s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 2.1932	Accuracy: 61.40%
# 	Elapsed Time: 21.37s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 2.1493	Accuracy: 62.00%
# 	Elapsed Time: 21.54s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 2.1109	Accuracy: 62.40%
# 	Elapsed Time: 21.98s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 2.0744	Accuracy: 62.60%
# 	Elapsed Time: 21.33s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 2.0439	Accuracy: 64.00%
# 	Elapsed Time: 21.41s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 2.0176	Accuracy: 65.40%
# 	Elapsed Time: 21.34s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.9917	Accuracy: 66.00%
# 	Elapsed Time: 21.46s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.9745	Accuracy: 66.80%
# 	Elapsed Time: 21.58s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.9558	Accuracy: 67.80%
# 	Elapsed Time: 22.05s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.9397	Accuracy: 68.60%
# 	Elapsed Time: 22.26s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.9257	Accuracy: 69.80%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.9148	Accuracy: 70.80%
# 	Elapsed Time: 22.08s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.9002	Accuracy: 71.00%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.8878	Accuracy: 72.00%
# 	Elapsed Time: 22.10s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.8813	Accuracy: 72.80%
# 	Elapsed Time: 21.85s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.8716	Accuracy: 73.00%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.8606	Accuracy: 73.20%
# 	Elapsed Time: 22.28s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 2.0791	 Val Accuracy: 45.00%
# [i] Epoch 1
# 	Loss: 2.2943	Accuracy: 20.20%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.2649	Accuracy: 50.80%
# 	Elapsed Time: 22.25s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.2310	Accuracy: 58.80%
# 	Elapsed Time: 21.88s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 2.1919	Accuracy: 62.60%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 2.1483	Accuracy: 63.60%
# 	Elapsed Time: 22.26s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 2.1119	Accuracy: 64.60%
# 	Elapsed Time: 22.08s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 2.0755	Accuracy: 65.20%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 2.0445	Accuracy: 65.80%
# 	Elapsed Time: 21.82s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 2.0155	Accuracy: 66.60%
# 	Elapsed Time: 21.90s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.9925	Accuracy: 68.40%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.9703	Accuracy: 69.80%
# 	Elapsed Time: 21.84s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.9493	Accuracy: 70.40%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.9355	Accuracy: 71.40%
# 	Elapsed Time: 22.39s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.9210	Accuracy: 71.60%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.9091	Accuracy: 72.00%
# 	Elapsed Time: 23.47s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.8973	Accuracy: 72.20%
# 	Elapsed Time: 22.94s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.8874	Accuracy: 72.60%
# 	Elapsed Time: 22.43s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.8792	Accuracy: 73.00%
# 	Elapsed Time: 22.54s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.8685	Accuracy: 73.40%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.8631	Accuracy: 74.00%
# 	Elapsed Time: 22.86s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 2.0693	 Val Accuracy: 45.00%
# [i] Epoch 1
# 	Loss: 2.2960	Accuracy: 20.80%
# 	Elapsed Time: 22.14s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.2667	Accuracy: 50.00%
# 	Elapsed Time: 22.25s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.2340	Accuracy: 59.60%
# 	Elapsed Time: 22.27s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 2.1929	Accuracy: 61.40%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 2.1516	Accuracy: 62.80%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 2.1107	Accuracy: 64.20%
# 	Elapsed Time: 22.31s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 2.0763	Accuracy: 64.80%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 2.0396	Accuracy: 65.40%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 2.0144	Accuracy: 67.40%
# 	Elapsed Time: 22.83s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.9916	Accuracy: 68.20%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.9695	Accuracy: 68.80%
# 	Elapsed Time: 23.65s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.9505	Accuracy: 69.00%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.9370	Accuracy: 70.40%
# 	Elapsed Time: 23.47s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.9210	Accuracy: 70.60%
# 	Elapsed Time: 24.05s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.9098	Accuracy: 71.40%
# 	Elapsed Time: 23.97s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.8962	Accuracy: 71.80%
# 	Elapsed Time: 23.38s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.8850	Accuracy: 72.60%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.8743	Accuracy: 73.20%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.8653	Accuracy: 73.80%
# 	Elapsed Time: 22.02s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.8617	Accuracy: 74.00%
# 	Elapsed Time: 22.35s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 2.0746	 Val Accuracy: 48.00%
# [i] Epoch 1
# 	Loss: 2.2958	Accuracy: 17.80%
# 	Elapsed Time: 21.93s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.2670	Accuracy: 50.40%
# 	Elapsed Time: 22.04s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.2342	Accuracy: 60.20%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 2.1955	Accuracy: 62.60%
# 	Elapsed Time: 21.64s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 2.1566	Accuracy: 63.40%
# 	Elapsed Time: 21.53s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 2.1187	Accuracy: 63.60%
# 	Elapsed Time: 21.84s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 2.0894	Accuracy: 63.80%
# 	Elapsed Time: 21.52s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 2.0596	Accuracy: 65.40%
# 	Elapsed Time: 21.16s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 2.0337	Accuracy: 66.20%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 2.0129	Accuracy: 67.20%
# 	Elapsed Time: 20.75s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.9913	Accuracy: 67.40%
# 	Elapsed Time: 20.91s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.9756	Accuracy: 67.60%
# 	Elapsed Time: 21.37s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.9602	Accuracy: 68.40%
# 	Elapsed Time: 20.91s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.9472	Accuracy: 69.40%
# 	Elapsed Time: 21.23s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.9367	Accuracy: 69.60%
# 	Elapsed Time: 21.07s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.9260	Accuracy: 69.80%
# 	Elapsed Time: 21.08s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.9162	Accuracy: 70.20%
# 	Elapsed Time: 21.06s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.9085	Accuracy: 70.40%
# 	Elapsed Time: 21.03s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.9011	Accuracy: 70.40%
# 	Elapsed Time: 20.85s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.8934	Accuracy: 70.80%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 2.0817	 Val Accuracy: 46.00%
# [i] Epoch 1
# 	Loss: 2.2966	Accuracy: 18.60%
# 	Elapsed Time: 20.46s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.2674	Accuracy: 49.80%
# 	Elapsed Time: 20.68s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.2349	Accuracy: 59.00%
# 	Elapsed Time: 20.79s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 2.1961	Accuracy: 60.80%
# 	Elapsed Time: 20.62s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 2.1564	Accuracy: 61.80%
# 	Elapsed Time: 20.67s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 2.1182	Accuracy: 63.40%
# 	Elapsed Time: 20.99s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 2.0873	Accuracy: 64.60%
# 	Elapsed Time: 20.96s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 2.0584	Accuracy: 65.40%
# 	Elapsed Time: 21.04s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 2.0313	Accuracy: 66.40%
# 	Elapsed Time: 20.96s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 2.0117	Accuracy: 67.80%
# 	Elapsed Time: 21.06s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.9920	Accuracy: 68.80%
# 	Elapsed Time: 21.08s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.9758	Accuracy: 69.80%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.9625	Accuracy: 70.20%
# 	Elapsed Time: 21.06s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.9475	Accuracy: 71.00%
# 	Elapsed Time: 20.87s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.9385	Accuracy: 71.80%
# 	Elapsed Time: 20.99s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.9219	Accuracy: 72.20%
# 	Elapsed Time: 20.71s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.9146	Accuracy: 72.40%
# 	Elapsed Time: 20.79s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.9073	Accuracy: 72.80%
# 	Elapsed Time: 20.58s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.8987	Accuracy: 73.00%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.8909	Accuracy: 73.40%
# 	Elapsed Time: 20.77s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 2.0827	 Val Accuracy: 47.00%
# [i] Epoch 1
# 	Loss: 2.2948	Accuracy: 22.00%
# 	Elapsed Time: 20.15s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.2664	Accuracy: 49.00%
# 	Elapsed Time: 20.68s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.2342	Accuracy: 59.40%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 2.1966	Accuracy: 62.40%
# 	Elapsed Time: 20.66s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 2.1599	Accuracy: 63.60%
# 	Elapsed Time: 20.66s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 2.1207	Accuracy: 63.60%
# 	Elapsed Time: 20.57s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 2.0886	Accuracy: 64.60%
# 	Elapsed Time: 20.87s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 2.0600	Accuracy: 64.80%
# 	Elapsed Time: 20.82s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 2.0357	Accuracy: 66.00%
# 	Elapsed Time: 20.98s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 2.0132	Accuracy: 66.80%
# 	Elapsed Time: 21.21s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.9936	Accuracy: 67.20%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.9803	Accuracy: 67.40%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.9645	Accuracy: 68.00%
# 	Elapsed Time: 21.01s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.9503	Accuracy: 69.00%
# 	Elapsed Time: 20.90s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.9397	Accuracy: 69.80%
# 	Elapsed Time: 20.57s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.9272	Accuracy: 70.40%
# 	Elapsed Time: 21.21s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.9176	Accuracy: 71.00%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.9120	Accuracy: 71.00%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.9048	Accuracy: 71.20%
# 	Elapsed Time: 20.84s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.8963	Accuracy: 71.40%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 2.0865	 Val Accuracy: 45.00%
# [i] Epoch 1
# 	Loss: 2.2989	Accuracy: 15.00%
# 	Elapsed Time: 20.29s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2832	Accuracy: 39.40%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.2654	Accuracy: 50.00%
# 	Elapsed Time: 20.76s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.2464	Accuracy: 54.80%
# 	Elapsed Time: 20.76s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.2240	Accuracy: 58.00%
# 	Elapsed Time: 20.58s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 2.2014	Accuracy: 59.20%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 2.1757	Accuracy: 60.20%
# 	Elapsed Time: 20.64s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 2.1525	Accuracy: 62.00%
# 	Elapsed Time: 21.04s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 2.1296	Accuracy: 62.40%
# 	Elapsed Time: 20.84s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 2.1075	Accuracy: 63.20%
# 	Elapsed Time: 20.66s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 2.0877	Accuracy: 64.40%
# 	Elapsed Time: 20.59s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 2.0695	Accuracy: 64.60%
# 	Elapsed Time: 21.15s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 2.0518	Accuracy: 65.60%
# 	Elapsed Time: 20.99s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 2.0350	Accuracy: 66.40%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 2.0222	Accuracy: 67.00%
# 	Elapsed Time: 20.84s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 2.0095	Accuracy: 67.80%
# 	Elapsed Time: 20.90s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.9958	Accuracy: 68.60%
# 	Elapsed Time: 20.75s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.9854	Accuracy: 68.80%
# 	Elapsed Time: 20.56s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.9755	Accuracy: 69.20%
# 	Elapsed Time: 20.62s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.9654	Accuracy: 69.60%
# 	Elapsed Time: 20.80s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 2.1203	 Val Accuracy: 46.00%
# [i] Epoch 1
# 	Loss: 2.2989	Accuracy: 17.00%
# 	Elapsed Time: 20.47s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2832	Accuracy: 41.80%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.2661	Accuracy: 53.60%
# 	Elapsed Time: 20.83s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.2461	Accuracy: 58.00%
# 	Elapsed Time: 20.87s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.2229	Accuracy: 59.80%
# 	Elapsed Time: 20.84s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 2.2011	Accuracy: 61.00%
# 	Elapsed Time: 21.11s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 2.1743	Accuracy: 62.60%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 2.1527	Accuracy: 63.20%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 2.1276	Accuracy: 62.80%
# 	Elapsed Time: 20.76s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 2.1040	Accuracy: 63.20%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 2.0861	Accuracy: 63.40%
# 	Elapsed Time: 20.51s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 2.0648	Accuracy: 63.80%
# 	Elapsed Time: 20.62s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 2.0489	Accuracy: 64.60%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 2.0322	Accuracy: 65.40%
# 	Elapsed Time: 20.45s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 2.0201	Accuracy: 65.60%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 2.0065	Accuracy: 66.80%
# 	Elapsed Time: 20.87s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.9930	Accuracy: 67.40%
# 	Elapsed Time: 22.95s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.9855	Accuracy: 68.20%
# 	Elapsed Time: 20.94s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.9723	Accuracy: 68.20%
# 	Elapsed Time: 21.01s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.9619	Accuracy: 68.40%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 2.1163	 Val Accuracy: 44.00%
# [i] Epoch 1
# 	Loss: 2.2980	Accuracy: 15.60%
# 	Elapsed Time: 20.69s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2811	Accuracy: 38.00%
# 	Elapsed Time: 20.82s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.2638	Accuracy: 51.60%
# 	Elapsed Time: 20.67s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.2443	Accuracy: 56.00%
# 	Elapsed Time: 20.56s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.2222	Accuracy: 59.80%
# 	Elapsed Time: 20.61s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 2.1986	Accuracy: 62.40%
# 	Elapsed Time: 20.89s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 2.1736	Accuracy: 63.20%
# 	Elapsed Time: 20.97s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 2.1489	Accuracy: 64.20%
# 	Elapsed Time: 20.96s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 2.1275	Accuracy: 64.60%
# 	Elapsed Time: 20.69s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 2.1038	Accuracy: 64.80%
# 	Elapsed Time: 21.00s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 2.0856	Accuracy: 65.80%
# 	Elapsed Time: 20.85s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 2.0654	Accuracy: 65.60%
# 	Elapsed Time: 20.80s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 2.0472	Accuracy: 66.00%
# 	Elapsed Time: 20.77s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 2.0339	Accuracy: 67.00%
# 	Elapsed Time: 20.43s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 2.0198	Accuracy: 68.00%
# 	Elapsed Time: 20.47s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 2.0050	Accuracy: 69.00%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.9921	Accuracy: 69.20%
# 	Elapsed Time: 20.63s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.9839	Accuracy: 69.80%
# 	Elapsed Time: 20.74s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.9709	Accuracy: 70.00%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.9642	Accuracy: 70.00%
# 	Elapsed Time: 20.84s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 2.1187	 Val Accuracy: 47.00%
# [i] Epoch 1
# 	Loss: 2.2956	Accuracy: 22.00%
# 	Elapsed Time: 20.37s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2791	Accuracy: 45.80%
# 	Elapsed Time: 20.69s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.2621	Accuracy: 55.00%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.2438	Accuracy: 60.20%
# 	Elapsed Time: 20.60s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.2228	Accuracy: 61.80%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 2.2004	Accuracy: 62.60%
# 	Elapsed Time: 21.02s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 2.1805	Accuracy: 62.80%
# 	Elapsed Time: 20.91s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 2.1592	Accuracy: 63.20%
# 	Elapsed Time: 20.59s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 2.1387	Accuracy: 63.60%
# 	Elapsed Time: 20.60s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 2.1208	Accuracy: 63.80%
# 	Elapsed Time: 20.87s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 2.1052	Accuracy: 65.00%
# 	Elapsed Time: 20.99s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 2.0893	Accuracy: 65.60%
# 	Elapsed Time: 20.72s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 2.0718	Accuracy: 65.80%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 2.0604	Accuracy: 66.40%
# 	Elapsed Time: 20.76s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 2.0471	Accuracy: 66.80%
# 	Elapsed Time: 20.89s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 2.0381	Accuracy: 67.00%
# 	Elapsed Time: 21.14s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 2.0257	Accuracy: 67.00%
# 	Elapsed Time: 20.94s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 2.0170	Accuracy: 67.20%
# 	Elapsed Time: 21.00s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 2.0119	Accuracy: 67.20%
# 	Elapsed Time: 20.91s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 2.0010	Accuracy: 67.60%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 2.1356	 Val Accuracy: 43.00%
# [i] Epoch 1
# 	Loss: 2.2999	Accuracy: 12.20%
# 	Elapsed Time: 20.33s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2842	Accuracy: 35.60%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.2678	Accuracy: 48.60%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.2480	Accuracy: 52.40%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.2292	Accuracy: 57.00%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 2.2076	Accuracy: 59.80%
# 	Elapsed Time: 21.10s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 2.1856	Accuracy: 60.40%
# 	Elapsed Time: 21.01s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 2.1665	Accuracy: 61.20%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 2.1432	Accuracy: 62.60%
# 	Elapsed Time: 21.01s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 2.1237	Accuracy: 63.00%
# 	Elapsed Time: 20.83s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 2.1092	Accuracy: 63.20%
# 	Elapsed Time: 20.60s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 2.0928	Accuracy: 63.60%
# 	Elapsed Time: 20.93s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 2.0756	Accuracy: 64.00%
# 	Elapsed Time: 20.63s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 2.0641	Accuracy: 65.00%
# 	Elapsed Time: 20.63s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 2.0519	Accuracy: 66.00%
# 	Elapsed Time: 20.57s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 2.0407	Accuracy: 65.80%
# 	Elapsed Time: 20.72s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 2.0319	Accuracy: 66.60%
# 	Elapsed Time: 20.95s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 2.0217	Accuracy: 67.20%
# 	Elapsed Time: 20.75s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 2.0110	Accuracy: 67.40%
# 	Elapsed Time: 21.21s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 2.0064	Accuracy: 67.80%
# 	Elapsed Time: 20.64s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 2.1307	 Val Accuracy: 48.00%
# [i] Epoch 1
# 	Loss: 2.3006	Accuracy: 12.20%
# 	Elapsed Time: 20.49s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2850	Accuracy: 37.60%
# 	Elapsed Time: 20.61s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.2689	Accuracy: 53.80%
# 	Elapsed Time: 20.89s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.2507	Accuracy: 59.00%
# 	Elapsed Time: 20.53s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.2307	Accuracy: 63.00%
# 	Elapsed Time: 20.79s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 2.2080	Accuracy: 62.80%
# 	Elapsed Time: 20.91s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 2.1874	Accuracy: 63.80%
# 	Elapsed Time: 20.75s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 2.1667	Accuracy: 64.60%
# 	Elapsed Time: 20.76s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 2.1449	Accuracy: 65.40%
# 	Elapsed Time: 21.08s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 2.1251	Accuracy: 65.80%
# 	Elapsed Time: 20.80s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 2.1096	Accuracy: 65.80%
# 	Elapsed Time: 20.77s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 2.0934	Accuracy: 66.40%
# 	Elapsed Time: 20.68s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 2.0765	Accuracy: 66.20%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 2.0638	Accuracy: 67.00%
# 	Elapsed Time: 20.67s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 2.0526	Accuracy: 67.20%
# 	Elapsed Time: 20.76s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 2.0370	Accuracy: 67.40%
# 	Elapsed Time: 21.08s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 2.0309	Accuracy: 67.60%
# 	Elapsed Time: 20.98s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 2.0211	Accuracy: 67.80%
# 	Elapsed Time: 20.98s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 2.0082	Accuracy: 68.00%
# 	Elapsed Time: 21.08s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 2.0036	Accuracy: 68.20%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 2.1350	 Val Accuracy: 41.00%
