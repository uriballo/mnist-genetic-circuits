# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time

import torch.nn as nn

# %%
def decode_to_code(encoded_circuit):
    weight_idx = 0
    for encoded_gate in encoded_circuit:
        wire2  = encoded_gate % 10
        wire1 = (encoded_gate // 10) % 10
        gate = (encoded_gate // 100) % 10

        if gate == 1:
            print(f"qml.RX(weights[{weight_idx}], wires={wire1})")
            weight_idx += 1
        elif gate == 2:
            print(f"qml.RZ(weights[{weight_idx}], wires={wire1})")
            weight_idx += 1
        elif gate == 3:
            print(f"qml.CNOT(wires=[{wire1}, {wire2}])")
        elif gate == 4:
            print(f"qml.Hadamard(wires={wire1})")
            
c = [223, 403, 420, 210, 233, 122, 230]
decode_to_code(c)
# Out:
# qml.RZ(weights[0], wires=2)
# qml.Hadamard(wires=0)
# qml.Hadamard(wires=2)
# qml.RZ(weights[1], wires=1)
# qml.RZ(weights[2], wires=3)
# qml.RX(weights[3], wires=2)
# qml.RZ(weights[4], wires=3)

# %%
n_train    = 500 
n_test     = 100
batch_size = 32
lr         = 0.01
gamma      = 0.96

num_qubits = 4
repetitions = 1
n_weights = 3 * repetitions


n_epochs = 20

resized_x = 14
resized_y = resized_x

# %%
dev = qml.device('lightning.qubit', wires=4)

@qml.qnode(dev,interface="torch", diff_method="adjoint")
def circuit(inputs, weights):
    # Encoding of 4 classical input values
    for j in range(num_qubits):
        qml.RY(np.pi * inputs[j], wires=j)

    for i in range (repetitions):
        qml.RZ(weights[0 + i], wires=3)
        qml.RX(weights[1 + i], wires=1)
        qml.CNOT(wires=[1, 3])
        qml.RZ(weights[2 + i], wires=1)
        qml.Hadamard(wires=3)
        qml.CNOT(wires=[0, 2])

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(num_qubits)]

# %%
def load_dataset(n_train, n_test, batch_size):
    """
    Loads train & test sets from MNIST with user-specified sizes.

    Args:
        n_train (int): Desired number of samples in the training set.
        n_test (int): Desired number of samples in the testing set.
        batch_size (int): Batch size for the DataLoaders.

    Returns:
        tuple: (train_loader, test_loader) where each loader is a
               torch.utils.data.DataLoader.
    """
    # Define transformations for the dataset
    transform = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.5,), (0.5,)),
                                    transforms.Lambda(lambda img: F.interpolate(img.unsqueeze(0), size=(resized_x, resized_y), 
                                        mode='bilinear', align_corners=False).squeeze(0))])

    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    # Subset the datasets to the desired number of samples
    train_subset = torch.utils.data.Subset(train_dataset, range(n_train))
    test_subset = torch.utils.data.Subset(test_dataset, range(n_test))

    # Create DataLoaders for training and testing sets
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, pin_memory=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, pin_memory=True)

    print("Number of training samples:", len(train_subset))
    print("Number of test samples:", len(test_subset))

    return train_loader, test_loader

# %%
qlayer = qml.qnn.TorchLayer(circuit, {"weights": (n_weights,)})
fig, ax = qml.draw_mpl(circuit)([1.0,4,54,44], [1,2,3,4,5,123,2,23,1,1,1,1,1,1])
fig.show()
# Out:
# /var/folders/pc/01wnjzvx01n_gqvkhmw2_9nr0000gn/T/ipykernel_48299/3623739010.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def extract_image_patches(x):
    # Do TF 'SAME' Padding
    B, C, H, W = x.shape  
    #x = torch.arange(B*C*H*W).view(B, C, H, W)
    kernel_h, kernel_w = 2, 2
    stride = 2

    patches = x.unfold(2, kernel_h, stride).unfold(3, kernel_w, stride)
      
    patches = patches.contiguous().view(B, H // stride, W // stride, -1)

    return patches.reshape(-1, 4)

# %%
dim = resized_x // 2
class HQNN(nn.Module):
    def __init__(self):
        super(HQNN, self).__init__()

        # Quanvolutional layer (Maps 1 input channel to 4 output channels)
        self.quanv = qlayer

        # Fully connected layer to perform the final classification
        self.fc1 = nn.Linear(dim * dim * 4, 10)  # Assuming 10 output classes

    def forward(self, input):
        patches = extract_image_patches(input)  

        quanvoluted_patches = torch.stack([self.quanv(patch) for patch in patches])
        x = quanvoluted_patches.reshape(input.shape[0], dim, dim, 4)

        x = x.view(-1, dim * dim * 4)  # Flatten for the fully connected layer
        x = self.fc1(x)
        x = F.softmax(x, dim=1)  # Apply softmax
        return x

# %%
loss_fn = F.cross_entropy
train_loader, test_loader = load_dataset(n_train, n_test, batch_size)
# Out:
# Number of training samples: 500
# Number of test samples: 100

# %%
def append_data_to_markdown_table(file_path, circuit, lr, gamma, batch_size, val_loss, val_acc):
    """
    Appends variables to an existing Markdown table in a file, formatting floats to 3 decimal places.

    Args:
        file_path (str): The path to the Markdown file.
        lr (float): The learning rate value.
        gamma (float): The gamma value.
        batch_size (int): The batch size value.
        val_loss (float): The validation loss value.
        val_acc (float): The validation accuracy value.
    """

    with open(file_path, 'a') as f:  # Open the file in append mode
        row = f"| {circuit} | {lr} | {gamma:.2f} | {batch_size} | {val_loss:.3f} | {val_acc:.2f} |\n"
        f.write(row)  # Write the new row of data
        
lr_values    = [0.001, 0.001, 0.0007, 0.0007, 0.0005, 0.0005, 0.0003, 0.0003]
gamma_values = [0.98, 0.96, 0.96, 0.98, 0.98, 0.96, 0.98, 0.96] 

for lr, gamma in zip(lr_values, gamma_values):
    for _ in range(3):
        model = HQNN() 
        optimizer = torch.optim.Adam(model.parameters(), lr =lr)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma) 
        for epoch in range(n_epochs):
            # ---- Training Phase ----
            running_loss = 0.0 
            correct = 0  
            total = 0
            train_losses = []
            test_losses = []
            start_time = time.time()
            for i, (images, labels) in enumerate(train_loader):
                # --- 2. Forward Pass ---
                outputs = model(images)

                # --- 3. Loss Calculation ---
                loss = loss_fn(outputs, labels)
                train_losses.append(loss.item())
                # --- 4. Backpropagation and Optimization ---
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()  
                train_losses.append(loss.item())  # Store loss for each batch

                # Accuracy calculation for the epoch
                _, predicted = torch.max(outputs.data, 1) 
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            scheduler.step() 

            # Print statistics for the epoch
            epoch_loss = sum(train_losses) / len(train_losses)  
            epoch_acc = 100 * correct / total 

            current_lr = scheduler.get_last_lr()[0]  

            # Periodic Evaluation and Logging
            print(f'[i] Epoch {epoch + 1}\n\tLoss: {epoch_loss:.4f}\tAccuracy: {epoch_acc :.2f}%\n\tElapsed Time: {time.time() - start_time:.2f}s')
            print(f'\tLearning Rate: {current_lr}\n')

        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():  # Disable gradients for evaluation
            val_correct = 0
            val_total = 0

            for images, labels in test_loader:
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                test_losses.append(loss.item())

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = sum(test_losses) / len(test_losses)
        val_acc = 100 * val_correct / val_total 

        print(f'[i] Val Loss: {val_loss:.4f}\t Val Accuracy: {val_acc :.2f}%')
        append_data_to_markdown_table("results500.md", "circ1", lr, gamma, batch_size, val_loss, val_acc)
# Out:
# [i] Epoch 1
# 	Loss: 2.2988	Accuracy: 10.80%
# 	Elapsed Time: 18.73s
# 	Learning Rate: 0.00098
#
# [i] Epoch 2
# 	Loss: 2.2792	Accuracy: 24.00%
# 	Elapsed Time: 18.90s
# 	Learning Rate: 0.0009603999999999999
#
# [i] Epoch 3
# 	Loss: 2.2592	Accuracy: 22.40%
# 	Elapsed Time: 19.24s
# 	Learning Rate: 0.0009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.2412	Accuracy: 20.00%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.0009223681599999998
#
# [i] Epoch 5
# 	Loss: 2.2209	Accuracy: 27.20%
# 	Elapsed Time: 19.09s
# 	Learning Rate: 0.0009039207967999998
#
# [i] Epoch 6
# 	Loss: 2.2007	Accuracy: 32.60%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.0008858423808639998
#
# [i] Epoch 7
# 	Loss: 2.1770	Accuracy: 36.60%
# 	Elapsed Time: 19.33s
# 	Learning Rate: 0.0008681255332467198
#
# [i] Epoch 8
# 	Loss: 2.1572	Accuracy: 42.40%
# 	Elapsed Time: 19.14s
# 	Learning Rate: 0.0008507630225817853
#
# [i] Epoch 9
# 	Loss: 2.1373	Accuracy: 47.20%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.0008337477621301496
#
# [i] Epoch 10
# 	Loss: 2.1150	Accuracy: 52.20%
# 	Elapsed Time: 19.22s
# 	Learning Rate: 0.0008170728068875465
#
# [i] Epoch 11
# 	Loss: 2.0947	Accuracy: 52.80%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.0008007313507497956
#
# [i] Epoch 12
# 	Loss: 2.0788	Accuracy: 53.20%
# 	Elapsed Time: 19.12s
# 	Learning Rate: 0.0007847167237347997
#
# [i] Epoch 13
# 	Loss: 2.0611	Accuracy: 54.20%
# 	Elapsed Time: 18.97s
# 	Learning Rate: 0.0007690223892601037
#
# [i] Epoch 14
# 	Loss: 2.0500	Accuracy: 55.40%
# 	Elapsed Time: 19.04s
# 	Learning Rate: 0.0007536419414749016
#
# [i] Epoch 15
# 	Loss: 2.0322	Accuracy: 57.80%
# 	Elapsed Time: 19.30s
# 	Learning Rate: 0.0007385691026454036
#
# [i] Epoch 16
# 	Loss: 2.0206	Accuracy: 60.00%
# 	Elapsed Time: 19.77s
# 	Learning Rate: 0.0007237977205924955
#
# [i] Epoch 17
# 	Loss: 2.0071	Accuracy: 60.60%
# 	Elapsed Time: 19.74s
# 	Learning Rate: 0.0007093217661806456
#
# [i] Epoch 18
# 	Loss: 1.9948	Accuracy: 61.40%
# 	Elapsed Time: 19.43s
# 	Learning Rate: 0.0006951353308570327
#
# [i] Epoch 19
# 	Loss: 1.9786	Accuracy: 63.80%
# 	Elapsed Time: 19.39s
# 	Learning Rate: 0.000681232624239892
#
# [i] Epoch 20
# 	Loss: 1.9703	Accuracy: 65.00%
# 	Elapsed Time: 19.35s
# 	Learning Rate: 0.0006676079717550942
#
# [i] Val Loss: 2.0006	 Val Accuracy: 66.00%
# [i] Epoch 1
# 	Loss: 2.2919	Accuracy: 16.80%
# 	Elapsed Time: 18.90s
# 	Learning Rate: 0.00098
#
# [i] Epoch 2
# 	Loss: 2.2655	Accuracy: 18.20%
# 	Elapsed Time: 19.24s
# 	Learning Rate: 0.0009603999999999999
#
# [i] Epoch 3
# 	Loss: 2.2500	Accuracy: 16.00%
# 	Elapsed Time: 19.47s
# 	Learning Rate: 0.0009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.2282	Accuracy: 24.40%
# 	Elapsed Time: 19.54s
# 	Learning Rate: 0.0009223681599999998
#
# [i] Epoch 5
# 	Loss: 2.2063	Accuracy: 33.80%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.0009039207967999998
#
# [i] Epoch 6
# 	Loss: 2.1852	Accuracy: 39.80%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.0008858423808639998
#
# [i] Epoch 7
# 	Loss: 2.1582	Accuracy: 43.40%
# 	Elapsed Time: 19.03s
# 	Learning Rate: 0.0008681255332467198
#
# [i] Epoch 8
# 	Loss: 2.1339	Accuracy: 48.40%
# 	Elapsed Time: 19.05s
# 	Learning Rate: 0.0008507630225817853
#
# [i] Epoch 9
# 	Loss: 2.1096	Accuracy: 54.80%
# 	Elapsed Time: 19.32s
# 	Learning Rate: 0.0008337477621301496
#
# [i] Epoch 10
# 	Loss: 2.0881	Accuracy: 56.20%
# 	Elapsed Time: 19.36s
# 	Learning Rate: 0.0008170728068875465
#
# [i] Epoch 11
# 	Loss: 2.0654	Accuracy: 63.60%
# 	Elapsed Time: 19.31s
# 	Learning Rate: 0.0008007313507497956
#
# [i] Epoch 12
# 	Loss: 2.0425	Accuracy: 63.00%
# 	Elapsed Time: 19.26s
# 	Learning Rate: 0.0007847167237347997
#
# [i] Epoch 13
# 	Loss: 2.0233	Accuracy: 64.20%
# 	Elapsed Time: 19.24s
# 	Learning Rate: 0.0007690223892601037
#
# [i] Epoch 14
# 	Loss: 2.0086	Accuracy: 67.40%
# 	Elapsed Time: 19.05s
# 	Learning Rate: 0.0007536419414749016
#
# [i] Epoch 15
# 	Loss: 1.9900	Accuracy: 66.80%
# 	Elapsed Time: 19.18s
# 	Learning Rate: 0.0007385691026454036
#
# [i] Epoch 16
# 	Loss: 1.9753	Accuracy: 66.60%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.0007237977205924955
#
# [i] Epoch 17
# 	Loss: 1.9648	Accuracy: 68.00%
# 	Elapsed Time: 19.28s
# 	Learning Rate: 0.0007093217661806456
#
# [i] Epoch 18
# 	Loss: 1.9530	Accuracy: 68.20%
# 	Elapsed Time: 19.22s
# 	Learning Rate: 0.0006951353308570327
#
# [i] Epoch 19
# 	Loss: 1.9426	Accuracy: 69.20%
# 	Elapsed Time: 19.22s
# 	Learning Rate: 0.000681232624239892
#
# [i] Epoch 20
# 	Loss: 1.9333	Accuracy: 69.00%
# 	Elapsed Time: 17.64s
# 	Learning Rate: 0.0006676079717550942
#
# [i] Val Loss: 1.9841	 Val Accuracy: 60.00%
# [i] Epoch 1
# 	Loss: 2.2989	Accuracy: 11.40%
# 	Elapsed Time: 16.86s
# 	Learning Rate: 0.00098
#
# [i] Epoch 2
# 	Loss: 2.2704	Accuracy: 16.20%
# 	Elapsed Time: 16.96s
# 	Learning Rate: 0.0009603999999999999
#
# [i] Epoch 3
# 	Loss: 2.2513	Accuracy: 14.20%
# 	Elapsed Time: 17.05s
# 	Learning Rate: 0.0009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.2336	Accuracy: 19.00%
# 	Elapsed Time: 17.02s
# 	Learning Rate: 0.0009223681599999998
#
# [i] Epoch 5
# 	Loss: 2.2089	Accuracy: 31.20%
# 	Elapsed Time: 17.05s
# 	Learning Rate: 0.0009039207967999998
#
# [i] Epoch 6
# 	Loss: 2.1847	Accuracy: 39.00%
# 	Elapsed Time: 17.03s
# 	Learning Rate: 0.0008858423808639998
#
# [i] Epoch 7
# 	Loss: 2.1552	Accuracy: 47.40%
# 	Elapsed Time: 17.02s
# 	Learning Rate: 0.0008681255332467198
#
# [i] Epoch 8
# 	Loss: 2.1294	Accuracy: 51.40%
# 	Elapsed Time: 17.10s
# 	Learning Rate: 0.0008507630225817853
#
# [i] Epoch 9
# 	Loss: 2.1023	Accuracy: 58.80%
# 	Elapsed Time: 17.03s
# 	Learning Rate: 0.0008337477621301496
#
# [i] Epoch 10
# 	Loss: 2.0775	Accuracy: 60.20%
# 	Elapsed Time: 17.11s
# 	Learning Rate: 0.0008170728068875465
#
# [i] Epoch 11
# 	Loss: 2.0574	Accuracy: 62.60%
# 	Elapsed Time: 17.00s
# 	Learning Rate: 0.0008007313507497956
#
# [i] Epoch 12
# 	Loss: 2.0327	Accuracy: 63.40%
# 	Elapsed Time: 17.10s
# 	Learning Rate: 0.0007847167237347997
#
# [i] Epoch 13
# 	Loss: 2.0131	Accuracy: 64.40%
# 	Elapsed Time: 16.96s
# 	Learning Rate: 0.0007690223892601037
#
# [i] Epoch 14
# 	Loss: 1.9996	Accuracy: 66.40%
# 	Elapsed Time: 17.00s
# 	Learning Rate: 0.0007536419414749016
#
# [i] Epoch 15
# 	Loss: 1.9832	Accuracy: 67.60%
# 	Elapsed Time: 17.03s
# 	Learning Rate: 0.0007385691026454036
#
# [i] Epoch 16
# 	Loss: 1.9673	Accuracy: 68.40%
# 	Elapsed Time: 17.12s
# 	Learning Rate: 0.0007237977205924955
#
# [i] Epoch 17
# 	Loss: 1.9584	Accuracy: 68.60%
# 	Elapsed Time: 17.08s
# 	Learning Rate: 0.0007093217661806456
#
# [i] Epoch 18
# 	Loss: 1.9484	Accuracy: 68.00%
# 	Elapsed Time: 17.06s
# 	Learning Rate: 0.0006951353308570327
#
# [i] Epoch 19
# 	Loss: 1.9368	Accuracy: 69.20%
# 	Elapsed Time: 16.99s
# 	Learning Rate: 0.000681232624239892
#
# [i] Epoch 20
# 	Loss: 1.9275	Accuracy: 69.00%
# 	Elapsed Time: 17.02s
# 	Learning Rate: 0.0006676079717550942
#
# [i] Val Loss: 1.9952	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2865	Accuracy: 14.80%
# 	Elapsed Time: 16.70s
# 	Learning Rate: 0.00096
#
# [i] Epoch 2
# 	Loss: 2.2654	Accuracy: 13.60%
# 	Elapsed Time: 16.88s
# 	Learning Rate: 0.0009216
#
# [i] Epoch 3
# 	Loss: 2.2429	Accuracy: 16.60%
# 	Elapsed Time: 16.90s
# 	Learning Rate: 0.0008847359999999999
#
# [i] Epoch 4
# 	Loss: 2.2210	Accuracy: 29.80%
# 	Elapsed Time: 17.11s
# 	Learning Rate: 0.0008493465599999999
#
# [i] Epoch 5
# 	Loss: 2.2009	Accuracy: 35.00%
# 	Elapsed Time: 17.10s
# 	Learning Rate: 0.0008153726975999999
#
# [i] Epoch 6
# 	Loss: 2.1793	Accuracy: 39.20%
# 	Elapsed Time: 17.20s
# 	Learning Rate: 0.0007827577896959998
#
# [i] Epoch 7
# 	Loss: 2.1557	Accuracy: 42.80%

# 	Elapsed Time: 18.17s
# 	Learning Rate: 0.0006648326359915007
#
# [i] Epoch 11
# 	Loss: 2.0849	Accuracy: 55.40%
# 	Elapsed Time: 18.36s
# 	Learning Rate: 0.0006382393305518406
#
# [i] Epoch 12
# 	Loss: 2.0695	Accuracy: 56.20%
# 	Elapsed Time: 18.38s
# 	Learning Rate: 0.000612709757329767
#
# [i] Epoch 13
# 	Loss: 2.0506	Accuracy: 60.00%
# 	Elapsed Time: 18.42s
# 	Learning Rate: 0.0005882013670365763
#
# [i] Epoch 14
# 	Loss: 2.0403	Accuracy: 62.60%
# 	Elapsed Time: 18.35s
# 	Learning Rate: 0.0005646733123551131
#
# [i] Epoch 15
# 	Loss: 2.0247	Accuracy: 62.60%
# 	Elapsed Time: 18.47s
# 	Learning Rate: 0.0005420863798609086
#
# [i] Epoch 16
# 	Loss: 2.0117	Accuracy: 65.60%
# 	Elapsed Time: 18.29s
# 	Learning Rate: 0.0005204029246664722
#
# [i] Epoch 17
# 	Loss: 1.9994	Accuracy: 66.20%
# 	Elapsed Time: 18.41s
# 	Learning Rate: 0.0004995868076798133
#
# [i] Epoch 18
# 	Loss: 1.9891	Accuracy: 66.80%
# 	Elapsed Time: 18.43s
# 	Learning Rate: 0.0004796033353726208
#
# [i] Epoch 19
# 	Loss: 1.9804	Accuracy: 66.40%
# 	Elapsed Time: 18.51s
# 	Learning Rate: 0.00046041920195771596
#
# [i] Epoch 20
# 	Loss: 1.9723	Accuracy: 67.80%
# 	Elapsed Time: 18.31s
# 	Learning Rate: 0.0004420024338794073
#
# [i] Val Loss: 2.0138	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.3047	Accuracy: 9.00%
# 	Elapsed Time: 18.28s
# 	Learning Rate: 0.000672
#
# [i] Epoch 2
# 	Loss: 2.2881	Accuracy: 15.60%
# 	Elapsed Time: 18.43s
# 	Learning Rate: 0.0006451199999999999
#
# [i] Epoch 3
# 	Loss: 2.2696	Accuracy: 14.60%
# 	Elapsed Time: 18.45s
# 	Learning Rate: 0.0006193151999999999
#
# [i] Epoch 4
# 	Loss: 2.2563	Accuracy: 14.20%
# 	Elapsed Time: 18.56s
# 	Learning Rate: 0.0005945425919999999
#
# [i] Epoch 5
# 	Loss: 2.2413	Accuracy: 20.20%
# 	Elapsed Time: 18.59s
# 	Learning Rate: 0.0005707608883199999
#
# [i] Epoch 6
# 	Loss: 2.2272	Accuracy: 24.60%
# 	Elapsed Time: 18.68s
# 	Learning Rate: 0.0005479304527872
#
# [i] Epoch 7
# 	Loss: 2.2126	Accuracy: 34.40%
# 	Elapsed Time: 18.74s
# 	Learning Rate: 0.0005260132346757119
#
# [i] Epoch 8
# 	Loss: 2.1974	Accuracy: 36.60%
# 	Elapsed Time: 18.80s
# 	Learning Rate: 0.0005049727052886834
#
# [i] Epoch 9
# 	Loss: 2.1821	Accuracy: 39.40%
# 	Elapsed Time: 18.79s
# 	Learning Rate: 0.00048477379707713604
#
# [i] Epoch 10
# 	Loss: 2.1684	Accuracy: 42.60%
# 	Elapsed Time: 19.02s
# 	Learning Rate: 0.00046538284519405057
#
# [i] Epoch 11
# 	Loss: 2.1580	Accuracy: 44.20%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.00044676753138628853
#
# [i] Epoch 12
# 	Loss: 2.1461	Accuracy: 46.40%
# 	Elapsed Time: 19.28s
# 	Learning Rate: 0.00042889683013083696
#
# [i] Epoch 13
# 	Loss: 2.1349	Accuracy: 47.20%
# 	Elapsed Time: 19.78s
# 	Learning Rate: 0.0004117409569256035
#
# [i] Epoch 14
# 	Loss: 2.1271	Accuracy: 47.20%
# 	Elapsed Time: 20.16s
# 	Learning Rate: 0.00039527131864857936
#
# [i] Epoch 15
# 	Loss: 2.1157	Accuracy: 48.00%
# 	Elapsed Time: 20.20s
# 	Learning Rate: 0.00037946046590263616
#
# [i] Epoch 16
# 	Loss: 2.1059	Accuracy: 50.60%
# 	Elapsed Time: 20.28s
# 	Learning Rate: 0.0003642820472665307
#
# [i] Epoch 17
# 	Loss: 2.0972	Accuracy: 51.20%
# 	Elapsed Time: 20.63s
# 	Learning Rate: 0.00034971076537586944
#
# [i] Epoch 18
# 	Loss: 2.0929	Accuracy: 51.20%
# 	Elapsed Time: 20.53s
# 	Learning Rate: 0.00033572233476083466
#
# [i] Epoch 19
# 	Loss: 2.0857	Accuracy: 54.00%
# 	Elapsed Time: 20.58s
# 	Learning Rate: 0.00032229344137040125
#
# [i] Epoch 20
# 	Loss: 2.0760	Accuracy: 56.80%
# 	Elapsed Time: 20.22s
# 	Learning Rate: 0.0003094017037155852
#
# [i] Val Loss: 2.1122	 Val Accuracy: 49.00%
# [i] Epoch 1
# 	Loss: 2.2972	Accuracy: 11.80%
# 	Elapsed Time: 19.76s
# 	Learning Rate: 0.000672
#
# [i] Epoch 2
# 	Loss: 2.2805	Accuracy: 21.20%
# 	Elapsed Time: 19.56s
# 	Learning Rate: 0.0006451199999999999
#
# [i] Epoch 3
# 	Loss: 2.2628	Accuracy: 22.60%
# 	Elapsed Time: 19.31s
# 	Learning Rate: 0.0006193151999999999
#
# [i] Epoch 4
# 	Loss: 2.2470	Accuracy: 17.20%
# 	Elapsed Time: 19.35s
# 	Learning Rate: 0.0005945425919999999
#
# [i] Epoch 5
# 	Loss: 2.2350	Accuracy: 21.60%
# 	Elapsed Time: 19.18s
# 	Learning Rate: 0.0005707608883199999
#
# [i] Epoch 6
# 	Loss: 2.2192	Accuracy: 26.80%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.0005479304527872
#
# [i] Epoch 7
# 	Loss: 2.2053	Accuracy: 29.80%
# 	Elapsed Time: 19.62s
# 	Learning Rate: 0.0005260132346757119
#
# [i] Epoch 8
# 	Loss: 2.1910	Accuracy: 31.60%
# 	Elapsed Time: 20.50s
# 	Learning Rate: 0.0005049727052886834
#
# [i] Epoch 9
# 	Loss: 2.1771	Accuracy: 35.00%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.00048477379707713604
#
# [i] Epoch 10
# 	Loss: 2.1636	Accuracy: 43.00%
# 	Elapsed Time: 20.03s
# 	Learning Rate: 0.00046538284519405057
#
# [i] Epoch 11
# 	Loss: 2.1483	Accuracy: 45.00%
# 	Elapsed Time: 20.19s
# 	Learning Rate: 0.00044676753138628853
#
# [i] Epoch 12
# 	Loss: 2.1371	Accuracy: 47.40%
# 	Elapsed Time: 20.25s
# 	Learning Rate: 0.00042889683013083696
#
# [i] Epoch 13
# 	Loss: 2.1223	Accuracy: 51.00%
# 	Elapsed Time: 20.38s
# 	Learning Rate: 0.0004117409569256035
#
# [i] Epoch 14
# 	Loss: 2.1125	Accuracy: 53.40%
# 	Elapsed Time: 20.09s
# 	Learning Rate: 0.00039527131864857936
#
# [i] Epoch 15
# 	Loss: 2.0988	Accuracy: 56.20%
# 	Elapsed Time: 20.36s

# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.0006588343999999999
#
# [i] Epoch 4
# 	Loss: 2.2545	Accuracy: 16.60%
# 	Elapsed Time: 22.88s
# 	Learning Rate: 0.0006456577119999999
#
# [i] Epoch 5
# 	Loss: 2.2392	Accuracy: 19.00%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.0006327445577599998
#
# [i] Epoch 6
# 	Loss: 2.2231	Accuracy: 23.40%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.0006200896666047998
#
# [i] Epoch 7
# 	Loss: 2.2065	Accuracy: 28.80%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.0006076878732727038
#
# [i] Epoch 8
# 	Loss: 2.1905	Accuracy: 35.20%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.0005955341158072497
#
# [i] Epoch 9
# 	Loss: 2.1706	Accuracy: 46.60%
# 	Elapsed Time: 22.98s
# 	Learning Rate: 0.0005836234334911047
#
# [i] Epoch 10
# 	Loss: 2.1536	Accuracy: 53.60%
# 	Elapsed Time: 22.98s
# 	Learning Rate: 0.0005719509648212825
#
# [i] Epoch 11
# 	Loss: 2.1358	Accuracy: 53.00%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.0005605119455248568
#
# [i] Epoch 12
# 	Loss: 2.1185	Accuracy: 54.60%
# 	Elapsed Time: 22.34s
# 	Learning Rate: 0.0005493017066143597
#
# [i] Epoch 13
# 	Loss: 2.1028	Accuracy: 57.00%
# 	Elapsed Time: 22.26s
# 	Learning Rate: 0.0005383156724820725
#
# [i] Epoch 14
# 	Loss: 2.0865	Accuracy: 58.60%
# 	Elapsed Time: 22.17s
# 	Learning Rate: 0.0005275493590324309
#
# [i] Epoch 15
# 	Loss: 2.0753	Accuracy: 60.20%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.0005169983718517823
#
# [i] Epoch 16
# 	Loss: 2.0578	Accuracy: 61.40%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.0005066584044147466
#
# [i] Epoch 17
# 	Loss: 2.0450	Accuracy: 63.20%
# 	Elapsed Time: 21.36s
# 	Learning Rate: 0.0004965252363264516
#
# [i] Epoch 18
# 	Loss: 2.0351	Accuracy: 63.00%
# 	Elapsed Time: 21.62s
# 	Learning Rate: 0.0004865947315999226
#
# [i] Epoch 19
# 	Loss: 2.0234	Accuracy: 64.80%
# 	Elapsed Time: 21.35s
# 	Learning Rate: 0.00047686283696792416
#
# [i] Epoch 20
# 	Loss: 2.0147	Accuracy: 64.80%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.00046732558022856565
#
# [i] Val Loss: 2.0369	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2960	Accuracy: 12.20%
# 	Elapsed Time: 20.46s
# 	Learning Rate: 0.000686
#
# [i] Epoch 2
# 	Loss: 2.2775	Accuracy: 18.80%
# 	Elapsed Time: 20.68s
# 	Learning Rate: 0.0006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.2571	Accuracy: 16.60%
# 	Elapsed Time: 20.60s
# 	Learning Rate: 0.0006588343999999999
#
# [i] Epoch 4
# 	Loss: 2.2429	Accuracy: 15.60%
# 	Elapsed Time: 20.62s
# 	Learning Rate: 0.0006456577119999999
#
# [i] Epoch 5
# 	Loss: 2.2279	Accuracy: 19.60%
# 	Elapsed Time: 20.72s
# 	Learning Rate: 0.0006327445577599998
#
# [i] Epoch 6
# 	Loss: 2.2120	Accuracy: 27.80%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.0006200896666047998
#
# [i] Epoch 7
# 	Loss: 2.1968	Accuracy: 33.60%
# 	Elapsed Time: 20.99s
# 	Learning Rate: 0.0006076878732727038
#
# [i] Epoch 8
# 	Loss: 2.1792	Accuracy: 37.60%
# 	Elapsed Time: 21.15s
# 	Learning Rate: 0.0005955341158072497
#
# [i] Epoch 9
# 	Loss: 2.1633	Accuracy: 40.80%
# 	Elapsed Time: 21.56s
# 	Learning Rate: 0.0005836234334911047
#
# [i] Epoch 10
# 	Loss: 2.1487	Accuracy: 43.60%
# 	Elapsed Time: 21.35s
# 	Learning Rate: 0.0005719509648212825
#
# [i] Epoch 11
# 	Loss: 2.1325	Accuracy: 49.00%
# 	Elapsed Time: 21.20s
# 	Learning Rate: 0.0005605119455248568
#
# [i] Epoch 12
# 	Loss: 2.1184	Accuracy: 51.60%
# 	Elapsed Time: 20.91s
# 	Learning Rate: 0.0005493017066143597
#
# [i] Epoch 13
# 	Loss: 2.1014	Accuracy: 53.60%
# 	Elapsed Time: 20.51s
# 	Learning Rate: 0.0005383156724820725
#
# [i] Epoch 14
# 	Loss: 2.0853	Accuracy: 57.00%
# 	Elapsed Time: 20.35s
# 	Learning Rate: 0.0005275493590324309
#
# [i] Epoch 15
# 	Loss: 2.0742	Accuracy: 58.80%
# 	Elapsed Time: 19.94s
# 	Learning Rate: 0.0005169983718517823
#
# [i] Epoch 16
# 	Loss: 2.0589	Accuracy: 61.20%
# 	Elapsed Time: 19.51s
# 	Learning Rate: 0.0005066584044147466
#
# [i] Epoch 17
# 	Loss: 2.0455	Accuracy: 62.00%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.0004965252363264516
#
# [i] Epoch 18
# 	Loss: 2.0344	Accuracy: 63.20%
# 	Elapsed Time: 19.20s
# 	Learning Rate: 0.0004865947315999226
#
# [i] Epoch 19
# 	Loss: 2.0253	Accuracy: 64.00%
# 	Elapsed Time: 19.15s
# 	Learning Rate: 0.00047686283696792416
#
# [i] Epoch 20
# 	Loss: 2.0144	Accuracy: 65.40%
# 	Elapsed Time: 18.95s
# 	Learning Rate: 0.00046732558022856565
#
# [i] Val Loss: 2.0538	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.3009	Accuracy: 12.80%
# 	Elapsed Time: 18.42s
# 	Learning Rate: 0.00049
#
# [i] Epoch 2
# 	Loss: 2.2903	Accuracy: 17.00%
# 	Elapsed Time: 18.57s
# 	Learning Rate: 0.00048019999999999996
#
# [i] Epoch 3
# 	Loss: 2.2786	Accuracy: 16.80%
# 	Elapsed Time: 18.55s
# 	Learning Rate: 0.00047059599999999994
#
# [i] Epoch 4
# 	Loss: 2.2675	Accuracy: 21.60%
# 	Elapsed Time: 18.64s
# 	Learning Rate: 0.0004611840799999999
#
# [i] Epoch 5
# 	Loss: 2.2542	Accuracy: 25.40%
# 	Elapsed Time: 18.79s
# 	Learning Rate: 0.0004519603983999999
#
# [i] Epoch 6
# 	Loss: 2.2462	Accuracy: 20.40%
# 	Elapsed Time: 18.77s
# 	Learning Rate: 0.0004429211904319999
#
# [i] Epoch 7
# 	Loss: 2.2362	Accuracy: 22.20%
# 	Elapsed Time: 19.03s
# 	Learning Rate: 0.0004340627666233599
#
# [i] Epoch 8
# 	Loss: 2.2244	Accuracy: 28.40%
# 	Elapsed Time: 18.90s
# 	Learning Rate: 0.00042538151129089267
#
# [i] Epoch 9
# 	Loss: 2.2148	Accuracy: 32.60%
# 	Elapsed Time: 19.08s
# 	Learning Rate: 0.0004168738810650748
#
# [i] Epoch 10
# 	Loss: 2.2032	Accuracy: 33.40%
# 	Elapsed Time: 18.82s
# 	Learning Rate: 0.00040853640344377327
#
# [i] Epoch 11
# 	Loss: 2.1922	Accuracy: 39.40%
# 	Elapsed Time: 19.14s
# 	Learning Rate: 0.0004003656753748978
#
# [i] Epoch 12
# 	Loss: 2.1810	Accuracy: 42.60%
# 	Elapsed Time: 18.93s
# 	Learning Rate: 0.00039235836186739986
#
# [i] Epoch 13
# 	Loss: 2.1702	Accuracy: 44.20%
# 	Elapsed Time: 19.04s
# 	Learning Rate: 0.00038451119463005185
#
# [i] Epoch 14
# 	Loss: 2.1597	Accuracy: 46.60%
# 	Elapsed Time: 18.97s

# 	Elapsed Time: 19.24s
# 	Learning Rate: 0.00034756766542851634
#
# [i] Epoch 19
# 	Loss: 2.0928	Accuracy: 58.80%
# 	Elapsed Time: 19.33s
# 	Learning Rate: 0.000340616312119946
#
# [i] Epoch 20
# 	Loss: 2.0846	Accuracy: 59.00%
# 	Elapsed Time: 19.17s
# 	Learning Rate: 0.0003338039858775471
#
# [i] Val Loss: 2.0859	 Val Accuracy: 57.00%
# [i] Epoch 1
# 	Loss: 2.2978	Accuracy: 10.60%
# 	Elapsed Time: 18.80s
# 	Learning Rate: 0.00049
#
# [i] Epoch 2
# 	Loss: 2.2852	Accuracy: 18.80%
# 	Elapsed Time: 19.06s
# 	Learning Rate: 0.00048019999999999996
#
# [i] Epoch 3
# 	Loss: 2.2738	Accuracy: 18.20%
# 	Elapsed Time: 19.11s
# 	Learning Rate: 0.00047059599999999994
#
# [i] Epoch 4
# 	Loss: 2.2615	Accuracy: 16.00%
# 	Elapsed Time: 19.12s
# 	Learning Rate: 0.0004611840799999999
#
# [i] Epoch 5
# 	Loss: 2.2523	Accuracy: 16.00%
# 	Elapsed Time: 19.20s
# 	Learning Rate: 0.0004519603983999999
#
# [i] Epoch 6
# 	Loss: 2.2436	Accuracy: 19.60%
# 	Elapsed Time: 19.12s
# 	Learning Rate: 0.0004429211904319999
#
# [i] Epoch 7
# 	Loss: 2.2335	Accuracy: 22.40%
# 	Elapsed Time: 19.22s
# 	Learning Rate: 0.0004340627666233599
#
# [i] Epoch 8
# 	Loss: 2.2218	Accuracy: 27.40%
# 	Elapsed Time: 19.18s
# 	Learning Rate: 0.00042538151129089267
#
# [i] Epoch 9
# 	Loss: 2.2120	Accuracy: 30.40%
# 	Elapsed Time: 19.32s
# 	Learning Rate: 0.0004168738810650748
#
# [i] Epoch 10
# 	Loss: 2.1994	Accuracy: 33.20%
# 	Elapsed Time: 19.17s
# 	Learning Rate: 0.00040853640344377327
#
# [i] Epoch 11
# 	Loss: 2.1877	Accuracy: 40.20%
# 	Elapsed Time: 19.50s
# 	Learning Rate: 0.0004003656753748978
#
# [i] Epoch 12
# 	Loss: 2.1773	Accuracy: 43.60%
# 	Elapsed Time: 19.05s
# 	Learning Rate: 0.00039235836186739986
#
# [i] Epoch 13
# 	Loss: 2.1670	Accuracy: 44.60%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.00038451119463005185
#
# [i] Epoch 14
# 	Loss: 2.1551	Accuracy: 45.60%
# 	Elapsed Time: 19.29s
# 	Learning Rate: 0.0003768209707374508
#
# [i] Epoch 15
# 	Loss: 2.1461	Accuracy: 48.40%
# 	Elapsed Time: 19.46s
# 	Learning Rate: 0.0003692845513227018
#
# [i] Epoch 16
# 	Loss: 2.1330	Accuracy: 50.40%
# 	Elapsed Time: 19.20s
# 	Learning Rate: 0.00036189886029624774
#
# [i] Epoch 17
# 	Loss: 2.1222	Accuracy: 53.60%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.0003546608830903228
#
# [i] Epoch 18
# 	Loss: 2.1104	Accuracy: 55.60%
# 	Elapsed Time: 19.26s
# 	Learning Rate: 0.00034756766542851634
#
# [i] Epoch 19
# 	Loss: 2.0997	Accuracy: 57.00%
# 	Elapsed Time: 19.28s
# 	Learning Rate: 0.000340616312119946
#
# [i] Epoch 20
# 	Loss: 2.0909	Accuracy: 59.20%
# 	Elapsed Time: 19.32s
# 	Learning Rate: 0.0003338039858775471
#
# [i] Val Loss: 2.1167	 Val Accuracy: 50.00%
# [i] Epoch 1
# 	Loss: 2.2991	Accuracy: 10.60%
# 	Elapsed Time: 19.02s
# 	Learning Rate: 0.00048
#
# [i] Epoch 2
# 	Loss: 2.2851	Accuracy: 15.60%
# 	Elapsed Time: 19.32s
# 	Learning Rate: 0.0004608
#
# [i] Epoch 3
# 	Loss: 2.2748	Accuracy: 13.80%
# 	Elapsed Time: 19.34s
# 	Learning Rate: 0.00044236799999999995
#
# [i] Epoch 4
# 	Loss: 2.2645	Accuracy: 13.60%
# 	Elapsed Time: 19.60s
# 	Learning Rate: 0.00042467327999999994
#
# [i] Epoch 5
# 	Loss: 2.2555	Accuracy: 14.20%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.00040768634879999994
#
# [i] Epoch 6
# 	Loss: 2.2454	Accuracy: 15.80%
# 	Elapsed Time: 19.42s
# 	Learning Rate: 0.0003913788948479999
#
# [i] Epoch 7
# 	Loss: 2.2371	Accuracy: 19.40%
# 	Elapsed Time: 19.32s
# 	Learning Rate: 0.0003757237390540799
#
# [i] Epoch 8
# 	Loss: 2.2262	Accuracy: 22.60%
# 	Elapsed Time: 19.43s
# 	Learning Rate: 0.00036069478949191667
#
# [i] Epoch 9
# 	Loss: 2.2168	Accuracy: 26.80%
# 	Elapsed Time: 19.54s
# 	Learning Rate: 0.00034626699791224
#
# [i] Epoch 10
# 	Loss: 2.2074	Accuracy: 32.60%
# 	Elapsed Time: 19.62s
# 	Learning Rate: 0.0003324163179957504
#
# [i] Epoch 11
# 	Loss: 2.1982	Accuracy: 36.60%
# 	Elapsed Time: 19.51s
# 	Learning Rate: 0.0003191196652759203
#
# [i] Epoch 12
# 	Loss: 2.1911	Accuracy: 37.00%
# 	Elapsed Time: 19.35s
# 	Learning Rate: 0.0003063548786648835
#
# [i] Epoch 13
# 	Loss: 2.1790	Accuracy: 39.20%
# 	Elapsed Time: 19.13s
# 	Learning Rate: 0.00029410068351828813
#
# [i] Epoch 14
# 	Loss: 2.1702	Accuracy: 43.80%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.0002823366561775566
#
# [i] Epoch 15
# 	Loss: 2.1603	Accuracy: 46.60%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.0002710431899304543
#
# [i] Epoch 16
# 	Loss: 2.1552	Accuracy: 48.20%
# 	Elapsed Time: 19.25s
# 	Learning Rate: 0.0002602014623332361
#
# [i] Epoch 17
# 	Loss: 2.1454	Accuracy: 49.80%
# 	Elapsed Time: 19.33s
# 	Learning Rate: 0.00024979340383990666
#
# [i] Epoch 18
# 	Loss: 2.1371	Accuracy: 52.20%
# 	Elapsed Time: 19.27s
# 	Learning Rate: 0.0002398016676863104
#
# [i] Epoch 19
# 	Loss: 2.1292	Accuracy: 53.60%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.00023020960097885798
#
# [i] Epoch 20
# 	Loss: 2.1241	Accuracy: 53.20%
# 	Elapsed Time: 19.42s
# 	Learning Rate: 0.00022100121693970366
#
# [i] Val Loss: 2.1441	 Val Accuracy: 41.00%
# [i] Epoch 1
# 	Loss: 2.2970	Accuracy: 14.20%
# 	Elapsed Time: 19.03s
# 	Learning Rate: 0.00048
#
# [i] Epoch 2
# 	Loss: 2.2814	Accuracy: 15.00%
# 	Elapsed Time: 19.33s
# 	Learning Rate: 0.0004608
#
# [i] Epoch 3
# 	Loss: 2.2703	Accuracy: 13.60%
# 	Elapsed Time: 19.46s
# 	Learning Rate: 0.00044236799999999995
#
# [i] Epoch 4
# 	Loss: 2.2619	Accuracy: 13.80%
# 	Elapsed Time: 19.50s
# 	Learning Rate: 0.00042467327999999994
#
# [i] Epoch 5
# 	Loss: 2.2523	Accuracy: 15.20%
# 	Elapsed Time: 19.53s
# 	Learning Rate: 0.00040768634879999994
#
# [i] Epoch 6
# 	Loss: 2.2441	Accuracy: 18.20%
# 	Elapsed Time: 19.48s
# 	Learning Rate: 0.0003913788948479999
#
# [i] Epoch 7
# 	Loss: 2.2344	Accuracy: 20.20%
# 	Elapsed Time: 19.25s
# 	Learning Rate: 0.0003757237390540799
#
# [i] Epoch 8
# 	Loss: 2.2245	Accuracy: 24.00%
# 	Elapsed Time: 19.16s
# 	Learning Rate: 0.00036069478949191667
#
# [i] Epoch 9
# 	Loss: 2.2135	Accuracy: 29.40%
# 	Elapsed Time: 19.25s
# 	Learning Rate: 0.00034626699791224
#
# [i] Epoch 10
# 	Loss: 2.2049	Accuracy: 32.00%
# 	Elapsed Time: 19.20s
# 	Learning Rate: 0.0003324163179957504
#
# [i] Epoch 11
# 	Loss: 2.1945	Accuracy: 34.20%
# 	Elapsed Time: 19.50s
# 	Learning Rate: 0.0003191196652759203
#
# [i] Epoch 12
# 	Loss: 2.1857	Accuracy: 35.80%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.0003063548786648835
#
# [i] Epoch 13
# 	Loss: 2.1776	Accuracy: 38.40%
# 	Elapsed Time: 19.44s
# 	Learning Rate: 0.00029410068351828813
#
# [i] Epoch 14
# 	Loss: 2.1696	Accuracy: 40.60%
# 	Elapsed Time: 19.44s
# 	Learning Rate: 0.0002823366561775566
#
# [i] Epoch 15
# 	Loss: 2.1621	Accuracy: 43.40%
# 	Elapsed Time: 19.34s
# 	Learning Rate: 0.0002710431899304543
#
# [i] Epoch 16
# 	Loss: 2.1510	Accuracy: 45.00%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.0002602014623332361
#
# [i] Epoch 17
# 	Loss: 2.1455	Accuracy: 45.80%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.00024979340383990666
#
# [i] Epoch 18
# 	Loss: 2.1378	Accuracy: 48.60%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.0002398016676863104
#
# [i] Epoch 19
# 	Loss: 2.1319	Accuracy: 51.80%
# 	Elapsed Time: 19.50s
# 	Learning Rate: 0.00023020960097885798
#
# [i] Epoch 20
# 	Loss: 2.1247	Accuracy: 53.40%
# 	Elapsed Time: 19.36s
# 	Learning Rate: 0.00022100121693970366
#
# [i] Val Loss: 2.1332	 Val Accuracy: 49.00%
# [i] Epoch 1
# 	Loss: 2.2955	Accuracy: 12.80%
# 	Elapsed Time: 19.02s
# 	Learning Rate: 0.00048
#
# [i] Epoch 2
# 	Loss: 2.2820	Accuracy: 14.20%
# 	Elapsed Time: 19.20s
# 	Learning Rate: 0.0004608
#
# [i] Epoch 3
# 	Loss: 2.2722	Accuracy: 13.20%
# 	Elapsed Time: 19.29s
# 	Learning Rate: 0.00044236799999999995
#
# [i] Epoch 4
# 	Loss: 2.2621	Accuracy: 13.40%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.00042467327999999994
#
# [i] Epoch 5
# 	Loss: 2.2535	Accuracy: 13.60%
# 	Elapsed Time: 19.30s
# 	Learning Rate: 0.00040768634879999994
#
# [i] Epoch 6
# 	Loss: 2.2429	Accuracy: 17.00%
# 	Elapsed Time: 19.27s
# 	Learning Rate: 0.0003913788948479999
#
# [i] Epoch 7
# 	Loss: 2.2342	Accuracy: 21.60%
# 	Elapsed Time: 19.46s
# 	Learning Rate: 0.0003757237390540799
#
# [i] Epoch 8
# 	Loss: 2.2243	Accuracy: 23.40%
# 	Elapsed Time: 19.30s
# 	Learning Rate: 0.00036069478949191667
#
# [i] Epoch 9
# 	Loss: 2.2135	Accuracy: 27.40%
# 	Elapsed Time: 19.34s
# 	Learning Rate: 0.00034626699791224
#
# [i] Epoch 10
# 	Loss: 2.2052	Accuracy: 30.20%
# 	Elapsed Time: 19.12s
# 	Learning Rate: 0.0003324163179957504
#
# [i] Epoch 11
# 	Loss: 2.1939	Accuracy: 36.60%
# 	Elapsed Time: 19.30s
# 	Learning Rate: 0.0003191196652759203
#
# [i] Epoch 12
# 	Loss: 2.1852	Accuracy: 38.20%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.0003063548786648835
#
# [i] Epoch 13
# 	Loss: 2.1762	Accuracy: 39.80%
# 	Elapsed Time: 19.41s
# 	Learning Rate: 0.00029410068351828813
#
# [i] Epoch 14
# 	Loss: 2.1674	Accuracy: 42.60%
# 	Elapsed Time: 19.34s
# 	Learning Rate: 0.0002823366561775566
#
# [i] Epoch 15
# 	Loss: 2.1613	Accuracy: 45.80%
# 	Elapsed Time: 19.29s
# 	Learning Rate: 0.0002710431899304543
#
# [i] Epoch 16
# 	Loss: 2.1530	Accuracy: 49.20%
# 	Elapsed Time: 19.35s
# 	Learning Rate: 0.0002602014623332361
#
# [i] Epoch 17
# 	Loss: 2.1443	Accuracy: 50.40%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.00024979340383990666
#
# [i] Epoch 18
# 	Loss: 2.1362	Accuracy: 51.40%
# 	Elapsed Time: 19.30s
# 	Learning Rate: 0.0002398016676863104
#
# [i] Epoch 19
# 	Loss: 2.1302	Accuracy: 52.00%
# 	Elapsed Time: 19.44s
# 	Learning Rate: 0.00023020960097885798
#
# [i] Epoch 20
# 	Loss: 2.1241	Accuracy: 54.20%
# 	Elapsed Time: 19.42s
# 	Learning Rate: 0.00022100121693970366
#
# [i] Val Loss: 2.1334	 Val Accuracy: 49.00%
# [i] Epoch 1
# 	Loss: 2.3014	Accuracy: 7.00%
# 	Elapsed Time: 18.91s
# 	Learning Rate: 0.000294
#
# [i] Epoch 2
# 	Loss: 2.2936	Accuracy: 14.20%
# 	Elapsed Time: 19.12s
# 	Learning Rate: 0.00028812
#
# [i] Epoch 3
# 	Loss: 2.2868	Accuracy: 14.60%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.0002823576
#
# [i] Epoch 4
# 	Loss: 2.2809	Accuracy: 14.00%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.000276710448
#
# [i] Epoch 5
# 	Loss: 2.2734	Accuracy: 14.00%
# 	Elapsed Time: 19.25s
# 	Learning Rate: 0.00027117623904
#
# [i] Epoch 6
# 	Loss: 2.2673	Accuracy: 14.60%
# 	Elapsed Time: 19.25s
# 	Learning Rate: 0.00026575271425920003
#
# [i] Epoch 7
# 	Loss: 2.2610	Accuracy: 15.20%
# 	Elapsed Time: 19.34s
# 	Learning Rate: 0.000260437659974016
#
# [i] Epoch 8
# 	Loss: 2.2554	Accuracy: 15.60%
# 	Elapsed Time: 19.20s
# 	Learning Rate: 0.0002552289067745357
#
# [i] Epoch 9
# 	Loss: 2.2501	Accuracy: 16.80%
# 	Elapsed Time: 19.36s
# 	Learning Rate: 0.00025012432863904497
#
# [i] Epoch 10
# 	Loss: 2.2443	Accuracy: 20.40%
# 	Elapsed Time: 19.28s
# 	Learning Rate: 0.00024512184206626405
#
# [i] Epoch 11
# 	Loss: 2.2375	Accuracy: 23.20%
# 	Elapsed Time: 19.40s
# 	Learning Rate: 0.00024021940522493877
#
# [i] Epoch 12
# 	Loss: 2.2299	Accuracy: 27.60%
# 	Elapsed Time: 19.24s
# 	Learning Rate: 0.00023541501712044
#
# [i] Epoch 13
# 	Loss: 2.2234	Accuracy: 31.60%
# 	Elapsed Time: 19.46s
# 	Learning Rate: 0.00023070671677803117
#
# [i] Epoch 14
# 	Loss: 2.2190	Accuracy: 35.40%
# 	Elapsed Time: 19.27s
# 	Learning Rate: 0.00022609258244247053
#
# [i] Epoch 15
# 	Loss: 2.2132	Accuracy: 37.40%
# 	Elapsed Time: 19.35s
# 	Learning Rate: 0.00022157073079362113
#
# [i] Epoch 16
# 	Loss: 2.2055	Accuracy: 38.20%
# 	Elapsed Time: 19.39s
# 	Learning Rate: 0.0002171393161777487
#
# [i] Epoch 17
# 	Loss: 2.2006	Accuracy: 39.20%
# 	Elapsed Time: 19.26s
# 	Learning Rate: 0.00021279652985419374
#
# [i] Epoch 18
# 	Loss: 2.1952	Accuracy: 41.20%
# 	Elapsed Time: 19.32s
# 	Learning Rate: 0.00020854059925710987
#
# [i] Epoch 19
# 	Loss: 2.1899	Accuracy: 42.80%
# 	Elapsed Time: 19.46s
# 	Learning Rate: 0.00020436978727196768
#
# [i] Epoch 20
# 	Loss: 2.1823	Accuracy: 42.80%
# 	Elapsed Time: 19.44s
# 	Learning Rate: 0.00020028239152652833
#
# [i] Val Loss: 2.1736	 Val Accuracy: 38.00%
# [i] Epoch 1
# 	Loss: 2.2989	Accuracy: 11.60%
# 	Elapsed Time: 19.05s
# 	Learning Rate: 0.000294
#
# [i] Epoch 2
# 	Loss: 2.2921	Accuracy: 14.60%
# 	Elapsed Time: 19.18s
# 	Learning Rate: 0.00028812
#
# [i] Epoch 3
# 	Loss: 2.2848	Accuracy: 20.40%
# 	Elapsed Time: 19.18s
# 	Learning Rate: 0.0002823576
#
# [i] Epoch 4
# 	Loss: 2.2776	Accuracy: 24.20%
# 	Elapsed Time: 19.22s
# 	Learning Rate: 0.000276710448
#
# [i] Epoch 5
# 	Loss: 2.2698	Accuracy: 22.40%
# 	Elapsed Time: 19.19s
# 	Learning Rate: 0.00027117623904
#
# [i] Epoch 6
# 	Loss: 2.2631	Accuracy: 19.80%
# 	Elapsed Time: 19.23s
# 	Learning Rate: 0.00026575271425920003
#
# [i] Epoch 7
# 	Loss: 2.2554	Accuracy: 18.60%
# 	Elapsed Time: 19.33s
# 	Learning Rate: 0.000260437659974016
#
# [i] Epoch 8
# 	Loss: 2.2490	Accuracy: 18.80%
# 	Elapsed Time: 19.51s
# 	Learning Rate: 0.0002552289067745357
#
# [i] Epoch 9
# 	Loss: 2.2440	Accuracy: 21.60%
# 	Elapsed Time: 19.49s
# 	Learning Rate: 0.00025012432863904497
#
# [i] Epoch 10
# 	Loss: 2.2376	Accuracy: 22.20%
# 	Elapsed Time: 19.51s
# 	Learning Rate: 0.00024512184206626405
#
# [i] Epoch 11
# 	Loss: 2.2313	Accuracy: 23.20%
# 	Elapsed Time: 19.56s
# 	Learning Rate: 0.00024021940522493877
#
# [i] Epoch 12
# 	Loss: 2.2258	Accuracy: 24.20%
# 	Elapsed Time: 19.63s
# 	Learning Rate: 0.00023541501712044
#
# [i] Epoch 13
# 	Loss: 2.2199	Accuracy: 27.60%
# 	Elapsed Time: 19.67s
# 	Learning Rate: 0.00023070671677803117
#
# [i] Epoch 14
# 	Loss: 2.2128	Accuracy: 29.60%
# 	Elapsed Time: 19.60s
# 	Learning Rate: 0.00022609258244247053
#
# [i] Epoch 15
# 	Loss: 2.2085	Accuracy: 29.20%
# 	Elapsed Time: 19.70s
# 	Learning Rate: 0.00022157073079362113
#
# [i] Epoch 16
# 	Loss: 2.2018	Accuracy: 30.40%
# 	Elapsed Time: 19.62s
# 	Learning Rate: 0.0002171393161777487
#
# [i] Epoch 17
# 	Loss: 2.1969	Accuracy: 32.20%
# 	Elapsed Time: 19.93s
# 	Learning Rate: 0.00021279652985419374
#
# [i] Epoch 18
# 	Loss: 2.1914	Accuracy: 35.40%
# 	Elapsed Time: 19.71s
# 	Learning Rate: 0.00020854059925710987
#
# [i] Epoch 19
# 	Loss: 2.1873	Accuracy: 35.80%
# 	Elapsed Time: 19.67s
# 	Learning Rate: 0.00020436978727196768
#
# [i] Epoch 20
# 	Loss: 2.1817	Accuracy: 38.20%
# 	Elapsed Time: 20.33s
# 	Learning Rate: 0.00020028239152652833
#
# [i] Val Loss: 2.1861	 Val Accuracy: 29.00%
# [i] Epoch 1
# 	Loss: 2.3018	Accuracy: 6.60%
# 	Elapsed Time: 20.68s
# 	Learning Rate: 0.000294
#
# [i] Epoch 2
# 	Loss: 2.2942	Accuracy: 14.00%
# 	Elapsed Time: 20.45s
# 	Learning Rate: 0.00028812
#
# [i] Epoch 3
# 	Loss: 2.2878	Accuracy: 14.40%
# 	Elapsed Time: 20.33s
# 	Learning Rate: 0.0002823576
#
# [i] Epoch 4
# 	Loss: 2.2809	Accuracy: 14.00%
# 	Elapsed Time: 20.95s
# 	Learning Rate: 0.000276710448
#
# [i] Epoch 5
# 	Loss: 2.2739	Accuracy: 14.20%
# 	Elapsed Time: 21.75s
# 	Learning Rate: 0.00027117623904
#
# [i] Epoch 6
# 	Loss: 2.2678	Accuracy: 15.20%
# 	Elapsed Time: 20.12s
# 	Learning Rate: 0.00026575271425920003
#
# [i] Epoch 7
# 	Loss: 2.2610	Accuracy: 16.40%
# 	Elapsed Time: 20.46s
# 	Learning Rate: 0.000260437659974016
#
# [i] Epoch 8
# 	Loss: 2.2543	Accuracy: 18.80%
# 	Elapsed Time: 20.63s
# 	Learning Rate: 0.0002552289067745357
#
# [i] Epoch 9
# 	Loss: 2.2476	Accuracy: 21.40%
# 	Elapsed Time: 20.41s
# 	Learning Rate: 0.00025012432863904497
#
# [i] Epoch 10
# 	Loss: 2.2437	Accuracy: 22.60%
# 	Elapsed Time: 20.10s
# 	Learning Rate: 0.00024512184206626405
#
# [i] Epoch 11
# 	Loss: 2.2365	Accuracy: 23.80%
# 	Elapsed Time: 20.23s
# 	Learning Rate: 0.00024021940522493877
#
# [i] Epoch 12
# 	Loss: 2.2293	Accuracy: 25.20%
# 	Elapsed Time: 20.42s
# 	Learning Rate: 0.00023541501712044
#
# [i] Epoch 13
# 	Loss: 2.2236	Accuracy: 27.40%
# 	Elapsed Time: 19.73s
# 	Learning Rate: 0.00023070671677803117
#
# [i] Epoch 14
# 	Loss: 2.2173	Accuracy: 29.20%
# 	Elapsed Time: 19.77s
# 	Learning Rate: 0.00022609258244247053
#
# [i] Epoch 15
# 	Loss: 2.2123	Accuracy: 29.80%
# 	Elapsed Time: 20.16s
# 	Learning Rate: 0.00022157073079362113
#
# [i] Epoch 16
# 	Loss: 2.2034	Accuracy: 31.40%
# 	Elapsed Time: 20.01s
# 	Learning Rate: 0.0002171393161777487
#
# [i] Epoch 17
# 	Loss: 2.1998	Accuracy: 31.60%
# 	Elapsed Time: 20.22s
# 	Learning Rate: 0.00021279652985419374
#
# [i] Epoch 18
# 	Loss: 2.1932	Accuracy: 33.80%
# 	Elapsed Time: 20.00s
# 	Learning Rate: 0.00020854059925710987
#
# [i] Epoch 19
# 	Loss: 2.1883	Accuracy: 34.20%
# 	Elapsed Time: 19.69s
# 	Learning Rate: 0.00020436978727196768
#
# [i] Epoch 20
# 	Loss: 2.1833	Accuracy: 36.80%
# 	Elapsed Time: 20.24s
# 	Learning Rate: 0.00020028239152652833
#
# [i] Val Loss: 2.1724	 Val Accuracy: 32.00%
# [i] Epoch 1
# 	Loss: 2.3036	Accuracy: 7.20%
# 	Elapsed Time: 19.81s
# 	Learning Rate: 0.00028799999999999995
#
# [i] Epoch 2
# 	Loss: 2.2938	Accuracy: 14.60%
# 	Elapsed Time: 19.87s
# 	Learning Rate: 0.00027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.2852	Accuracy: 19.20%
# 	Elapsed Time: 20.33s
# 	Learning Rate: 0.00026542079999999994
#
# [i] Epoch 4
# 	Loss: 2.2769	Accuracy: 16.00%
# 	Elapsed Time: 20.21s
# 	Learning Rate: 0.00025480396799999993
#
# [i] Epoch 5
# 	Loss: 2.2688	Accuracy: 15.60%
# 	Elapsed Time: 20.46s
# 	Learning Rate: 0.00024461180927999994
#
# [i] Epoch 6
# 	Loss: 2.2634	Accuracy: 15.40%
# 	Elapsed Time: 19.76s
# 	Learning Rate: 0.00023482733690879994
#
# [i] Epoch 7
# 	Loss: 2.2589	Accuracy: 15.80%
# 	Elapsed Time: 20.21s
# 	Learning Rate: 0.00022543424343244794
#
# [i] Epoch 8
# 	Loss: 2.2517	Accuracy: 16.40%
# 	Elapsed Time: 19.87s
# 	Learning Rate: 0.00021641687369515
#
# [i] Epoch 9
# 	Loss: 2.2476	Accuracy: 18.20%
# 	Elapsed Time: 19.97s
# 	Learning Rate: 0.000207760198747344
#
# [i] Epoch 10
# 	Loss: 2.2425	Accuracy: 20.20%
# 	Elapsed Time: 19.93s
# 	Learning Rate: 0.00019944979079745024
#
# [i] Epoch 11
# 	Loss: 2.2367	Accuracy: 23.20%
# 	Elapsed Time: 20.11s
# 	Learning Rate: 0.00019147179916555223
#
# [i] Epoch 12
# 	Loss: 2.2307	Accuracy: 24.40%
# 	Elapsed Time: 20.02s
# 	Learning Rate: 0.00018381292719893012
#
# [i] Epoch 13
# 	Loss: 2.2282	Accuracy: 26.00%
# 	Elapsed Time: 20.07s
# 	Learning Rate: 0.0001764604101109729
#
# [i] Epoch 14
# 	Loss: 2.2237	Accuracy: 27.00%
# 	Elapsed Time: 20.38s
# 	Learning Rate: 0.00016940199370653398
#
# [i] Epoch 15
# 	Loss: 2.2195	Accuracy: 27.60%
# 	Elapsed Time: 20.48s
# 	Learning Rate: 0.00016262591395827263
#
# [i] Epoch 16
# 	Loss: 2.2146	Accuracy: 28.60%
# 	Elapsed Time: 19.75s
# 	Learning Rate: 0.00015612087739994173
#
# [i] Epoch 17
# 	Loss: 2.2115	Accuracy: 29.60%
# 	Elapsed Time: 19.82s
# 	Learning Rate: 0.00014987604230394405
#
# [i] Epoch 18
# 	Loss: 2.2070	Accuracy: 30.20%
# 	Elapsed Time: 19.79s
# 	Learning Rate: 0.00014388100061178628
#
# [i] Epoch 19
# 	Loss: 2.2019	Accuracy: 31.00%
# 	Elapsed Time: 20.16s
# 	Learning Rate: 0.00013812576058731482
#
# [i] Epoch 20
# 	Loss: 2.1997	Accuracy: 31.80%
# 	Elapsed Time: 19.85s
# 	Learning Rate: 0.00013260073016382222
#
# [i] Val Loss: 2.1970	 Val Accuracy: 32.00%
# [i] Epoch 1
# 	Loss: 2.3030	Accuracy: 8.80%
# 	Elapsed Time: 19.54s
# 	Learning Rate: 0.00028799999999999995
#
# [i] Epoch 2
# 	Loss: 2.2945	Accuracy: 13.60%
# 	Elapsed Time: 19.80s
# 	Learning Rate: 0.00027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.2869	Accuracy: 20.40%
# 	Elapsed Time: 19.98s
# 	Learning Rate: 0.00026542079999999994
#
# [i] Epoch 4
# 	Loss: 2.2798	Accuracy: 22.00%
# 	Elapsed Time: 20.08s
# 	Learning Rate: 0.00025480396799999993
#
# [i] Epoch 5
# 	Loss: 2.2740	Accuracy: 18.80%
# 	Elapsed Time: 20.23s
# 	Learning Rate: 0.00024461180927999994
#
# [i] Epoch 6
# 	Loss: 2.2670	Accuracy: 17.20%
# 	Elapsed Time: 20.29s
# 	Learning Rate: 0.00023482733690879994
#
# [i] Epoch 7
# 	Loss: 2.2612	Accuracy: 16.60%
# 	Elapsed Time: 20.30s
# 	Learning Rate: 0.00022543424343244794
#
# [i] Epoch 8
# 	Loss: 2.2539	Accuracy: 17.20%
# 	Elapsed Time: 20.41s
# 	Learning Rate: 0.00021641687369515
#
# [i] Epoch 9
# 	Loss: 2.2508	Accuracy: 17.80%
# 	Elapsed Time: 20.22s
# 	Learning Rate: 0.000207760198747344
#
# [i] Epoch 10
# 	Loss: 2.2452	Accuracy: 19.00%
# 	Elapsed Time: 20.20s
# 	Learning Rate: 0.00019944979079745024
#
# [i] Epoch 11
# 	Loss: 2.2412	Accuracy: 20.00%
# 	Elapsed Time: 20.21s
# 	Learning Rate: 0.00019147179916555223
#
# [i] Epoch 12
# 	Loss: 2.2354	Accuracy: 21.80%
# 	Elapsed Time: 20.27s
# 	Learning Rate: 0.00018381292719893012
#
# [i] Epoch 13
# 	Loss: 2.2315	Accuracy: 24.00%
# 	Elapsed Time: 19.90s
# 	Learning Rate: 0.0001764604101109729
#
# [i] Epoch 14
# 	Loss: 2.2258	Accuracy: 25.40%
# 	Elapsed Time: 19.87s
# 	Learning Rate: 0.00016940199370653398
#
# [i] Epoch 15
# 	Loss: 2.2228	Accuracy: 27.00%
# 	Elapsed Time: 20.04s
# 	Learning Rate: 0.00016262591395827263
#
# [i] Epoch 16
# 	Loss: 2.2184	Accuracy: 28.60%
# 	Elapsed Time: 20.41s
# 	Learning Rate: 0.00015612087739994173
#
# [i] Epoch 17
# 	Loss: 2.2151	Accuracy: 30.00%
# 	Elapsed Time: 20.12s
# 	Learning Rate: 0.00014987604230394405
#
# [i] Epoch 18
# 	Loss: 2.2094	Accuracy: 32.80%
# 	Elapsed Time: 20.30s
# 	Learning Rate: 0.00014388100061178628
#
# [i] Epoch 19
# 	Loss: 2.2075	Accuracy: 34.20%
# 	Elapsed Time: 20.86s
# 	Learning Rate: 0.00013812576058731482
#
# [i] Epoch 20
# 	Loss: 2.2030	Accuracy: 35.40%
# 	Elapsed Time: 20.04s
# 	Learning Rate: 0.00013260073016382222
#
# [i] Val Loss: 2.2042	 Val Accuracy: 33.00%
# [i] Epoch 1
# 	Loss: 2.2997	Accuracy: 16.00%
# 	Elapsed Time: 19.62s
# 	Learning Rate: 0.00028799999999999995
#
# [i] Epoch 2
# 	Loss: 2.2893	Accuracy: 19.80%
# 	Elapsed Time: 19.63s
# 	Learning Rate: 0.00027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.2805	Accuracy: 18.80%
# 	Elapsed Time: 20.09s
# 	Learning Rate: 0.00026542079999999994
#
# [i] Epoch 4
# 	Loss: 2.2743	Accuracy: 17.40%
# 	Elapsed Time: 20.42s
# 	Learning Rate: 0.00025480396799999993
#
# [i] Epoch 5
# 	Loss: 2.2695	Accuracy: 16.40%
# 	Elapsed Time: 20.89s
# 	Learning Rate: 0.00024461180927999994
#
# [i] Epoch 6
# 	Loss: 2.2644	Accuracy: 17.00%
# 	Elapsed Time: 21.11s
# 	Learning Rate: 0.00023482733690879994
#
# [i] Epoch 7
# 	Loss: 2.2593	Accuracy: 18.60%
# 	Elapsed Time: 20.30s
# 	Learning Rate: 0.00022543424343244794
#
# [i] Epoch 8
# 	Loss: 2.2549	Accuracy: 19.60%
# 	Elapsed Time: 20.48s
# 	Learning Rate: 0.00021641687369515
#
# [i] Epoch 9
# 	Loss: 2.2488	Accuracy: 20.20%
# 	Elapsed Time: 19.90s
# 	Learning Rate: 0.000207760198747344
#
# [i] Epoch 10
# 	Loss: 2.2456	Accuracy: 20.60%
# 	Elapsed Time: 19.96s
# 	Learning Rate: 0.00019944979079745024
#
# [i] Epoch 11
# 	Loss: 2.2418	Accuracy: 20.60%
# 	Elapsed Time: 19.77s
# 	Learning Rate: 0.00019147179916555223
#
# [i] Epoch 12
# 	Loss: 2.2368	Accuracy: 21.40%
# 	Elapsed Time: 19.83s
# 	Learning Rate: 0.00018381292719893012
#
# [i] Epoch 13
# 	Loss: 2.2332	Accuracy: 23.00%
# 	Elapsed Time: 20.28s
# 	Learning Rate: 0.0001764604101109729
#
# [i] Epoch 14
# 	Loss: 2.2278	Accuracy: 24.40%
# 	Elapsed Time: 19.77s
# 	Learning Rate: 0.00016940199370653398
#
# [i] Epoch 15
# 	Loss: 2.2241	Accuracy: 26.20%
# 	Elapsed Time: 19.95s
# 	Learning Rate: 0.00016262591395827263
#
# [i] Epoch 16
# 	Loss: 2.2180	Accuracy: 27.60%
# 	Elapsed Time: 21.13s
# 	Learning Rate: 0.00015612087739994173
#
# [i] Epoch 17
# 	Loss: 2.2156	Accuracy: 29.40%
# 	Elapsed Time: 21.62s
# 	Learning Rate: 0.00014987604230394405
#
# [i] Epoch 18
# 	Loss: 2.2097	Accuracy: 31.20%
# 	Elapsed Time: 21.20s
# 	Learning Rate: 0.00014388100061178628
#
# [i] Epoch 19
# 	Loss: 2.2060	Accuracy: 31.60%
# 	Elapsed Time: 20.94s
# 	Learning Rate: 0.00013812576058731482
#
# [i] Epoch 20
# 	Loss: 2.2043	Accuracy: 32.40%
# 	Elapsed Time: 19.96s
# 	Learning Rate: 0.00013260073016382222
#
# [i] Val Loss: 2.2079	 Val Accuracy: 26.00%
