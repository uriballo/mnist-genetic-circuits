# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time

import torch.nn as nn

# %%
def decode_to_code(encoded_circuit):
    weight_idx = 0
    for encoded_gate in encoded_circuit:
        wire2  = encoded_gate % 10
        wire1 = (encoded_gate // 10) % 10
        gate = (encoded_gate // 100) % 10

        if gate == 1:
            print(f"qml.RX(weights[{weight_idx}], wires={wire1})")
            weight_idx += 1
        elif gate == 2:
            print(f"qml.RZ(weights[{weight_idx}], wires={wire1})")
            weight_idx += 1
        elif gate == 3:
            print(f"qml.CNOT(wires=[{wire1}, {wire2}])")
        elif gate == 4:
            print(f"qml.Hadamard(wires={wire1})")
            
c = [413, 330, 432]

decode_to_code(c)
# Out:
# qml.Hadamard(wires=1)
# qml.CNOT(wires=[3, 0])
# qml.Hadamard(wires=3)

# %%
n_train    = 500 
n_test     = 100
batch_size = 32

num_qubits = 4
repetitions = 1
n_weights = 3 * repetitions

n_epochs = 20

resized_x = 14
resized_y = resized_x

# %%
dev = qml.device('lightning.qubit', wires=4)

@qml.qnode(dev,interface="torch", diff_method="adjoint")
def circuit(inputs, weights):
    # Encoding of 4 classical input values
    for j in range(num_qubits):
        qml.RY(np.pi * inputs[j], wires=j)

    for i in range (repetitions):
        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[1, 2])
        qml.CNOT(wires=[2, 3])
        
        qml.RZ(weights[0+i], wires=3 -i)
        qml.RX(weights[1 + i], wires=1- i)
        qml.CNOT(wires=[3-i, 2- i])
        qml.CNOT(wires=[1, 0])
        qml.RZ(weights[2+ i], wires=1-i)
        qml.Hadamard(wires=3-i)

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(num_qubits)]

# %%
def load_dataset(n_train, n_test, batch_size):
    """
    Loads train & test sets from MNIST with user-specified sizes.

    Args:
        n_train (int): Desired number of samples in the training set.
        n_test (int): Desired number of samples in the testing set.
        batch_size (int): Batch size for the DataLoaders.

    Returns:
        tuple: (train_loader, test_loader) where each loader is a
               torch.utils.data.DataLoader.
    """
    # Define transformations for the dataset
    transform = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.5,), (0.5,)),
                                    transforms.Lambda(lambda img: F.interpolate(img.unsqueeze(0), size=(resized_x, resized_y), 
                                        mode='bilinear', align_corners=False).squeeze(0))])

    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    # Subset the datasets to the desired number of samples
    train_subset = torch.utils.data.Subset(train_dataset, range(n_train))
    test_subset = torch.utils.data.Subset(test_dataset, range(n_test))

    # Create DataLoaders for training and testing sets
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, pin_memory=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, pin_memory=True)

    print("Number of training samples:", len(train_subset))
    print("Number of test samples:", len(test_subset))

    return train_loader, test_loader

# %%
qlayer = qml.qnn.TorchLayer(circuit, {"weights": (n_weights,)})
fig, ax = qml.draw_mpl(circuit)([1.0,4,54,44], [1,2,3,4,5,123,2,23,1,1,1,1,1,1])
fig.show()
# Out:
# /var/folders/pc/01wnjzvx01n_gqvkhmw2_9nr0000gn/T/ipykernel_13549/3623739010.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def extract_image_patches(x):
    # Do TF 'SAME' Padding
    B, C, H, W = x.shape  
    #x = torch.arange(B*C*H*W).view(B, C, H, W)
    kernel_h, kernel_w = 2, 2
    stride = 2

    patches = x.unfold(2, kernel_h, stride).unfold(3, kernel_w, stride)
      
    patches = patches.contiguous().view(B, H // stride, W // stride, -1)

    return patches.reshape(-1, 4)

# %%
dim = resized_x // 2
class HQNN(nn.Module):
    def __init__(self):
        super(HQNN, self).__init__()

        # Quanvolutional layer (Maps 1 input channel to 4 output channels)
        self.quanv = qlayer

        # Fully connected layer to perform the final classification
        self.fc1 = nn.Linear(dim * dim * 4, 10)  # Assuming 10 output classes

    def forward(self, input):
        patches = extract_image_patches(input)  

        quanvoluted_patches = torch.stack([self.quanv(patch) for patch in patches])
        x = quanvoluted_patches.reshape(input.shape[0], dim, dim, 4)

        x = x.view(-1, dim * dim * 4)  # Flatten for the fully connected layer
        x = self.fc1(x)
        x = F.softmax(x, dim=1)  # Apply softmax
        return x

# %%
loss_fn = F.cross_entropy
train_loader, test_loader = load_dataset(n_train, n_test, batch_size)
# Out:
# Number of training samples: 500
# Number of test samples: 100

# %%
def append_data_to_markdown_table(file_path, circuit, lr, gamma, batch_size, val_loss, val_acc):
    """
    Appends variables to an existing Markdown table in a file, formatting floats to 3 decimal places.

    Args:
        file_path (str): The path to the Markdown file.
        lr (float): The learning rate value.
        gamma (float): The gamma value.
        batch_size (int): The batch size value.
        val_loss (float): The validation loss value.
        val_acc (float): The validation accuracy value.
    """

    with open(file_path, 'a') as f:  # Open the file in append mode
        row = f"| {circuit} | {lr} | {gamma:.2f} | {batch_size} | {val_loss:.3f} | {val_acc:.2f} |\n"
        f.write(row)  # Write the new row of data
        
lr_values    = [0.01, 0.01, 0.007, 0.007, 0.005, 0.005, 0.003, 0.003]
gamma_values = [0.98, 0.96, 0.96, 0.98, 0.98, 0.96, 0.98, 0.96] 

for lr, gamma in zip(lr_values, gamma_values):
    for _ in range(3):
        model = HQNN() 
        optimizer = torch.optim.Adam(model.parameters(), lr = lr)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma) 
        for epoch in range(n_epochs):
            # ---- Training Phase ----
            running_loss = 0.0 
            correct = 0  
            total = 0
            train_losses = []
            test_losses = []
            start_time = time.time()
            for i, (images, labels) in enumerate(train_loader):
                # --- 2. Forward Pass ---
                outputs = model(images)

                # --- 3. Loss Calculation ---
                loss = loss_fn(outputs, labels)
                train_losses.append(loss.item())
                # --- 4. Backpropagation and Optimization ---
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()  
                train_losses.append(loss.item())  # Store loss for each batch

                # Accuracy calculation for the epoch
                _, predicted = torch.max(outputs.data, 1) 
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            scheduler.step() 

            # Print statistics for the epoch
            epoch_loss = sum(train_losses) / len(train_losses)  
            epoch_acc = 100 * correct / total 

            current_lr = scheduler.get_last_lr()[0]  

            # Periodic Evaluation and Logging
            print(f'[i] Epoch {epoch + 1}\n\tLoss: {epoch_loss:.4f}\tAccuracy: {epoch_acc :.2f}%\n\tElapsed Time: {time.time() - start_time:.2f}s')
            print(f'\tLearning Rate: {current_lr}\n')

        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():  # Disable gradients for evaluation
            val_correct = 0
            val_total = 0

            for images, labels in test_loader:
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                test_losses.append(loss.item())

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = sum(test_losses) / len(test_losses)
        val_acc = 100 * val_correct / val_total 

        print(f'[i] Val Loss: {val_loss:.4f}\t Val Accuracy: {val_acc :.2f}%')
        append_data_to_markdown_table("results500.md", "circ5_SE", lr, gamma, batch_size, val_loss, val_acc)
# Out:
# [i] Epoch 1
# 	Loss: 2.2452	Accuracy: 22.00%
# 	Elapsed Time: 20.71s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.1143	Accuracy: 40.00%
# 	Elapsed Time: 20.69s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.0366	Accuracy: 45.40%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 1.9717	Accuracy: 53.60%
# 	Elapsed Time: 21.39s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.9328	Accuracy: 55.80%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.9091	Accuracy: 58.40%
# 	Elapsed Time: 20.66s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.8955	Accuracy: 59.20%
# 	Elapsed Time: 20.98s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.8842	Accuracy: 59.80%
# 	Elapsed Time: 21.15s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8631	Accuracy: 63.40%
# 	Elapsed Time: 20.83s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8370	Accuracy: 66.40%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8231	Accuracy: 67.20%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8109	Accuracy: 68.20%
# 	Elapsed Time: 20.86s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.8015	Accuracy: 68.60%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.7982	Accuracy: 69.80%
# 	Elapsed Time: 21.38s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.7898	Accuracy: 69.60%
# 	Elapsed Time: 21.12s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.7845	Accuracy: 69.80%
# 	Elapsed Time: 21.43s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.7802	Accuracy: 70.20%
# 	Elapsed Time: 21.77s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.7815	Accuracy: 70.40%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.7709	Accuracy: 72.00%
# 	Elapsed Time: 22.38s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.7404	Accuracy: 75.80%
# 	Elapsed Time: 22.41s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 1.9861	 Val Accuracy: 54.00%
# [i] Epoch 1
# 	Loss: 2.2773	Accuracy: 17.20%
# 	Elapsed Time: 22.25s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.1554	Accuracy: 36.40%
# 	Elapsed Time: 22.31s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.0542	Accuracy: 46.40%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 2.0026	Accuracy: 51.00%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.9714	Accuracy: 52.80%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.9489	Accuracy: 55.40%
# 	Elapsed Time: 22.92s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.9212	Accuracy: 57.60%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.9046	Accuracy: 58.20%
# 	Elapsed Time: 22.96s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8780	Accuracy: 62.20%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8407	Accuracy: 66.00%
# 	Elapsed Time: 22.85s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8177	Accuracy: 67.80%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8075	Accuracy: 68.80%
# 	Elapsed Time: 22.67s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.7617	Accuracy: 75.40%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.7153	Accuracy: 79.20%
# 	Elapsed Time: 22.88s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.7065	Accuracy: 80.80%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.6845	Accuracy: 81.80%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.6775	Accuracy: 82.20%
# 	Elapsed Time: 22.66s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.6700	Accuracy: 82.80%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.6720	Accuracy: 83.00%
# 	Elapsed Time: 22.61s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.6649	Accuracy: 83.00%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 1.9046	 Val Accuracy: 56.00%
# [i] Epoch 1
# 	Loss: 2.2468	Accuracy: 21.60%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.0580	Accuracy: 50.60%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 1.9708	Accuracy: 56.20%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 1.9008	Accuracy: 63.80%
# 	Elapsed Time: 23.15s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.8413	Accuracy: 68.20%
# 	Elapsed Time: 24.06s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.8041	Accuracy: 71.00%
# 	Elapsed Time: 22.81s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.7765	Accuracy: 74.80%
# 	Elapsed Time: 23.11s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.7618	Accuracy: 74.40%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.7524	Accuracy: 74.80%
# 	Elapsed Time: 23.78s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.7432	Accuracy: 76.60%
# 	Elapsed Time: 23.92s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.7277	Accuracy: 77.20%
# 	Elapsed Time: 23.86s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.7214	Accuracy: 78.00%
# 	Elapsed Time: 23.99s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.7112	Accuracy: 77.80%
# 	Elapsed Time: 24.34s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.7089	Accuracy: 78.20%
# 	Elapsed Time: 23.79s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.7063	Accuracy: 78.40%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.7048	Accuracy: 78.80%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.6963	Accuracy: 79.20%
# 	Elapsed Time: 23.81s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.6935	Accuracy: 79.60%
# 	Elapsed Time: 25.61s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.6886	Accuracy: 79.40%
# 	Elapsed Time: 29.08s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.6793	Accuracy: 80.80%
# 	Elapsed Time: 28.50s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 1.9471	 Val Accuracy: 59.00%
# [i] Epoch 1
# 	Loss: 2.2378	Accuracy: 22.80%
# 	Elapsed Time: 25.74s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.0980	Accuracy: 39.60%
# 	Elapsed Time: 24.81s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 1.9923	Accuracy: 54.00%
# 	Elapsed Time: 24.91s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 1.9243	Accuracy: 59.00%
# 	Elapsed Time: 23.67s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 1.8795	Accuracy: 64.00%
# 	Elapsed Time: 23.64s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.8588	Accuracy: 64.80%
# 	Elapsed Time: 23.98s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.8373	Accuracy: 66.40%
# 	Elapsed Time: 23.33s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.8252	Accuracy: 67.60%
# 	Elapsed Time: 23.78s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8121	Accuracy: 68.20%
# 	Elapsed Time: 23.18s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8128	Accuracy: 68.00%
# 	Elapsed Time: 23.07s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.7966	Accuracy: 69.40%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.7948	Accuracy: 69.60%
# 	Elapsed Time: 23.42s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.7972	Accuracy: 70.40%
# 	Elapsed Time: 23.11s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.7859	Accuracy: 70.60%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.7858	Accuracy: 70.40%
# 	Elapsed Time: 23.18s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.7819	Accuracy: 71.00%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.7771	Accuracy: 71.00%
# 	Elapsed Time: 22.93s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.7737	Accuracy: 70.80%
# 	Elapsed Time: 23.18s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.7751	Accuracy: 71.00%
# 	Elapsed Time: 23.40s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.7733	Accuracy: 71.20%
# 	Elapsed Time: 23.30s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 1.8968	 Val Accuracy: 55.00%
# [i] Epoch 1
# 	Loss: 2.2582	Accuracy: 20.20%
# 	Elapsed Time: 22.52s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.1583	Accuracy: 33.60%
# 	Elapsed Time: 23.00s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.0476	Accuracy: 49.20%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 1.9659	Accuracy: 55.00%
# 	Elapsed Time: 23.26s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 1.9171	Accuracy: 61.60%
# 	Elapsed Time: 22.96s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.8902	Accuracy: 61.20%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.8670	Accuracy: 63.00%
# 	Elapsed Time: 23.14s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.8607	Accuracy: 64.20%
# 	Elapsed Time: 23.15s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8473	Accuracy: 65.80%
# 	Elapsed Time: 22.77s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8416	Accuracy: 65.40%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.8323	Accuracy: 66.40%
# 	Elapsed Time: 22.74s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.8244	Accuracy: 66.80%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.8200	Accuracy: 67.40%
# 	Elapsed Time: 22.81s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.8207	Accuracy: 67.40%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.8123	Accuracy: 67.20%
# 	Elapsed Time: 22.69s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.8092	Accuracy: 67.40%
# 	Elapsed Time: 22.74s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.8045	Accuracy: 67.80%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.8057	Accuracy: 67.80%
# 	Elapsed Time: 23.19s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.8018	Accuracy: 67.80%
# 	Elapsed Time: 23.31s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.8009	Accuracy: 68.00%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 1.9000	 Val Accuracy: 56.00%
# [i] Epoch 1
# 	Loss: 2.2367	Accuracy: 23.60%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.1006	Accuracy: 40.80%
# 	Elapsed Time: 22.95s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.0434	Accuracy: 45.40%
# 	Elapsed Time: 23.36s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 2.0088	Accuracy: 48.00%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 1.9866	Accuracy: 50.40%
# 	Elapsed Time: 22.93s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9660	Accuracy: 52.60%
# 	Elapsed Time: 23.16s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.8955	Accuracy: 62.20%
# 	Elapsed Time: 22.95s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.8385	Accuracy: 68.80%
# 	Elapsed Time: 23.02s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8090	Accuracy: 71.20%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.7844	Accuracy: 73.40%
# 	Elapsed Time: 23.20s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.7754	Accuracy: 74.20%
# 	Elapsed Time: 23.15s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.7621	Accuracy: 75.40%
# 	Elapsed Time: 23.71s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.7513	Accuracy: 75.80%
# 	Elapsed Time: 23.40s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.7449	Accuracy: 76.40%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.7423	Accuracy: 76.40%
# 	Elapsed Time: 23.03s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.7371	Accuracy: 76.00%
# 	Elapsed Time: 23.77s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.7392	Accuracy: 76.40%
# 	Elapsed Time: 23.85s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.7273	Accuracy: 76.80%
# 	Elapsed Time: 23.14s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.7247	Accuracy: 77.60%
# 	Elapsed Time: 23.36s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.7235	Accuracy: 77.60%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 1.9492	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2808	Accuracy: 14.80%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.1452	Accuracy: 44.00%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 2.0165	Accuracy: 59.60%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 1.8956	Accuracy: 70.40%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 1.8276	Accuracy: 76.80%
# 	Elapsed Time: 23.56s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 1.7779	Accuracy: 81.20%
# 	Elapsed Time: 23.15s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 1.7467	Accuracy: 82.80%
# 	Elapsed Time: 23.13s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.7163	Accuracy: 85.40%
# 	Elapsed Time: 23.13s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.7052	Accuracy: 85.00%
# 	Elapsed Time: 23.09s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.6828	Accuracy: 87.20%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.6721	Accuracy: 87.60%
# 	Elapsed Time: 23.25s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.6573	Accuracy: 88.00%
# 	Elapsed Time: 22.96s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.6549	Accuracy: 88.40%
# 	Elapsed Time: 23.09s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.6432	Accuracy: 88.80%
# 	Elapsed Time: 23.13s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.6378	Accuracy: 88.80%
# 	Elapsed Time: 23.13s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.6309	Accuracy: 89.80%
# 	Elapsed Time: 24.03s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.6274	Accuracy: 89.60%
# 	Elapsed Time: 24.17s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.6239	Accuracy: 89.40%
# 	Elapsed Time: 23.03s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.6193	Accuracy: 89.60%
# 	Elapsed Time: 23.43s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.6168	Accuracy: 91.00%
# 	Elapsed Time: 23.18s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 1.8846	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2572	Accuracy: 20.60%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.1323	Accuracy: 38.40%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 2.0407	Accuracy: 50.60%
# 	Elapsed Time: 22.88s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 1.9790	Accuracy: 54.40%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 1.9332	Accuracy: 60.20%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 1.9118	Accuracy: 60.00%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 1.8779	Accuracy: 65.00%
# 	Elapsed Time: 23.32s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.8483	Accuracy: 66.60%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.8297	Accuracy: 68.60%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.7816	Accuracy: 77.40%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.7586	Accuracy: 79.00%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.7414	Accuracy: 79.80%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.7234	Accuracy: 80.80%
# 	Elapsed Time: 22.77s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.7121	Accuracy: 82.40%
# 	Elapsed Time: 22.93s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.7034	Accuracy: 82.20%
# 	Elapsed Time: 22.68s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.7000	Accuracy: 82.40%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.6940	Accuracy: 82.20%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.6883	Accuracy: 83.60%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.6796	Accuracy: 84.00%
# 	Elapsed Time: 23.46s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.6723	Accuracy: 84.00%
# 	Elapsed Time: 23.19s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 1.8774	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2664	Accuracy: 15.20%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.1405	Accuracy: 40.80%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 2.0108	Accuracy: 58.20%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 1.9090	Accuracy: 71.00%
# 	Elapsed Time: 22.80s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 1.8423	Accuracy: 74.60%
# 	Elapsed Time: 23.43s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 1.7743	Accuracy: 81.00%
# 	Elapsed Time: 23.24s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 1.7367	Accuracy: 82.80%
# 	Elapsed Time: 23.70s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.7161	Accuracy: 84.80%
# 	Elapsed Time: 23.61s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.6944	Accuracy: 85.20%
# 	Elapsed Time: 23.52s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.6833	Accuracy: 86.40%
# 	Elapsed Time: 25.56s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.6680	Accuracy: 86.60%
# 	Elapsed Time: 27.30s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.6613	Accuracy: 87.80%
# 	Elapsed Time: 26.93s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.6504	Accuracy: 88.40%
# 	Elapsed Time: 23.71s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.6450	Accuracy: 88.20%
# 	Elapsed Time: 23.17s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.6360	Accuracy: 88.80%
# 	Elapsed Time: 23.07s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.6293	Accuracy: 89.00%
# 	Elapsed Time: 23.14s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.6265	Accuracy: 89.80%
# 	Elapsed Time: 23.26s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.6212	Accuracy: 90.40%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.6169	Accuracy: 90.60%
# 	Elapsed Time: 23.61s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.6142	Accuracy: 90.40%
# 	Elapsed Time: 23.76s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 1.8971	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2613	Accuracy: 20.00%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.1177	Accuracy: 43.60%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 1.9901	Accuracy: 61.20%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 1.8947	Accuracy: 71.40%
# 	Elapsed Time: 22.86s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 1.8343	Accuracy: 73.80%
# 	Elapsed Time: 22.94s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 1.7923	Accuracy: 76.20%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.7635	Accuracy: 77.60%
# 	Elapsed Time: 22.76s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.7498	Accuracy: 79.00%
# 	Elapsed Time: 23.05s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.7325	Accuracy: 80.80%
# 	Elapsed Time: 23.46s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.7143	Accuracy: 82.20%
# 	Elapsed Time: 23.26s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.7096	Accuracy: 82.00%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.6953	Accuracy: 82.20%
# 	Elapsed Time: 23.20s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.6896	Accuracy: 83.20%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.6829	Accuracy: 84.20%
# 	Elapsed Time: 22.86s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.6721	Accuracy: 83.60%
# 	Elapsed Time: 22.88s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.6653	Accuracy: 84.80%
# 	Elapsed Time: 23.26s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.6639	Accuracy: 84.60%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.6570	Accuracy: 86.00%
# 	Elapsed Time: 23.08s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.6499	Accuracy: 85.80%
# 	Elapsed Time: 23.18s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.6449	Accuracy: 87.20%
# 	Elapsed Time: 22.86s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 1.8965	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2701	Accuracy: 16.80%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.1493	Accuracy: 37.40%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.0266	Accuracy: 53.20%
# 	Elapsed Time: 23.40s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 1.9336	Accuracy: 63.00%
# 	Elapsed Time: 23.44s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 1.8762	Accuracy: 68.80%
# 	Elapsed Time: 23.74s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 1.8366	Accuracy: 71.80%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.8103	Accuracy: 72.60%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.7883	Accuracy: 74.80%
# 	Elapsed Time: 22.96s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.7692	Accuracy: 75.80%
# 	Elapsed Time: 23.62s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.7619	Accuracy: 76.00%
# 	Elapsed Time: 24.33s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.7498	Accuracy: 76.80%
# 	Elapsed Time: 23.81s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.7443	Accuracy: 76.60%
# 	Elapsed Time: 23.88s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.7388	Accuracy: 76.40%
# 	Elapsed Time: 23.88s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.7336	Accuracy: 77.20%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.7284	Accuracy: 77.00%
# 	Elapsed Time: 23.56s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.7187	Accuracy: 77.40%
# 	Elapsed Time: 23.64s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.7155	Accuracy: 78.00%
# 	Elapsed Time: 23.58s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.7166	Accuracy: 78.40%
# 	Elapsed Time: 23.70s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.7162	Accuracy: 78.60%
# 	Elapsed Time: 23.89s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.7115	Accuracy: 78.80%
# 	Elapsed Time: 23.11s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 1.8842	 Val Accuracy: 59.00%
# [i] Epoch 1
# 	Loss: 2.2668	Accuracy: 20.20%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.1736	Accuracy: 32.60%
# 	Elapsed Time: 22.52s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.1139	Accuracy: 39.80%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 2.0707	Accuracy: 44.60%
# 	Elapsed Time: 22.66s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 1.9938	Accuracy: 55.80%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 1.9323	Accuracy: 60.60%
# 	Elapsed Time: 22.61s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.8959	Accuracy: 63.20%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.8785	Accuracy: 65.60%
# 	Elapsed Time: 22.62s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.8545	Accuracy: 67.80%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.8295	Accuracy: 69.80%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.8102	Accuracy: 71.80%
# 	Elapsed Time: 23.07s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.7977	Accuracy: 73.00%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.7879	Accuracy: 72.60%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.7787	Accuracy: 73.60%
# 	Elapsed Time: 22.76s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.7748	Accuracy: 73.60%
# 	Elapsed Time: 22.32s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.7724	Accuracy: 74.00%
# 	Elapsed Time: 22.36s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.7611	Accuracy: 74.80%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.7537	Accuracy: 74.80%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.7555	Accuracy: 75.00%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.7449	Accuracy: 76.00%
# 	Elapsed Time: 22.95s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 1.9684	 Val Accuracy: 57.00%
# [i] Epoch 1
# 	Loss: 2.2690	Accuracy: 18.00%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1596	Accuracy: 39.20%
# 	Elapsed Time: 22.74s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.0517	Accuracy: 54.40%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 1.9623	Accuracy: 66.00%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.9038	Accuracy: 69.00%
# 	Elapsed Time: 23.06s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.8551	Accuracy: 72.80%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8238	Accuracy: 76.00%
# 	Elapsed Time: 23.29s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.7866	Accuracy: 80.40%
# 	Elapsed Time: 22.93s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.7466	Accuracy: 83.80%
# 	Elapsed Time: 23.45s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.7253	Accuracy: 85.20%
# 	Elapsed Time: 22.94s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.7102	Accuracy: 86.40%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.6932	Accuracy: 86.60%
# 	Elapsed Time: 23.16s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.6855	Accuracy: 87.00%
# 	Elapsed Time: 23.09s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.6733	Accuracy: 87.60%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.6647	Accuracy: 88.40%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.6555	Accuracy: 87.80%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.6471	Accuracy: 88.40%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.6443	Accuracy: 89.20%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.6383	Accuracy: 88.60%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.6329	Accuracy: 89.20%
# 	Elapsed Time: 23.23s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.9064	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2664	Accuracy: 18.40%
# 	Elapsed Time: 23.54s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1567	Accuracy: 41.80%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.0661	Accuracy: 53.20%
# 	Elapsed Time: 23.31s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 1.9852	Accuracy: 62.60%
# 	Elapsed Time: 23.44s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.9218	Accuracy: 68.60%
# 	Elapsed Time: 23.50s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.8775	Accuracy: 68.40%
# 	Elapsed Time: 23.74s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8325	Accuracy: 73.80%
# 	Elapsed Time: 23.69s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.7994	Accuracy: 76.20%
# 	Elapsed Time: 23.55s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.7832	Accuracy: 77.00%
# 	Elapsed Time: 23.52s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.7605	Accuracy: 79.00%
# 	Elapsed Time: 23.54s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.7444	Accuracy: 79.80%
# 	Elapsed Time: 23.59s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.7324	Accuracy: 80.80%
# 	Elapsed Time: 23.48s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.7149	Accuracy: 83.40%
# 	Elapsed Time: 23.36s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.7048	Accuracy: 84.40%
# 	Elapsed Time: 23.54s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.6805	Accuracy: 86.60%
# 	Elapsed Time: 23.78s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.6686	Accuracy: 87.60%
# 	Elapsed Time: 23.68s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.6630	Accuracy: 88.40%
# 	Elapsed Time: 24.84s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.6540	Accuracy: 88.40%
# 	Elapsed Time: 24.72s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.6458	Accuracy: 89.00%
# 	Elapsed Time: 24.20s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.6384	Accuracy: 89.20%
# 	Elapsed Time: 25.41s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.9135	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2652	Accuracy: 17.80%
# 	Elapsed Time: 24.04s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1644	Accuracy: 37.40%
# 	Elapsed Time: 23.80s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.0853	Accuracy: 47.80%
# 	Elapsed Time: 23.46s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 2.0179	Accuracy: 56.20%
# 	Elapsed Time: 23.12s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.9623	Accuracy: 61.00%
# 	Elapsed Time: 23.04s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.9205	Accuracy: 63.60%
# 	Elapsed Time: 23.52s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8968	Accuracy: 64.80%
# 	Elapsed Time: 23.38s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.8784	Accuracy: 66.00%
# 	Elapsed Time: 22.77s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.8652	Accuracy: 65.80%
# 	Elapsed Time: 22.67s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.8632	Accuracy: 65.60%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.8469	Accuracy: 66.80%
# 	Elapsed Time: 22.83s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.8378	Accuracy: 68.40%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.8319	Accuracy: 69.60%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.8229	Accuracy: 69.00%
# 	Elapsed Time: 21.81s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.7964	Accuracy: 74.00%
# 	Elapsed Time: 21.74s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.7665	Accuracy: 76.20%
# 	Elapsed Time: 21.99s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.7530	Accuracy: 77.20%
# 	Elapsed Time: 22.23s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.7437	Accuracy: 77.80%
# 	Elapsed Time: 21.70s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.7369	Accuracy: 77.80%
# 	Elapsed Time: 22.20s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.7329	Accuracy: 78.20%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.8979	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2686	Accuracy: 17.40%
# 	Elapsed Time: 21.55s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.1478	Accuracy: 45.00%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.0530	Accuracy: 52.80%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 1.9876	Accuracy: 59.40%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.9382	Accuracy: 65.20%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.8995	Accuracy: 67.60%
# 	Elapsed Time: 21.92s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.8547	Accuracy: 71.40%
# 	Elapsed Time: 21.71s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.8327	Accuracy: 73.40%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.8053	Accuracy: 75.80%
# 	Elapsed Time: 21.60s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.7955	Accuracy: 75.80%
# 	Elapsed Time: 21.83s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.7767	Accuracy: 78.20%
# 	Elapsed Time: 22.09s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.7661	Accuracy: 78.60%
# 	Elapsed Time: 22.15s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.7564	Accuracy: 79.20%
# 	Elapsed Time: 21.95s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7520	Accuracy: 79.80%
# 	Elapsed Time: 22.05s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.7200	Accuracy: 85.60%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.6989	Accuracy: 86.40%
# 	Elapsed Time: 21.89s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.6891	Accuracy: 87.00%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.6770	Accuracy: 87.20%
# 	Elapsed Time: 21.92s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.6707	Accuracy: 87.80%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.6637	Accuracy: 88.20%
# 	Elapsed Time: 21.71s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 1.8967	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2953	Accuracy: 11.80%
# 	Elapsed Time: 21.14s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.2038	Accuracy: 30.80%
# 	Elapsed Time: 21.39s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.0721	Accuracy: 53.20%
# 	Elapsed Time: 21.41s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 1.9937	Accuracy: 63.00%
# 	Elapsed Time: 21.57s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.9196	Accuracy: 68.60%
# 	Elapsed Time: 21.66s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.8731	Accuracy: 73.40%
# 	Elapsed Time: 21.67s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.8447	Accuracy: 73.60%
# 	Elapsed Time: 21.84s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.8210	Accuracy: 74.60%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.8013	Accuracy: 76.00%
# 	Elapsed Time: 21.65s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.7856	Accuracy: 77.00%
# 	Elapsed Time: 21.59s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.7767	Accuracy: 76.80%
# 	Elapsed Time: 21.98s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.7659	Accuracy: 78.00%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.7568	Accuracy: 78.40%
# 	Elapsed Time: 22.12s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7499	Accuracy: 78.20%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.7444	Accuracy: 78.80%
# 	Elapsed Time: 21.81s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.7346	Accuracy: 79.00%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.7322	Accuracy: 79.40%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.7293	Accuracy: 79.80%
# 	Elapsed Time: 21.54s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.7257	Accuracy: 80.00%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.7232	Accuracy: 79.80%
# 	Elapsed Time: 21.40s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 1.9639	 Val Accuracy: 57.00%
# [i] Epoch 1
# 	Loss: 2.2677	Accuracy: 16.20%
# 	Elapsed Time: 21.06s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.1633	Accuracy: 38.00%
# 	Elapsed Time: 21.46s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.0696	Accuracy: 55.60%
# 	Elapsed Time: 21.72s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 1.9823	Accuracy: 64.60%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.9216	Accuracy: 66.60%
# 	Elapsed Time: 21.52s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.8821	Accuracy: 69.20%
# 	Elapsed Time: 22.07s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.8508	Accuracy: 70.00%
# 	Elapsed Time: 21.53s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.8309	Accuracy: 72.00%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.8169	Accuracy: 72.80%
# 	Elapsed Time: 21.47s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.8013	Accuracy: 73.60%
# 	Elapsed Time: 21.91s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.7952	Accuracy: 74.40%
# 	Elapsed Time: 21.82s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.7843	Accuracy: 74.80%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.7769	Accuracy: 75.00%
# 	Elapsed Time: 21.52s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7722	Accuracy: 75.60%
# 	Elapsed Time: 21.78s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.7650	Accuracy: 75.20%
# 	Elapsed Time: 22.07s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.7578	Accuracy: 76.40%
# 	Elapsed Time: 21.86s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.7522	Accuracy: 75.80%
# 	Elapsed Time: 21.67s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.7491	Accuracy: 76.20%
# 	Elapsed Time: 22.02s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.7454	Accuracy: 77.00%
# 	Elapsed Time: 21.64s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.7429	Accuracy: 76.80%
# 	Elapsed Time: 21.66s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 1.8969	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2734	Accuracy: 19.40%
# 	Elapsed Time: 20.89s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2073	Accuracy: 27.40%
# 	Elapsed Time: 21.59s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.1393	Accuracy: 40.80%
# 	Elapsed Time: 21.61s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.0770	Accuracy: 57.40%
# 	Elapsed Time: 21.85s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.0166	Accuracy: 58.40%
# 	Elapsed Time: 21.94s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 1.9659	Accuracy: 65.00%
# 	Elapsed Time: 21.70s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.9181	Accuracy: 72.20%
# 	Elapsed Time: 22.04s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.8817	Accuracy: 70.40%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.8527	Accuracy: 74.40%
# 	Elapsed Time: 21.84s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8315	Accuracy: 75.20%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.8136	Accuracy: 77.80%
# 	Elapsed Time: 21.81s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.7964	Accuracy: 77.80%
# 	Elapsed Time: 21.36s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.7859	Accuracy: 78.80%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.7752	Accuracy: 80.20%
# 	Elapsed Time: 21.48s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.7628	Accuracy: 80.00%
# 	Elapsed Time: 21.44s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.7495	Accuracy: 82.80%
# 	Elapsed Time: 21.44s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.7321	Accuracy: 84.80%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.7220	Accuracy: 85.40%
# 	Elapsed Time: 22.35s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.7160	Accuracy: 84.60%
# 	Elapsed Time: 23.35s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.7046	Accuracy: 86.60%
# 	Elapsed Time: 21.69s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.9326	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2819	Accuracy: 13.40%
# 	Elapsed Time: 21.22s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2088	Accuracy: 33.80%
# 	Elapsed Time: 21.95s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.1428	Accuracy: 42.00%
# 	Elapsed Time: 21.87s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.0730	Accuracy: 59.00%
# 	Elapsed Time: 21.58s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.0094	Accuracy: 63.60%
# 	Elapsed Time: 21.69s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 1.9625	Accuracy: 67.20%
# 	Elapsed Time: 21.73s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.9257	Accuracy: 69.20%
# 	Elapsed Time: 21.85s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.8936	Accuracy: 70.60%
# 	Elapsed Time: 21.91s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.8743	Accuracy: 71.40%
# 	Elapsed Time: 21.75s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8579	Accuracy: 69.80%
# 	Elapsed Time: 21.65s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.8420	Accuracy: 71.40%
# 	Elapsed Time: 21.94s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.8304	Accuracy: 72.20%
# 	Elapsed Time: 21.96s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.8230	Accuracy: 72.20%
# 	Elapsed Time: 21.65s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.8120	Accuracy: 74.20%
# 	Elapsed Time: 21.60s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.8042	Accuracy: 73.80%
# 	Elapsed Time: 21.53s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.8014	Accuracy: 74.40%
# 	Elapsed Time: 21.43s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.7901	Accuracy: 75.20%
# 	Elapsed Time: 21.29s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.7850	Accuracy: 75.60%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.7800	Accuracy: 75.60%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.7736	Accuracy: 76.20%
# 	Elapsed Time: 21.76s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.9186	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2772	Accuracy: 14.20%
# 	Elapsed Time: 21.34s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2178	Accuracy: 23.60%
# 	Elapsed Time: 21.70s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.1513	Accuracy: 46.40%
# 	Elapsed Time: 21.67s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.0853	Accuracy: 52.80%
# 	Elapsed Time: 21.52s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.0268	Accuracy: 62.60%
# 	Elapsed Time: 21.69s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 1.9740	Accuracy: 67.00%
# 	Elapsed Time: 21.64s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.9331	Accuracy: 70.20%
# 	Elapsed Time: 21.94s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.8984	Accuracy: 72.60%
# 	Elapsed Time: 21.52s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.8668	Accuracy: 75.00%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8346	Accuracy: 77.60%
# 	Elapsed Time: 21.81s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.8165	Accuracy: 78.20%
# 	Elapsed Time: 21.92s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.7989	Accuracy: 79.00%
# 	Elapsed Time: 21.39s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.7908	Accuracy: 79.40%
# 	Elapsed Time: 21.62s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.7753	Accuracy: 79.80%
# 	Elapsed Time: 21.69s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.7662	Accuracy: 80.40%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.7550	Accuracy: 81.00%
# 	Elapsed Time: 22.05s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.7522	Accuracy: 81.00%
# 	Elapsed Time: 21.89s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.7416	Accuracy: 81.80%
# 	Elapsed Time: 21.82s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.7318	Accuracy: 82.40%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.7281	Accuracy: 82.80%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.9179	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2891	Accuracy: 13.20%
# 	Elapsed Time: 21.36s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2203	Accuracy: 27.00%
# 	Elapsed Time: 21.73s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.1526	Accuracy: 41.20%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.0937	Accuracy: 51.20%
# 	Elapsed Time: 21.54s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.0324	Accuracy: 63.00%
# 	Elapsed Time: 21.95s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 1.9750	Accuracy: 73.60%
# 	Elapsed Time: 21.92s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.9145	Accuracy: 75.20%
# 	Elapsed Time: 21.72s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.8809	Accuracy: 77.20%
# 	Elapsed Time: 22.09s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.8483	Accuracy: 77.40%
# 	Elapsed Time: 21.58s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.8228	Accuracy: 80.60%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.8081	Accuracy: 79.60%
# 	Elapsed Time: 21.90s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.7867	Accuracy: 80.80%
# 	Elapsed Time: 21.60s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.7763	Accuracy: 82.60%
# 	Elapsed Time: 21.45s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.7623	Accuracy: 83.00%
# 	Elapsed Time: 21.56s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.7521	Accuracy: 83.40%
# 	Elapsed Time: 21.70s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.7457	Accuracy: 83.80%
# 	Elapsed Time: 21.79s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.7364	Accuracy: 84.60%
# 	Elapsed Time: 21.98s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.7338	Accuracy: 84.40%
# 	Elapsed Time: 21.98s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.7268	Accuracy: 85.40%
# 	Elapsed Time: 21.63s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.7143	Accuracy: 86.60%
# 	Elapsed Time: 22.12s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.9358	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2785	Accuracy: 13.60%
# 	Elapsed Time: 21.17s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2071	Accuracy: 31.00%
# 	Elapsed Time: 21.67s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.1392	Accuracy: 42.80%
# 	Elapsed Time: 21.46s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.0744	Accuracy: 58.20%
# 	Elapsed Time: 21.48s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.0246	Accuracy: 57.60%
# 	Elapsed Time: 21.74s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 1.9786	Accuracy: 65.20%
# 	Elapsed Time: 21.67s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.9489	Accuracy: 67.20%
# 	Elapsed Time: 21.83s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.9151	Accuracy: 68.40%
# 	Elapsed Time: 21.62s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.8906	Accuracy: 69.80%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.8734	Accuracy: 71.60%
# 	Elapsed Time: 21.56s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.8572	Accuracy: 72.00%
# 	Elapsed Time: 21.68s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.8473	Accuracy: 72.20%
# 	Elapsed Time: 21.54s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.8354	Accuracy: 72.80%
# 	Elapsed Time: 21.73s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.8240	Accuracy: 73.40%
# 	Elapsed Time: 21.93s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.8200	Accuracy: 73.60%
# 	Elapsed Time: 21.99s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.8186	Accuracy: 74.60%
# 	Elapsed Time: 21.80s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.8085	Accuracy: 75.00%
# 	Elapsed Time: 21.94s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.8050	Accuracy: 74.40%
# 	Elapsed Time: 21.66s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.7972	Accuracy: 75.40%
# 	Elapsed Time: 21.01s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.7920	Accuracy: 74.80%
# 	Elapsed Time: 20.87s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.9343	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2876	Accuracy: 16.20%
# 	Elapsed Time: 20.70s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2194	Accuracy: 29.00%
# 	Elapsed Time: 20.73s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.1664	Accuracy: 35.60%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.1071	Accuracy: 48.40%
# 	Elapsed Time: 20.57s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.0481	Accuracy: 60.20%
# 	Elapsed Time: 21.09s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 1.9860	Accuracy: 69.40%
# 	Elapsed Time: 20.95s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.9374	Accuracy: 72.40%
# 	Elapsed Time: 20.69s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.9027	Accuracy: 73.80%
# 	Elapsed Time: 21.17s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.8702	Accuracy: 75.00%
# 	Elapsed Time: 20.79s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.8562	Accuracy: 76.00%
# 	Elapsed Time: 20.74s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.8376	Accuracy: 77.20%
# 	Elapsed Time: 20.71s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.8237	Accuracy: 77.80%
# 	Elapsed Time: 20.78s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.8083	Accuracy: 77.00%
# 	Elapsed Time: 20.88s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.8006	Accuracy: 78.40%
# 	Elapsed Time: 20.71s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.7893	Accuracy: 79.20%
# 	Elapsed Time: 20.86s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.7802	Accuracy: 79.20%
# 	Elapsed Time: 20.92s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.7745	Accuracy: 79.80%
# 	Elapsed Time: 20.98s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.7656	Accuracy: 80.00%
# 	Elapsed Time: 21.35s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.7542	Accuracy: 81.40%
# 	Elapsed Time: 20.65s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.7449	Accuracy: 83.00%
# 	Elapsed Time: 21.02s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.9424	 Val Accuracy: 66.00%
