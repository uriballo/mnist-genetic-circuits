# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time
import torch.nn as nn

# %%
n_train    = 500 
n_test     = 100
batch_size = 32

num_qubits = 4
repetitions = 1
n_weights = 4 * repetitions

n_epochs = 20

resized_x = 14
resized_y = resized_x

# %%
dev = qml.device('lightning.qubit', wires=4)

@qml.qnode(dev,interface="jax", diff_method="adjoint")
def circuit(inputs, weights):
    # Encoding of 4 classical input values
    for j in range(num_qubits):
        qml.RY(np.pi * inputs[j], wires=j)
   
    for i in range(repetitions): 
        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[1, 2])
        qml.CNOT(wires=[2, 3])
        qml.CNOT(wires=[3, 0])
        qml.RX(weights[0 + i], wires=0)
        qml.RX(weights[1 + i], wires=1)

        qml.CNOT(wires=[2, 3])
        qml.CNOT(wires=[0, 2])
        qml.CNOT(wires=[0, 3])
        
        qml.RY(weights[2 + i], wires=0)
        qml.RY(weights[3 + i], wires=3)

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(num_qubits)]

# %%
def load_dataset(n_train, n_test, batch_size):
    """
    Loads train & test sets from MNIST with user-specified sizes.

    Args:
        n_train (int): Desired number of samples in the training set.
        n_test (int): Desired number of samples in the testing set.
        batch_size (int): Batch size for the DataLoaders.

    Returns:
        tuple: (train_loader, test_loader) where each loader is a
               torch.utils.data.DataLoader.
    """
    # Define transformations for the dataset
    transform = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.5,), (0.5,)),
                                    transforms.Lambda(lambda img: F.interpolate(img.unsqueeze(0), size=(resized_x, resized_y), 
                                        mode='bilinear', align_corners=False).squeeze(0))])

    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    # Subset the datasets to the desired number of samples
    train_subset = torch.utils.data.Subset(train_dataset, range(n_train))
    test_subset = torch.utils.data.Subset(test_dataset, range(n_test))

    # Create DataLoaders for training and testing sets
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, pin_memory=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, pin_memory=True)

    print("Number of training samples:", len(train_subset))
    print("Number of test samples:", len(test_subset))

    return train_loader, test_loader

# %%
qlayer = qml.qnn.TorchLayer(circuit, {"weights": (n_weights,)})
fig, ax = qml.draw_mpl(circuit)([1.0,4,54,44], [1,2,3,4,5,123,2,23,1,1,1,1,1,1])
fig.show()
# Out:
# /var/folders/pc/01wnjzvx01n_gqvkhmw2_9nr0000gn/T/ipykernel_21750/3623739010.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def extract_image_patches(x):
    # Do TF 'SAME' Padding
    B, C, H, W = x.shape  
    #x = torch.arange(B*C*H*W).view(B, C, H, W)
    kernel_h, kernel_w = 2, 2
    stride = 2

    patches = x.unfold(2, kernel_h, stride).unfold(3, kernel_w, stride)
      
    patches = patches.contiguous().view(B, H // stride, W // stride, -1)

    return patches.reshape(-1, 4)

# %%
dim = resized_x // 2
class HQNN(nn.Module):
    def __init__(self):
        super(HQNN, self).__init__()

        # Quanvolutional layer (Maps 1 input channel to 4 output channels)
        self.quanv = qlayer

        # Fully connected layer to perform the final classification
        self.fc1 = nn.Linear(dim * dim * 4, 10)  # Assuming 10 output classes

    def forward(self, input):
        patches = extract_image_patches(input)  

        
        quanvoluted_patches = torch.stack([self.quanv(patch) for patch in patches])
        x = quanvoluted_patches.reshape(input.shape[0], dim, dim, 4)

        x = x.view(-1, dim * dim * 4)  # Flatten for the fully connected layer
        x = self.fc1(x)
        x = F.softmax(x, dim=1)  # Apply softmax
        return x

# %%
loss_fn = F.cross_entropy
train_loader, test_loader = load_dataset(n_train, n_test, batch_size)
# Out:
# Number of training samples: 500
# Number of test samples: 100

# %%
def append_data_to_markdown_table(file_path, circuit, lr, gamma, batch_size, val_loss, val_acc):
    """
    Appends variables to an existing Markdown table in a file, formatting floats to 3 decimal places.

    Args:
        file_path (str): The path to the Markdown file.
        lr (float): The learning rate value.
        gamma (float): The gamma value.
        batch_size (int): The batch size value.
        val_loss (float): The validation loss value.
        val_acc (float): The validation accuracy value.
    """

    with open(file_path, 'a') as f:  # Open the file in append mode
        row = f"| {circuit} | {lr} | {gamma:.2f} | {batch_size} | {val_loss:.3f} | {val_acc:.2f} |\n"
        f.write(row)  # Write the new row of data
        
lr_values    = [0.01, 0.01, 0.007, 0.007, 0.005, 0.005, 0.003, 0.003]
gamma_values = [0.98, 0.96, 0.96, 0.98, 0.98, 0.96, 0.98, 0.96] 

for lr, gamma in zip(lr_values, gamma_values):
    for _ in range(3):
        model = HQNN() 
        optimizer = torch.optim.Adam(model.parameters(), lr =lr)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma) 
        for epoch in range(n_epochs):
            # ---- Training Phase ----
            running_loss = 0.0 
            correct = 0  
            total = 0
            train_losses = []
            test_losses = []
            start_time = time.time()
            for i, (images, labels) in enumerate(train_loader):
                # --- 2. Forward Pass ---
                outputs = model(images)

                # --- 3. Loss Calculation ---
                loss = loss_fn(outputs, labels)
                train_losses.append(loss.item())
                # --- 4. Backpropagation and Optimization ---
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()  
                train_losses.append(loss.item())  # Store loss for each batch

                # Accuracy calculation for the epoch
                _, predicted = torch.max(outputs.data, 1) 
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            scheduler.step() 

            # Print statistics for the epoch
            epoch_loss = sum(train_losses) / len(train_losses)  
            epoch_acc = 100 * correct / total 

            current_lr = scheduler.get_last_lr()[0]  

            # Periodic Evaluation and Logging
            print(f'[i] Epoch {epoch + 1}\n\tLoss: {epoch_loss:.4f}\tAccuracy: {epoch_acc :.2f}%\n\tElapsed Time: {time.time() - start_time:.2f}s')
            print(f'\tLearning Rate: {current_lr}\n')

        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():  # Disable gradients for evaluation
            val_correct = 0
            val_total = 0

            for images, labels in test_loader:
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                test_losses.append(loss.item())

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = sum(test_losses) / len(test_losses)
        val_acc = 100 * val_correct / val_total 

        print(f'[i] Val Loss: {val_loss:.4f}\t Val Accuracy: {val_acc :.2f}%')
        append_data_to_markdown_table("results500.md", "quanv_SE", lr, gamma, batch_size, val_loss, val_acc)
# Out:
# [i] Epoch 1
# 	Loss: 2.2892	Accuracy: 15.60%
# 	Elapsed Time: 26.71s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.2215	Accuracy: 20.40%
# 	Elapsed Time: 26.07s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.0652	Accuracy: 51.80%
# 	Elapsed Time: 26.26s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 1.8847	Accuracy: 68.20%
# 	Elapsed Time: 26.13s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.8043	Accuracy: 69.60%
# 	Elapsed Time: 26.50s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.7874	Accuracy: 69.60%
# 	Elapsed Time: 26.32s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.7550	Accuracy: 73.60%
# 	Elapsed Time: 26.15s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.7331	Accuracy: 75.40%
# 	Elapsed Time: 26.43s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.7215	Accuracy: 76.60%
# 	Elapsed Time: 26.16s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.7132	Accuracy: 77.00%
# 	Elapsed Time: 26.05s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.6984	Accuracy: 77.80%
# 	Elapsed Time: 26.31s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.6923	Accuracy: 78.20%
# 	Elapsed Time: 26.42s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.6937	Accuracy: 78.00%
# 	Elapsed Time: 26.49s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.6862	Accuracy: 78.40%
# 	Elapsed Time: 26.56s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.6850	Accuracy: 78.80%
# 	Elapsed Time: 27.99s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.6873	Accuracy: 78.80%
# 	Elapsed Time: 27.18s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.6798	Accuracy: 79.40%
# 	Elapsed Time: 27.95s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.6769	Accuracy: 79.40%
# 	Elapsed Time: 28.01s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.6515	Accuracy: 82.60%
# 	Elapsed Time: 27.20s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.6405	Accuracy: 83.60%
# 	Elapsed Time: 26.36s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 1.8542	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2412	Accuracy: 20.60%
# 	Elapsed Time: 25.28s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.0810	Accuracy: 43.20%
# 	Elapsed Time: 25.55s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 1.9665	Accuracy: 55.40%
# 	Elapsed Time: 25.94s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 1.9266	Accuracy: 58.00%
# 	Elapsed Time: 25.76s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.9122	Accuracy: 57.60%
# 	Elapsed Time: 25.18s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.8904	Accuracy: 59.00%
# 	Elapsed Time: 25.33s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.8865	Accuracy: 60.20%
# 	Elapsed Time: 25.38s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.8720	Accuracy: 60.40%
# 	Elapsed Time: 25.26s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8669	Accuracy: 61.00%
# 	Elapsed Time: 24.58s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8681	Accuracy: 61.40%
# 	Elapsed Time: 24.40s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8578	Accuracy: 61.40%
# 	Elapsed Time: 24.36s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8542	Accuracy: 62.00%
# 	Elapsed Time: 24.65s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.8497	Accuracy: 62.20%
# 	Elapsed Time: 24.66s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.8520	Accuracy: 62.80%
# 	Elapsed Time: 24.57s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.8460	Accuracy: 62.40%
# 	Elapsed Time: 24.61s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.8455	Accuracy: 62.60%
# 	Elapsed Time: 24.55s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.8453	Accuracy: 63.00%
# 	Elapsed Time: 24.74s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.8424	Accuracy: 62.80%
# 	Elapsed Time: 24.39s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.8368	Accuracy: 62.80%
# 	Elapsed Time: 24.19s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.8382	Accuracy: 63.00%
# 	Elapsed Time: 24.49s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 2.0065	 Val Accuracy: 51.00%
# [i] Epoch 1
# 	Loss: 2.2422	Accuracy: 21.20%
# 	Elapsed Time: 23.69s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.1019	Accuracy: 39.20%
# 	Elapsed Time: 24.20s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.0225	Accuracy: 45.40%
# 	Elapsed Time: 23.78s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 1.9637	Accuracy: 54.60%
# 	Elapsed Time: 24.47s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.9461	Accuracy: 53.00%
# 	Elapsed Time: 24.39s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.9125	Accuracy: 56.20%
# 	Elapsed Time: 24.64s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.9048	Accuracy: 57.00%
# 	Elapsed Time: 24.30s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.8989	Accuracy: 58.20%
# 	Elapsed Time: 24.52s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1.8976	Accuracy: 58.60%
# 	Elapsed Time: 24.45s
# 	Learning Rate: 0.008337477621301496
#
# [i] Epoch 10
# 	Loss: 1.8845	Accuracy: 59.20%
# 	Elapsed Time: 24.48s
# 	Learning Rate: 0.008170728068875466
#
# [i] Epoch 11
# 	Loss: 1.8739	Accuracy: 60.00%
# 	Elapsed Time: 24.34s
# 	Learning Rate: 0.008007313507497957
#
# [i] Epoch 12
# 	Loss: 1.8704	Accuracy: 60.40%
# 	Elapsed Time: 24.42s
# 	Learning Rate: 0.007847167237347998
#
# [i] Epoch 13
# 	Loss: 1.8658	Accuracy: 60.60%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.007690223892601038
#
# [i] Epoch 14
# 	Loss: 1.8616	Accuracy: 60.60%
# 	Elapsed Time: 24.27s
# 	Learning Rate: 0.007536419414749017
#
# [i] Epoch 15
# 	Loss: 1.8672	Accuracy: 60.80%
# 	Elapsed Time: 24.02s
# 	Learning Rate: 0.007385691026454037
#
# [i] Epoch 16
# 	Loss: 1.8601	Accuracy: 61.20%
# 	Elapsed Time: 24.17s
# 	Learning Rate: 0.0072379772059249555
#
# [i] Epoch 17
# 	Loss: 1.8559	Accuracy: 61.20%
# 	Elapsed Time: 24.29s
# 	Learning Rate: 0.007093217661806457
#
# [i] Epoch 18
# 	Loss: 1.8571	Accuracy: 61.20%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.006951353308570328
#
# [i] Epoch 19
# 	Loss: 1.8550	Accuracy: 61.20%
# 	Elapsed Time: 24.38s
# 	Learning Rate: 0.006812326242398921
#
# [i] Epoch 20
# 	Loss: 1.8518	Accuracy: 61.40%
# 	Elapsed Time: 24.50s
# 	Learning Rate: 0.006676079717550942
#
# [i] Val Loss: 1.9679	 Val Accuracy: 52.00%
# [i] Epoch 1
# 	Loss: 2.2569	Accuracy: 20.80%
# 	Elapsed Time: 23.46s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.1345	Accuracy: 34.60%
# 	Elapsed Time: 24.03s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.0654	Accuracy: 42.40%
# 	Elapsed Time: 24.16s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 1.9990	Accuracy: 48.20%
# 	Elapsed Time: 24.50s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 1.9395	Accuracy: 55.60%
# 	Elapsed Time: 24.47s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9277	Accuracy: 56.00%
# 	Elapsed Time: 24.45s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.9102	Accuracy: 57.60%
# 	Elapsed Time: 23.90s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.8787	Accuracy: 61.60%
# 	Elapsed Time: 24.47s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8153	Accuracy: 68.60%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.7962	Accuracy: 69.80%
# 	Elapsed Time: 24.36s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.7768	Accuracy: 72.60%
# 	Elapsed Time: 24.17s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.7603	Accuracy: 73.00%
# 	Elapsed Time: 24.07s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.7538	Accuracy: 73.60%
# 	Elapsed Time: 24.32s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.7467	Accuracy: 74.40%
# 	Elapsed Time: 24.20s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.7429	Accuracy: 74.80%
# 	Elapsed Time: 24.31s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.7369	Accuracy: 75.60%
# 	Elapsed Time: 24.36s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.7304	Accuracy: 75.80%
# 	Elapsed Time: 24.41s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.7275	Accuracy: 76.20%
# 	Elapsed Time: 24.35s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.7247	Accuracy: 76.00%
# 	Elapsed Time: 24.44s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.7207	Accuracy: 76.20%
# 	Elapsed Time: 24.35s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 1.8652	 Val Accuracy: 66.00%
# [i] Epoch 1
# 	Loss: 2.2315	Accuracy: 24.00%
# 	Elapsed Time: 23.86s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.0817	Accuracy: 40.80%
# 	Elapsed Time: 23.76s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.0019	Accuracy: 46.80%
# 	Elapsed Time: 24.00s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 1.9456	Accuracy: 54.60%
# 	Elapsed Time: 24.43s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 1.9135	Accuracy: 57.40%
# 	Elapsed Time: 24.48s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9023	Accuracy: 57.00%
# 	Elapsed Time: 24.23s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.8904	Accuracy: 59.20%
# 	Elapsed Time: 24.27s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.8872	Accuracy: 59.40%
# 	Elapsed Time: 24.03s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8697	Accuracy: 60.00%
# 	Elapsed Time: 24.22s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8732	Accuracy: 60.00%
# 	Elapsed Time: 24.00s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.8649	Accuracy: 60.00%
# 	Elapsed Time: 24.27s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.8638	Accuracy: 60.20%
# 	Elapsed Time: 24.42s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.8660	Accuracy: 60.00%
# 	Elapsed Time: 24.53s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.8599	Accuracy: 61.00%
# 	Elapsed Time: 24.32s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.8565	Accuracy: 60.80%
# 	Elapsed Time: 24.48s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.8536	Accuracy: 61.00%
# 	Elapsed Time: 24.64s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.8618	Accuracy: 61.20%
# 	Elapsed Time: 24.54s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.8567	Accuracy: 60.80%
# 	Elapsed Time: 24.24s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.8554	Accuracy: 61.20%
# 	Elapsed Time: 24.34s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.8529	Accuracy: 61.00%
# 	Elapsed Time: 23.96s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 1.9309	 Val Accuracy: 58.00%
# [i] Epoch 1
# 	Loss: 2.2464	Accuracy: 20.00%
# 	Elapsed Time: 23.48s
# 	Learning Rate: 0.0096
#
# [i] Epoch 2
# 	Loss: 2.1248	Accuracy: 35.60%
# 	Elapsed Time: 23.96s
# 	Learning Rate: 0.009215999999999998
#
# [i] Epoch 3
# 	Loss: 2.0536	Accuracy: 43.40%
# 	Elapsed Time: 23.65s
# 	Learning Rate: 0.008847359999999999
#
# [i] Epoch 4
# 	Loss: 2.0245	Accuracy: 44.60%
# 	Elapsed Time: 24.12s
# 	Learning Rate: 0.008493465599999998
#
# [i] Epoch 5
# 	Loss: 1.9770	Accuracy: 52.00%
# 	Elapsed Time: 24.49s
# 	Learning Rate: 0.008153726975999998
#
# [i] Epoch 6
# 	Loss: 1.9387	Accuracy: 54.00%
# 	Elapsed Time: 25.95s
# 	Learning Rate: 0.007827577896959998
#
# [i] Epoch 7
# 	Loss: 1.9257	Accuracy: 54.80%
# 	Elapsed Time: 24.38s
# 	Learning Rate: 0.007514474781081598
#
# [i] Epoch 8
# 	Loss: 1.9174	Accuracy: 56.80%
# 	Elapsed Time: 24.17s
# 	Learning Rate: 0.007213895789838334
#
# [i] Epoch 9
# 	Loss: 1.8859	Accuracy: 61.00%
# 	Elapsed Time: 24.80s
# 	Learning Rate: 0.0069253399582448
#
# [i] Epoch 10
# 	Loss: 1.8566	Accuracy: 63.80%
# 	Elapsed Time: 24.62s
# 	Learning Rate: 0.006648326359915008
#
# [i] Epoch 11
# 	Loss: 1.8402	Accuracy: 65.80%
# 	Elapsed Time: 24.23s
# 	Learning Rate: 0.0063823933055184075
#
# [i] Epoch 12
# 	Loss: 1.8347	Accuracy: 66.00%
# 	Elapsed Time: 24.23s
# 	Learning Rate: 0.006127097573297671
#
# [i] Epoch 13
# 	Loss: 1.8275	Accuracy: 66.60%
# 	Elapsed Time: 24.41s
# 	Learning Rate: 0.005882013670365764
#
# [i] Epoch 14
# 	Loss: 1.8197	Accuracy: 66.40%
# 	Elapsed Time: 24.36s
# 	Learning Rate: 0.005646733123551133
#
# [i] Epoch 15
# 	Loss: 1.8146	Accuracy: 66.60%
# 	Elapsed Time: 24.45s
# 	Learning Rate: 0.0054208637986090874
#
# [i] Epoch 16
# 	Loss: 1.8127	Accuracy: 67.00%
# 	Elapsed Time: 24.16s
# 	Learning Rate: 0.005204029246664724
#
# [i] Epoch 17
# 	Loss: 1.8084	Accuracy: 66.80%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.004995868076798135
#
# [i] Epoch 18
# 	Loss: 1.8062	Accuracy: 67.40%
# 	Elapsed Time: 24.35s
# 	Learning Rate: 0.00479603335372621
#
# [i] Epoch 19
# 	Loss: 1.8047	Accuracy: 67.20%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.004604192019577161
#
# [i] Epoch 20
# 	Loss: 1.8034	Accuracy: 67.60%
# 	Elapsed Time: 24.04s
# 	Learning Rate: 0.004420024338794074
#
# [i] Val Loss: 1.9163	 Val Accuracy: 51.00%
# [i] Epoch 1
# 	Loss: 2.2203	Accuracy: 25.40%
# 	Elapsed Time: 23.33s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.0338	Accuracy: 52.20%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 1.9265	Accuracy: 61.20%
# 	Elapsed Time: 23.98s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 1.8584	Accuracy: 68.00%
# 	Elapsed Time: 23.96s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 1.8179	Accuracy: 71.40%
# 	Elapsed Time: 24.36s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 1.7849	Accuracy: 73.40%
# 	Elapsed Time: 24.38s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 1.7596	Accuracy: 77.40%
# 	Elapsed Time: 24.13s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.7336	Accuracy: 78.40%
# 	Elapsed Time: 24.19s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.7218	Accuracy: 79.20%
# 	Elapsed Time: 24.12s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.7074	Accuracy: 81.40%
# 	Elapsed Time: 24.38s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.7022	Accuracy: 81.80%
# 	Elapsed Time: 24.40s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.6965	Accuracy: 81.60%
# 	Elapsed Time: 24.19s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.6867	Accuracy: 82.20%
# 	Elapsed Time: 24.23s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.6818	Accuracy: 82.60%
# 	Elapsed Time: 24.38s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.6753	Accuracy: 82.80%
# 	Elapsed Time: 24.05s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.6696	Accuracy: 83.00%
# 	Elapsed Time: 23.98s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.6690	Accuracy: 82.80%
# 	Elapsed Time: 24.26s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.6613	Accuracy: 83.80%
# 	Elapsed Time: 24.24s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.6590	Accuracy: 83.60%
# 	Elapsed Time: 24.42s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.6584	Accuracy: 83.80%
# 	Elapsed Time: 24.26s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 1.8462	 Val Accuracy: 66.00%
# [i] Epoch 1
# 	Loss: 2.2369	Accuracy: 20.60%
# 	Elapsed Time: 23.74s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.0401	Accuracy: 55.20%
# 	Elapsed Time: 23.98s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 1.9314	Accuracy: 62.60%
# 	Elapsed Time: 23.88s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 1.8630	Accuracy: 67.40%
# 	Elapsed Time: 24.30s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 1.8059	Accuracy: 72.60%
# 	Elapsed Time: 24.21s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 1.7742	Accuracy: 76.60%
# 	Elapsed Time: 24.30s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 1.7541	Accuracy: 77.40%
# 	Elapsed Time: 24.19s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.7285	Accuracy: 78.80%
# 	Elapsed Time: 24.49s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.7177	Accuracy: 81.00%
# 	Elapsed Time: 24.43s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.7034	Accuracy: 81.60%
# 	Elapsed Time: 24.78s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.6906	Accuracy: 82.00%
# 	Elapsed Time: 24.18s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.6871	Accuracy: 82.60%
# 	Elapsed Time: 24.14s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.6782	Accuracy: 82.80%
# 	Elapsed Time: 24.19s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.6726	Accuracy: 83.20%
# 	Elapsed Time: 23.94s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.6676	Accuracy: 84.00%
# 	Elapsed Time: 24.04s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.6580	Accuracy: 85.20%
# 	Elapsed Time: 23.89s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.6444	Accuracy: 86.60%
# 	Elapsed Time: 24.39s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.6395	Accuracy: 87.40%
# 	Elapsed Time: 24.34s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.6254	Accuracy: 88.80%
# 	Elapsed Time: 24.45s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.6212	Accuracy: 88.60%
# 	Elapsed Time: 23.97s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 1.8603	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2559	Accuracy: 17.80%
# 	Elapsed Time: 23.81s
# 	Learning Rate: 0.00672
#
# [i] Epoch 2
# 	Loss: 2.0849	Accuracy: 43.60%
# 	Elapsed Time: 24.25s
# 	Learning Rate: 0.0064512
#
# [i] Epoch 3
# 	Loss: 1.9674	Accuracy: 58.80%
# 	Elapsed Time: 23.93s
# 	Learning Rate: 0.0061931519999999995
#
# [i] Epoch 4
# 	Loss: 1.9018	Accuracy: 63.20%
# 	Elapsed Time: 24.26s
# 	Learning Rate: 0.00594542592
#
# [i] Epoch 5
# 	Loss: 1.8459	Accuracy: 68.00%
# 	Elapsed Time: 23.99s
# 	Learning Rate: 0.0057076088831999995
#
# [i] Epoch 6
# 	Loss: 1.8156	Accuracy: 70.40%
# 	Elapsed Time: 24.25s
# 	Learning Rate: 0.0054793045278719995
#
# [i] Epoch 7
# 	Loss: 1.7981	Accuracy: 72.00%
# 	Elapsed Time: 24.53s
# 	Learning Rate: 0.005260132346757119
#
# [i] Epoch 8
# 	Loss: 1.7726	Accuracy: 73.20%
# 	Elapsed Time: 24.12s
# 	Learning Rate: 0.005049727052886834
#
# [i] Epoch 9
# 	Loss: 1.7596	Accuracy: 74.80%
# 	Elapsed Time: 24.23s
# 	Learning Rate: 0.00484773797077136
#
# [i] Epoch 10
# 	Loss: 1.7522	Accuracy: 75.60%
# 	Elapsed Time: 24.08s
# 	Learning Rate: 0.0046538284519405055
#
# [i] Epoch 11
# 	Loss: 1.7425	Accuracy: 76.00%
# 	Elapsed Time: 24.19s
# 	Learning Rate: 0.004467675313862885
#
# [i] Epoch 12
# 	Loss: 1.7330	Accuracy: 76.60%
# 	Elapsed Time: 24.15s
# 	Learning Rate: 0.0042889683013083695
#
# [i] Epoch 13
# 	Loss: 1.7294	Accuracy: 77.40%
# 	Elapsed Time: 24.49s
# 	Learning Rate: 0.0041174095692560345
#
# [i] Epoch 14
# 	Loss: 1.7229	Accuracy: 77.60%
# 	Elapsed Time: 24.39s
# 	Learning Rate: 0.003952713186485793
#
# [i] Epoch 15
# 	Loss: 1.7202	Accuracy: 78.20%
# 	Elapsed Time: 24.29s
# 	Learning Rate: 0.0037946046590263613
#
# [i] Epoch 16
# 	Loss: 1.7168	Accuracy: 78.40%
# 	Elapsed Time: 24.57s
# 	Learning Rate: 0.003642820472665307
#
# [i] Epoch 17
# 	Loss: 1.7096	Accuracy: 78.60%
# 	Elapsed Time: 24.31s
# 	Learning Rate: 0.0034971076537586945
#
# [i] Epoch 18
# 	Loss: 1.7136	Accuracy: 79.00%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.0033572233476083465
#
# [i] Epoch 19
# 	Loss: 1.7062	Accuracy: 79.00%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.0032229344137040127
#
# [i] Epoch 20
# 	Loss: 1.7012	Accuracy: 79.00%
# 	Elapsed Time: 23.65s
# 	Learning Rate: 0.003094017037155852
#
# [i] Val Loss: 1.8672	 Val Accuracy: 67.00%
# [i] Epoch 1
# 	Loss: 2.2610	Accuracy: 19.40%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.1001	Accuracy: 44.60%
# 	Elapsed Time: 23.06s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.0057	Accuracy: 52.00%
# 	Elapsed Time: 23.16s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 1.9411	Accuracy: 57.20%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 1.8442	Accuracy: 68.80%
# 	Elapsed Time: 23.25s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 1.8168	Accuracy: 70.80%
# 	Elapsed Time: 23.69s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.7868	Accuracy: 72.80%
# 	Elapsed Time: 23.08s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.7686	Accuracy: 72.60%
# 	Elapsed Time: 23.27s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.7584	Accuracy: 75.40%
# 	Elapsed Time: 23.29s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.7482	Accuracy: 75.80%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.7394	Accuracy: 76.60%
# 	Elapsed Time: 23.25s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.7318	Accuracy: 77.00%
# 	Elapsed Time: 23.61s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.7247	Accuracy: 77.60%
# 	Elapsed Time: 23.29s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.7159	Accuracy: 78.60%
# 	Elapsed Time: 23.58s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.6990	Accuracy: 80.60%
# 	Elapsed Time: 23.28s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.6817	Accuracy: 83.80%
# 	Elapsed Time: 23.49s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.6679	Accuracy: 83.80%
# 	Elapsed Time: 23.14s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.6606	Accuracy: 84.60%
# 	Elapsed Time: 23.11s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.6513	Accuracy: 84.60%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.6524	Accuracy: 85.00%
# 	Elapsed Time: 23.13s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 1.8753	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2485	Accuracy: 20.80%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.0539	Accuracy: 53.00%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 1.9409	Accuracy: 61.00%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 1.8738	Accuracy: 66.00%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 1.8269	Accuracy: 70.60%
# 	Elapsed Time: 23.14s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 1.8017	Accuracy: 73.00%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.7520	Accuracy: 78.60%
# 	Elapsed Time: 22.80s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.7234	Accuracy: 81.00%
# 	Elapsed Time: 23.56s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.7076	Accuracy: 82.00%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.6963	Accuracy: 82.40%
# 	Elapsed Time: 23.41s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.6876	Accuracy: 83.80%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.6763	Accuracy: 84.00%
# 	Elapsed Time: 23.24s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.6690	Accuracy: 83.60%
# 	Elapsed Time: 23.30s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.6625	Accuracy: 84.40%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.6562	Accuracy: 84.40%
# 	Elapsed Time: 22.84s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.6496	Accuracy: 84.80%
# 	Elapsed Time: 23.41s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.6517	Accuracy: 84.80%
# 	Elapsed Time: 23.05s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.6447	Accuracy: 85.20%
# 	Elapsed Time: 23.05s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.6446	Accuracy: 85.20%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.6355	Accuracy: 85.40%
# 	Elapsed Time: 23.16s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 1.8402	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2578	Accuracy: 18.40%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.00686
#
# [i] Epoch 2
# 	Loss: 2.1226	Accuracy: 40.00%
# 	Elapsed Time: 22.94s
# 	Learning Rate: 0.006722799999999999
#
# [i] Epoch 3
# 	Loss: 2.0261	Accuracy: 49.80%
# 	Elapsed Time: 22.99s
# 	Learning Rate: 0.0065883439999999995
#
# [i] Epoch 4
# 	Loss: 1.9294	Accuracy: 63.20%
# 	Elapsed Time: 22.77s
# 	Learning Rate: 0.006456577119999999
#
# [i] Epoch 5
# 	Loss: 1.8822	Accuracy: 66.00%
# 	Elapsed Time: 23.37s
# 	Learning Rate: 0.006327445577599999
#
# [i] Epoch 6
# 	Loss: 1.8561	Accuracy: 65.00%
# 	Elapsed Time: 23.05s
# 	Learning Rate: 0.006200896666047999
#
# [i] Epoch 7
# 	Loss: 1.8232	Accuracy: 69.40%
# 	Elapsed Time: 23.05s
# 	Learning Rate: 0.006076878732727039
#
# [i] Epoch 8
# 	Loss: 1.7939	Accuracy: 72.80%
# 	Elapsed Time: 23.17s
# 	Learning Rate: 0.005955341158072498
#
# [i] Epoch 9
# 	Loss: 1.7830	Accuracy: 72.60%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.005836234334911048
#
# [i] Epoch 10
# 	Loss: 1.7710	Accuracy: 73.80%
# 	Elapsed Time: 23.11s
# 	Learning Rate: 0.0057195096482128265
#
# [i] Epoch 11
# 	Loss: 1.7665	Accuracy: 74.20%
# 	Elapsed Time: 23.80s
# 	Learning Rate: 0.00560511945524857
#
# [i] Epoch 12
# 	Loss: 1.7509	Accuracy: 74.40%
# 	Elapsed Time: 23.30s
# 	Learning Rate: 0.005493017066143599
#
# [i] Epoch 13
# 	Loss: 1.7029	Accuracy: 81.40%
# 	Elapsed Time: 23.18s
# 	Learning Rate: 0.005383156724820727
#
# [i] Epoch 14
# 	Loss: 1.6810	Accuracy: 83.40%
# 	Elapsed Time: 23.06s
# 	Learning Rate: 0.005275493590324312
#
# [i] Epoch 15
# 	Loss: 1.6705	Accuracy: 83.40%
# 	Elapsed Time: 23.71s
# 	Learning Rate: 0.0051699837185178255
#
# [i] Epoch 16
# 	Loss: 1.6676	Accuracy: 84.40%
# 	Elapsed Time: 23.53s
# 	Learning Rate: 0.0050665840441474685
#
# [i] Epoch 17
# 	Loss: 1.6542	Accuracy: 85.00%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.004965252363264519
#
# [i] Epoch 18
# 	Loss: 1.6550	Accuracy: 84.40%
# 	Elapsed Time: 23.00s
# 	Learning Rate: 0.004865947315999228
#
# [i] Epoch 19
# 	Loss: 1.6474	Accuracy: 84.80%
# 	Elapsed Time: 22.86s
# 	Learning Rate: 0.004768628369679243
#
# [i] Epoch 20
# 	Loss: 1.6403	Accuracy: 84.80%
# 	Elapsed Time: 22.71s
# 	Learning Rate: 0.004673255802285658
#
# [i] Val Loss: 1.8821	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2679	Accuracy: 17.20%
# 	Elapsed Time: 22.21s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1138	Accuracy: 47.80%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 1.9931	Accuracy: 58.80%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 1.9134	Accuracy: 66.20%
# 	Elapsed Time: 22.68s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.8637	Accuracy: 68.40%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.8355	Accuracy: 70.60%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8086	Accuracy: 73.20%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.7941	Accuracy: 72.40%
# 	Elapsed Time: 22.74s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.7803	Accuracy: 74.20%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.7728	Accuracy: 74.80%
# 	Elapsed Time: 22.77s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.7575	Accuracy: 75.20%
# 	Elapsed Time: 22.74s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.7553	Accuracy: 75.80%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.7463	Accuracy: 77.20%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.7393	Accuracy: 76.80%
# 	Elapsed Time: 23.10s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.7341	Accuracy: 77.80%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.7328	Accuracy: 77.80%
# 	Elapsed Time: 23.08s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.7216	Accuracy: 77.60%
# 	Elapsed Time: 23.03s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.7189	Accuracy: 78.00%
# 	Elapsed Time: 22.40s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.7193	Accuracy: 77.40%
# 	Elapsed Time: 22.17s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.7115	Accuracy: 78.60%
# 	Elapsed Time: 22.67s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.8556	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2845	Accuracy: 16.60%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1356	Accuracy: 38.80%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.0485	Accuracy: 49.00%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 1.9381	Accuracy: 63.20%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.8755	Accuracy: 68.00%
# 	Elapsed Time: 22.97s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.8373	Accuracy: 70.20%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8124	Accuracy: 71.20%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.7897	Accuracy: 72.60%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.7804	Accuracy: 73.60%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.7687	Accuracy: 75.40%
# 	Elapsed Time: 22.66s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.7599	Accuracy: 74.40%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.7423	Accuracy: 78.40%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.7302	Accuracy: 79.80%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.7137	Accuracy: 81.20%
# 	Elapsed Time: 22.98s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.7051	Accuracy: 82.20%
# 	Elapsed Time: 22.92s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.6903	Accuracy: 83.20%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.6833	Accuracy: 83.40%
# 	Elapsed Time: 22.83s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.6758	Accuracy: 83.80%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.6720	Accuracy: 84.20%
# 	Elapsed Time: 22.96s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.6689	Accuracy: 84.40%
# 	Elapsed Time: 23.16s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.8794	 Val Accuracy: 62.00%
# [i] Epoch 1
# 	Loss: 2.2637	Accuracy: 16.80%
# 	Elapsed Time: 22.21s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1370	Accuracy: 40.80%
# 	Elapsed Time: 23.01s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.0205	Accuracy: 56.40%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 1.9322	Accuracy: 65.00%
# 	Elapsed Time: 22.98s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.8761	Accuracy: 66.80%
# 	Elapsed Time: 22.85s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.8386	Accuracy: 68.60%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8091	Accuracy: 72.00%
# 	Elapsed Time: 22.97s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.7978	Accuracy: 73.40%
# 	Elapsed Time: 23.15s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.7818	Accuracy: 73.40%
# 	Elapsed Time: 23.29s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.7730	Accuracy: 74.40%
# 	Elapsed Time: 22.66s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.7646	Accuracy: 75.00%
# 	Elapsed Time: 22.68s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.7583	Accuracy: 75.40%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.7488	Accuracy: 76.20%
# 	Elapsed Time: 22.89s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.7409	Accuracy: 76.40%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.7375	Accuracy: 77.20%
# 	Elapsed Time: 22.67s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.7317	Accuracy: 76.60%
# 	Elapsed Time: 22.83s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.7270	Accuracy: 77.80%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.7231	Accuracy: 77.40%
# 	Elapsed Time: 22.92s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.7214	Accuracy: 77.40%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.7208	Accuracy: 77.80%
# 	Elapsed Time: 23.21s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.8622	 Val Accuracy: 72.00%
# [i] Epoch 1
# 	Loss: 2.2611	Accuracy: 17.60%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.1316	Accuracy: 40.20%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.0345	Accuracy: 52.80%
# 	Elapsed Time: 22.85s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 1.9279	Accuracy: 67.80%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.8663	Accuracy: 68.00%
# 	Elapsed Time: 22.88s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.8168	Accuracy: 74.80%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.7861	Accuracy: 75.80%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.7694	Accuracy: 77.80%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.7512	Accuracy: 78.40%
# 	Elapsed Time: 22.90s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.7375	Accuracy: 79.00%
# 	Elapsed Time: 22.85s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.7265	Accuracy: 80.40%
# 	Elapsed Time: 22.87s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.7163	Accuracy: 80.80%
# 	Elapsed Time: 22.79s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.7091	Accuracy: 80.60%
# 	Elapsed Time: 22.94s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7080	Accuracy: 82.00%
# 	Elapsed Time: 22.91s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.6981	Accuracy: 82.80%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.6894	Accuracy: 82.40%
# 	Elapsed Time: 22.80s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.6864	Accuracy: 83.20%
# 	Elapsed Time: 23.00s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.6837	Accuracy: 83.00%
# 	Elapsed Time: 22.68s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.6765	Accuracy: 83.80%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.6782	Accuracy: 83.40%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 1.8762	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2504	Accuracy: 18.80%
# 	Elapsed Time: 22.06s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.0884	Accuracy: 49.60%
# 	Elapsed Time: 22.14s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 1.9803	Accuracy: 61.40%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 1.9177	Accuracy: 62.60%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.8960	Accuracy: 62.80%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.8569	Accuracy: 67.80%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.8262	Accuracy: 71.80%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.7774	Accuracy: 78.00%
# 	Elapsed Time: 22.67s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.7525	Accuracy: 79.80%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.7405	Accuracy: 80.60%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.7262	Accuracy: 81.60%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.7196	Accuracy: 82.80%
# 	Elapsed Time: 22.70s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.7097	Accuracy: 82.40%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7002	Accuracy: 82.60%
# 	Elapsed Time: 22.82s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.6966	Accuracy: 83.60%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.6912	Accuracy: 83.60%
# 	Elapsed Time: 22.45s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.6816	Accuracy: 83.80%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.6801	Accuracy: 84.40%
# 	Elapsed Time: 22.61s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.6735	Accuracy: 84.80%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.6706	Accuracy: 84.60%
# 	Elapsed Time: 22.45s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 1.8815	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2456	Accuracy: 23.20%
# 	Elapsed Time: 22.03s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.1021	Accuracy: 47.20%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.0111	Accuracy: 52.40%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 1.9732	Accuracy: 53.80%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.9529	Accuracy: 55.00%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.9369	Accuracy: 56.20%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.8980	Accuracy: 62.40%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.8753	Accuracy: 63.60%
# 	Elapsed Time: 22.39s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.8609	Accuracy: 64.20%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.8205	Accuracy: 71.60%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.7903	Accuracy: 73.60%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.7785	Accuracy: 74.40%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.7679	Accuracy: 75.60%
# 	Elapsed Time: 22.71s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7534	Accuracy: 75.80%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.7379	Accuracy: 78.80%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.0027104318993045437
#
# [i] Epoch 16
# 	Loss: 1.7258	Accuracy: 81.00%
# 	Elapsed Time: 22.78s
# 	Learning Rate: 0.002602014623332362
#
# [i] Epoch 17
# 	Loss: 1.7134	Accuracy: 82.20%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.0024979340383990676
#
# [i] Epoch 18
# 	Loss: 1.7030	Accuracy: 83.00%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.002398016676863105
#
# [i] Epoch 19
# 	Loss: 1.6924	Accuracy: 83.80%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.0023020960097885805
#
# [i] Epoch 20
# 	Loss: 1.6890	Accuracy: 83.80%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.002210012169397037
#
# [i] Val Loss: 1.8724	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2723	Accuracy: 14.80%
# 	Elapsed Time: 21.93s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.1810	Accuracy: 29.00%
# 	Elapsed Time: 22.23s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.0973	Accuracy: 49.20%
# 	Elapsed Time: 22.40s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.0263	Accuracy: 59.20%
# 	Elapsed Time: 22.29s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 1.9542	Accuracy: 64.00%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 1.9093	Accuracy: 68.40%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.8667	Accuracy: 70.00%
# 	Elapsed Time: 22.72s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.8508	Accuracy: 70.80%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.8308	Accuracy: 71.40%
# 	Elapsed Time: 22.62s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8180	Accuracy: 71.20%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.8071	Accuracy: 72.00%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.7993	Accuracy: 72.80%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.7863	Accuracy: 73.20%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.7818	Accuracy: 73.60%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.7781	Accuracy: 74.20%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.7614	Accuracy: 75.80%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.7526	Accuracy: 78.00%
# 	Elapsed Time: 22.83s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.7466	Accuracy: 78.60%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.7341	Accuracy: 79.40%
# 	Elapsed Time: 22.62s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.7272	Accuracy: 81.20%
# 	Elapsed Time: 22.59s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.8821	 Val Accuracy: 63.00%
# [i] Epoch 1
# 	Loss: 2.2835	Accuracy: 17.20%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.1827	Accuracy: 31.40%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.0967	Accuracy: 46.00%
# 	Elapsed Time: 22.31s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.0283	Accuracy: 57.80%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 1.9671	Accuracy: 63.00%
# 	Elapsed Time: 22.43s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 1.9112	Accuracy: 68.20%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.8770	Accuracy: 69.80%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.8538	Accuracy: 71.20%
# 	Elapsed Time: 22.71s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.8274	Accuracy: 74.20%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8007	Accuracy: 75.80%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.7831	Accuracy: 80.60%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.7618	Accuracy: 79.80%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.7470	Accuracy: 83.00%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.7278	Accuracy: 83.00%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.7171	Accuracy: 84.80%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.7034	Accuracy: 85.40%
# 	Elapsed Time: 22.54s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.6961	Accuracy: 85.40%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.6899	Accuracy: 86.20%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.6846	Accuracy: 86.60%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.6757	Accuracy: 86.80%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.8958	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2794	Accuracy: 17.80%
# 	Elapsed Time: 22.07s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.1961	Accuracy: 29.00%
# 	Elapsed Time: 22.30s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.1124	Accuracy: 43.60%
# 	Elapsed Time: 22.55s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.0483	Accuracy: 52.00%
# 	Elapsed Time: 22.36s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 1.9888	Accuracy: 60.60%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 1.9206	Accuracy: 67.60%
# 	Elapsed Time: 22.58s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.8817	Accuracy: 68.80%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.8530	Accuracy: 70.80%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.8338	Accuracy: 71.20%
# 	Elapsed Time: 22.56s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8199	Accuracy: 71.20%
# 	Elapsed Time: 22.60s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.8111	Accuracy: 72.40%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.7994	Accuracy: 74.00%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.7913	Accuracy: 74.60%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.7866	Accuracy: 74.40%
# 	Elapsed Time: 22.72s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.7777	Accuracy: 74.80%
# 	Elapsed Time: 22.45s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.7688	Accuracy: 75.60%
# 	Elapsed Time: 22.73s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.7623	Accuracy: 76.00%
# 	Elapsed Time: 22.65s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.7608	Accuracy: 76.00%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.7560	Accuracy: 75.60%
# 	Elapsed Time: 22.67s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.7507	Accuracy: 76.40%
# 	Elapsed Time: 22.72s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.8884	 Val Accuracy: 64.00%
# [i] Epoch 1
# 	Loss: 2.2714	Accuracy: 13.80%
# 	Elapsed Time: 21.97s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.1716	Accuracy: 40.60%
# 	Elapsed Time: 22.22s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.0853	Accuracy: 51.80%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 1.9999	Accuracy: 65.60%
# 	Elapsed Time: 22.43s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 1.9428	Accuracy: 65.80%
# 	Elapsed Time: 22.41s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 1.9022	Accuracy: 68.60%
# 	Elapsed Time: 22.54s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.8774	Accuracy: 68.60%
# 	Elapsed Time: 22.41s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.8584	Accuracy: 70.20%
# 	Elapsed Time: 22.54s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.8384	Accuracy: 71.20%
# 	Elapsed Time: 22.38s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.8252	Accuracy: 72.20%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.8181	Accuracy: 72.00%
# 	Elapsed Time: 22.62s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.8059	Accuracy: 73.20%
# 	Elapsed Time: 22.57s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.8023	Accuracy: 73.20%
# 	Elapsed Time: 22.52s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.7961	Accuracy: 73.00%
# 	Elapsed Time: 22.64s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.7906	Accuracy: 74.20%
# 	Elapsed Time: 22.76s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.7837	Accuracy: 74.40%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.7754	Accuracy: 73.40%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.7707	Accuracy: 75.20%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.7684	Accuracy: 75.40%
# 	Elapsed Time: 22.63s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.7641	Accuracy: 75.20%
# 	Elapsed Time: 22.51s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.8959	 Val Accuracy: 65.00%
# [i] Epoch 1
# 	Loss: 2.2886	Accuracy: 13.20%
# 	Elapsed Time: 22.00s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.1995	Accuracy: 31.40%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.1182	Accuracy: 46.60%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.0469	Accuracy: 55.80%
# 	Elapsed Time: 22.53s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 1.9919	Accuracy: 61.60%
# 	Elapsed Time: 22.43s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 1.9297	Accuracy: 69.40%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.8841	Accuracy: 74.60%
# 	Elapsed Time: 22.66s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.8391	Accuracy: 78.80%
# 	Elapsed Time: 22.44s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.8105	Accuracy: 80.40%
# 	Elapsed Time: 22.75s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.7846	Accuracy: 81.00%
# 	Elapsed Time: 23.32s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.7654	Accuracy: 82.60%
# 	Elapsed Time: 22.49s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.7541	Accuracy: 82.20%
# 	Elapsed Time: 22.23s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.7458	Accuracy: 82.00%
# 	Elapsed Time: 22.31s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.7334	Accuracy: 84.20%
# 	Elapsed Time: 22.39s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.7243	Accuracy: 84.20%
# 	Elapsed Time: 22.24s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.7187	Accuracy: 84.20%
# 	Elapsed Time: 22.47s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.7085	Accuracy: 85.00%
# 	Elapsed Time: 22.40s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.7027	Accuracy: 85.00%
# 	Elapsed Time: 22.54s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.7001	Accuracy: 85.60%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.6922	Accuracy: 85.60%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.9055	 Val Accuracy: 64.00%
# [i] Epoch 1
# 	Loss: 2.2652	Accuracy: 19.60%
# 	Elapsed Time: 21.82s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.1731	Accuracy: 37.60%
# 	Elapsed Time: 22.16s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.0780	Accuracy: 50.60%
# 	Elapsed Time: 22.07s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.0031	Accuracy: 63.80%
# 	Elapsed Time: 22.39s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 1.9491	Accuracy: 66.40%
# 	Elapsed Time: 22.33s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 1.9098	Accuracy: 66.00%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.8785	Accuracy: 69.20%
# 	Elapsed Time: 22.37s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.8582	Accuracy: 70.20%
# 	Elapsed Time: 22.39s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.8442	Accuracy: 72.40%
# 	Elapsed Time: 22.48s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.8289	Accuracy: 72.40%
# 	Elapsed Time: 22.28s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.8129	Accuracy: 72.60%
# 	Elapsed Time: 22.32s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.8081	Accuracy: 73.20%
# 	Elapsed Time: 22.27s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.7991	Accuracy: 75.40%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.7810	Accuracy: 77.00%
# 	Elapsed Time: 22.27s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.7689	Accuracy: 79.80%
# 	Elapsed Time: 22.42s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.7569	Accuracy: 79.80%
# 	Elapsed Time: 22.50s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.7527	Accuracy: 80.20%
# 	Elapsed Time: 22.38s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.7381	Accuracy: 81.40%
# 	Elapsed Time: 22.46s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.7346	Accuracy: 81.00%
# 	Elapsed Time: 22.31s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.7315	Accuracy: 81.40%
# 	Elapsed Time: 22.36s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.9269	 Val Accuracy: 64.00%
