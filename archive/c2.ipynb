# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time

import torch.nn as nn

# %%
n_train    = 500 
n_test     = 100
batch_size = 32


num_qubits = 4
repetitions = 1
n_weights = 4 * repetitions
n_epochs = 20

resized_x = 14
resized_y = resized_x

# %%
dev = qml.device('lightning.qubit', wires=4)

@qml.qnode(dev,interface="torch", diff_method="adjoint")
def circuit(inputs, weights):
    # Encoding of 4 classical input values
    for j in range(num_qubits):
        qml.RY(np.pi * inputs[j], wires=j)
   
    qml.RX(weights[0], wires=2)
    qml.CNOT(wires=[0, 3])
    qml.RZ(weights[1], wires=0)
    qml.CNOT(wires=[1, 2])
    qml.CNOT(wires=[2, 0])
    qml.RZ(weights[2], wires=0)
    qml.RZ(weights[3], wires=3)
    qml.Hadamard(wires=0)
 
    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(num_qubits)]

# %%
def load_dataset(n_train, n_test, batch_size):
    """
    Loads train & test sets from MNIST with user-specified sizes.

    Args:
        n_train (int): Desired number of samples in the training set.
        n_test (int): Desired number of samples in the testing set.
        batch_size (int): Batch size for the DataLoaders.

    Returns:
        tuple: (train_loader, test_loader) where each loader is a
               torch.utils.data.DataLoader.
    """
    # Define transformations for the dataset
    transform = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.5,), (0.5,)),
                                    transforms.Lambda(lambda img: F.interpolate(img.unsqueeze(0), size=(resized_x, resized_y), 
                                        mode='bilinear', align_corners=False).squeeze(0))])

    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    # Subset the datasets to the desired number of samples
    train_subset = torch.utils.data.Subset(train_dataset, range(n_train))
    test_subset = torch.utils.data.Subset(test_dataset, range(n_test))

    # Create DataLoaders for training and testing sets
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, pin_memory=True)
    test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, pin_memory=True)

    print("Number of training samples:", len(train_subset))
    print("Number of test samples:", len(test_subset))

    return train_loader, test_loader

# %%
qlayer = qml.qnn.TorchLayer(circuit, {"weights": (n_weights,)})
fig, ax = qml.draw_mpl(circuit)([1.0,4,54,44], [1,2,3,4,5,123,2,23,1,1,1,1,1,1])
fig.show()
# Out:
# /var/folders/pc/01wnjzvx01n_gqvkhmw2_9nr0000gn/T/ipykernel_4549/3623739010.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def extract_image_patches(x):
    # Do TF 'SAME' Padding
    B, C, H, W = x.shape  
    #x = torch.arange(B*C*H*W).view(B, C, H, W)
    kernel_h, kernel_w = 2, 2
    stride = 2

    patches = x.unfold(2, kernel_h, stride).unfold(3, kernel_w, stride)
      
    patches = patches.contiguous().view(B, H // stride, W // stride, -1)

    return patches.reshape(-1, 4)

# %%
dim = resized_x // 2
class HQNN(nn.Module):
    def __init__(self):
        super(HQNN, self).__init__()

        # Quanvolutional layer (Maps 1 input channel to 4 output channels)
        self.quanv = qlayer

        # Fully connected layer to perform the final classification
        self.fc1 = nn.Linear(dim * dim * 4, 10)  # Assuming 10 output classes

    def forward(self, input):
        patches = extract_image_patches(input)  

        quanvoluted_patches = torch.stack([self.quanv(patch) for patch in patches])
        x = quanvoluted_patches.reshape(input.shape[0], dim, dim, 4)

        x = x.view(-1, dim * dim * 4)  # Flatten for the fully connected layer
        x = self.fc1(x)
        x = F.softmax(x, dim=1)  # Apply softmax
        return x

# %%
loss_fn = F.cross_entropy
train_loader, test_loader = load_dataset(n_train, n_test, batch_size)
# Out:
# Number of training samples: 500
# Number of test samples: 100

# %%
def append_data_to_markdown_table(file_path, circuit, lr, gamma, batch_size, val_loss, val_acc):
    """
    Appends variables to an existing Markdown table in a file, formatting floats to 3 decimal places.

    Args:
        file_path (str): The path to the Markdown file.
        lr (float): The learning rate value.
        gamma (float): The gamma value.
        batch_size (int): The batch size value.
        val_loss (float): The validation loss value.
        val_acc (float): The validation accuracy value.
    """

    with open(file_path, 'a') as f:  # Open the file in append mode
        row = f"| {circuit} | {lr} | {gamma:.2f} | {batch_size} | {val_loss:.3f} | {val_acc:.2f} |\n"
        f.write(row)  # Write the new row of data
        
lr_values    = [0.01, 0.01, 0.007, 0.007, 0.005, 0.005, 0.003, 0.003]
gamma_values = [0.98, 0.96, 0.96, 0.98, 0.98, 0.96, 0.98, 0.96] 

for lr, gamma in zip(lr_values, gamma_values):
    for _ in range(3):
        model = HQNN() 
        optimizer = torch.optim.Adam(model.parameters(), lr =lr)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma) 
        for epoch in range(n_epochs):
            # ---- Training Phase ----
            running_loss = 0.0 
            correct = 0  
            total = 0
            train_losses = []
            test_losses = []
            start_time = time.time()
            for i, (images, labels) in enumerate(train_loader):
                # --- 2. Forward Pass ---
                outputs = model(images)

                # --- 3. Loss Calculation ---
                loss = loss_fn(outputs, labels)
                train_losses.append(loss.item())
                # --- 4. Backpropagation and Optimization ---
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()  
                train_losses.append(loss.item())  # Store loss for each batch

                # Accuracy calculation for the epoch
                _, predicted = torch.max(outputs.data, 1) 
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            scheduler.step() 

            # Print statistics for the epoch
            epoch_loss = sum(train_losses) / len(train_losses)  
            epoch_acc = 100 * correct / total 

            current_lr = scheduler.get_last_lr()[0]  

            # Periodic Evaluation and Logging
            print(f'[i] Epoch {epoch + 1}\n\tLoss: {epoch_loss:.4f}\tAccuracy: {epoch_acc :.2f}%\n\tElapsed Time: {time.time() - start_time:.2f}s')
            print(f'\tLearning Rate: {current_lr}\n')

        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():  # Disable gradients for evaluation
            val_correct = 0
            val_total = 0

            for images, labels in test_loader:
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                test_losses.append(loss.item())

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = sum(test_losses) / len(test_losses)
        val_acc = 100 * val_correct / val_total 

        print(f'[i] Val Loss: {val_loss:.4f}\t Val Accuracy: {val_acc :.2f}%')
        append_data_to_markdown_table("results500.md", "circ8", lr, gamma, batch_size, val_loss, val_acc)
# Out:
# [i] Epoch 1
# 	Loss: 2.2678	Accuracy: 18.00%
# 	Elapsed Time: 18.49s
# 	Learning Rate: 0.0098
#
# [i] Epoch 2
# 	Loss: 2.1379	Accuracy: 36.20%
# 	Elapsed Time: 18.70s
# 	Learning Rate: 0.009604
#
# [i] Epoch 3
# 	Loss: 2.0317	Accuracy: 50.00%
# 	Elapsed Time: 18.52s
# 	Learning Rate: 0.009411919999999999
#
# [i] Epoch 4
# 	Loss: 1.9068	Accuracy: 67.80%
# 	Elapsed Time: 18.47s
# 	Learning Rate: 0.009223681599999999
#
# [i] Epoch 5
# 	Loss: 1.8156	Accuracy: 74.40%
# 	Elapsed Time: 18.60s
# 	Learning Rate: 0.009039207967999998
#
# [i] Epoch 6
# 	Loss: 1.7667	Accuracy: 76.80%
# 	Elapsed Time: 18.54s
# 	Learning Rate: 0.008858423808639998
#
# [i] Epoch 7
# 	Loss: 1.7404	Accuracy: 78.20%
# 	Elapsed Time: 18.76s
# 	Learning Rate: 0.008681255332467197
#
# [i] Epoch 8
# 	Loss: 1.7250	Accuracy: 79.00%
# 	Elapsed Time: 18.90s
# 	Learning Rate: 0.008507630225817853
#
# [i] Epoch 9
# 	Loss: 1

# 	Elapsed Time: 18.46s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.7565	Accuracy: 75.20%
# 	Elapsed Time: 18.61s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.7491	Accuracy: 77.00%
# 	Elapsed Time: 18.56s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.7414	Accuracy: 77.20%
# 	Elapsed Time: 18.44s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.8812	 Val Accuracy: 64.00%
# [i] Epoch 1
# 	Loss: 2.2728	Accuracy: 17.40%
# 	Elapsed Time: 18.18s
# 	Learning Rate: 0.0049
#
# [i] Epoch 2
# 	Loss: 2.1679	Accuracy: 37.00%
# 	Elapsed Time: 18.38s
# 	Learning Rate: 0.004802
#
# [i] Epoch 3
# 	Loss: 2.0817	Accuracy: 48.20%
# 	Elapsed Time: 18.44s
# 	Learning Rate: 0.0047059599999999995
#
# [i] Epoch 4
# 	Loss: 2.0077	Accuracy: 56.40%
# 	Elapsed Time: 18.41s
# 	Learning Rate: 0.004611840799999999
#
# [i] Epoch 5
# 	Loss: 1.9468	Accuracy: 65.40%
# 	Elapsed Time: 18.40s
# 	Learning Rate: 0.004519603983999999
#
# [i] Epoch 6
# 	Loss: 1.8987	Accuracy: 66.00%
# 	Elapsed Time: 18.49s
# 	Learning Rate: 0.004429211904319999
#
# [i] Epoch 7
# 	Loss: 1.8673	Accuracy: 68.60%
# 	Elapsed Time: 18.44s
# 	Learning Rate: 0.004340627666233598
#
# [i] Epoch 8
# 	Loss: 1.8424	Accuracy: 71.40%
# 	Elapsed Time: 18.51s
# 	Learning Rate: 0.004253815112908926
#
# [i] Epoch 9
# 	Loss: 1.8229	Accuracy: 71.20%
# 	Elapsed Time: 18.52s
# 	Learning Rate: 0.004168738810650748
#
# [i] Epoch 10
# 	Loss: 1.8140	Accuracy: 72.00%
# 	Elapsed Time: 18.56s
# 	Learning Rate: 0.004085364034437733
#
# [i] Epoch 11
# 	Loss: 1.8014	Accuracy: 72.60%
# 	Elapsed Time: 18.46s
# 	Learning Rate: 0.0040036567537489786
#
# [i] Epoch 12
# 	Loss: 1.7913	Accuracy: 73.60%
# 	Elapsed Time: 18.58s
# 	Learning Rate: 0.003923583618673999
#
# [i] Epoch 13
# 	Loss: 1.7843	Accuracy: 74.80%
# 	Elapsed Time: 18.57s
# 	Learning Rate: 0.003845111946300519
#
# [i] Epoch 14
# 	Loss: 1.7720	Accuracy: 74.60%
# 	Elapsed Time: 18.50s
# 	Learning Rate: 0.0037682097073745086
#
# [i] Epoch 15
# 	Loss: 1.7665	Accuracy: 75.40%
# 	Elapsed Time: 18.61s
# 	Learning Rate: 0.0036928455132270183
#
# [i] Epoch 16
# 	Loss: 1.7606	Accuracy: 76.80%
# 	Elapsed Time: 18.53s
# 	Learning Rate: 0.0036189886029624778
#
# [i] Epoch 17
# 	Loss: 1.7441	Accuracy: 79.80%
# 	Elapsed Time: 18.50s
# 	Learning Rate: 0.0035466088309032283
#
# [i] Epoch 18
# 	Loss: 1.7380	Accuracy: 79.60%
# 	Elapsed Time: 18.61s
# 	Learning Rate: 0.003475676654285164
#
# [i] Epoch 19
# 	Loss: 1.7236	Accuracy: 81.20%
# 	Elapsed Time: 18.49s
# 	Learning Rate: 0.0034061631211994604
#
# [i] Epoch 20
# 	Loss: 1.7080	Accuracy: 83.00%
# 	Elapsed Time: 18.51s
# 	Learning Rate: 0.003338039858775471
#
# [i] Val Loss: 1.8822	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2732	Accuracy: 17.00%
# 	Elapsed Time: 18.23s
# 	Learning Rate: 0.0048
#
# [i] Epoch 2
# 	Loss: 2.1938	Accuracy: 26.80%
# 	Elapsed Time: 18.35s
# 	Learning Rate: 0.004607999999999999
#
# [i] Epoch 3
# 	Loss: 2.0959	Accuracy: 50.80%
# 	Elapsed Time: 18.41s
# 	Learning Rate: 0.004423679999999999
#
# [i] Epoch 4
# 	Loss: 2.0384	Accuracy: 51.80%
# 	Elapsed Time: 18.47s
# 	Learning Rate: 0.004246732799999999
#
# [i] Epoch 5
# 	Loss: 1.9908	Accuracy: 59.80%
# 	Elapsed Time: 18.41s
# 	Learning Rate: 0.004076863487999999
#
# [i] Epoch 6
# 	Loss: 1.9475	Accuracy: 61.20%
# 	Elapsed Time: 18.51s
# 	Learning Rate: 0.003913788948479999
#
# [i] Epoch 7
# 	Loss: 1.9180	Accuracy: 63.00%
# 	Elapsed Time: 18.37s
# 	Learning Rate: 0.003757237390540799
#
# [i] Epoch 8
# 	Loss: 1.8926	Accuracy: 67.00%
# 	Elapsed Time: 18.50s
# 	Learning Rate: 0.003606947894919167
#
# [i] Epoch 9
# 	Loss: 1.8516	Accuracy: 70.40%
# 	Elapsed Time: 18.63s
# 	Learning Rate: 0.0034626699791224
#
# [i] Epoch 10
# 	Loss: 1.8362	Accuracy: 72.20%
# 	Elapsed Time: 18.60s
# 	Learning Rate: 0.003324163179957504
#
# [i] Epoch 11
# 	Loss: 1.8224	Accuracy: 72.60%
# 	Elapsed Time: 18.56s
# 	Learning Rate: 0.0031911966527592038
#
# [i] Epoch 12
# 	Loss: 1.8079	Accuracy: 74.00%
# 	Elapsed Time: 18.51s
# 	Learning Rate: 0.0030635487866488356
#
# [i] Epoch 13
# 	Loss: 1.8032	Accuracy: 73.80%
# 	Elapsed Time: 18.53s
# 	Learning Rate: 0.002941006835182882
#
# [i] Epoch 14
# 	Loss: 1.7903	Accuracy: 75.60%
# 	Elapsed Time: 18.65s
# 	Learning Rate: 0.0028233665617755665
#
# [i] Epoch 15
# 	Loss: 1.

# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.9931	Accuracy: 58.40%
# 	Elapsed Time: 18.16s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.9694	Accuracy: 59.40%
# 	Elapsed Time: 18.29s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.9470	Accuracy: 61.20%
# 	Elapsed Time: 18.31s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.9343	Accuracy: 62.20%
# 	Elapsed Time: 18.24s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.9156	Accuracy: 61.80%
# 	Elapsed Time: 18.28s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.9051	Accuracy: 66.60%
# 	Elapsed Time: 18.27s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.8696	Accuracy: 69.20%
# 	Elapsed Time: 18.26s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.8545	Accuracy: 71.60%
# 	Elapsed Time: 18.34s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.8361	Accuracy: 72.00%
# 	Elapsed Time: 18.24s
# 	Learning Rate: 0.002215707307936212
#
# [i] Epoch 16
# 	Loss: 1.8307	Accuracy: 72.40%
# 	Elapsed Time: 18.25s
# 	Learning Rate: 0.002171393161777488
#
# [i] Epoch 17
# 	Loss: 1.8202	Accuracy: 71.40%
# 	Elapsed Time: 18.24s
# 	Learning Rate: 0.002127965298541938
#
# [i] Epoch 18
# 	Loss: 1.8115	Accuracy: 73.20%
# 	Elapsed Time: 18.32s
# 	Learning Rate: 0.0020854059925710993
#
# [i] Epoch 19
# 	Loss: 1.8042	Accuracy: 74.20%
# 	Elapsed Time: 18.21s
# 	Learning Rate: 0.0020436978727196775
#
# [i] Epoch 20
# 	Loss: 1.8005	Accuracy: 73.60%
# 	Elapsed Time: 18.30s
# 	Learning Rate: 0.002002823915265284
#
# [i] Val Loss: 1.9334	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2834	Accuracy: 13.20%
# 	Elapsed Time: 18.03s
# 	Learning Rate: 0.00294
#
# [i] Epoch 2
# 	Loss: 2.2278	Accuracy: 23.40%
# 	Elapsed Time: 18.11s
# 	Learning Rate: 0.0028812
#
# [i] Epoch 3
# 	Loss: 2.1689	Accuracy: 37.40%
# 	Elapsed Time: 18.06s
# 	Learning Rate: 0.002823576
#
# [i] Epoch 4
# 	Loss: 2.1134	Accuracy: 46.20%
# 	Elapsed Time: 17.97s
# 	Learning Rate: 0.00276710448
#
# [i] Epoch 5
# 	Loss: 2.0567	Accuracy: 54.40%
# 	Elapsed Time: 18.36s
# 	Learning Rate: 0.0027117623904
#
# [i] Epoch 6
# 	Loss: 2.0056	Accuracy: 62.80%
# 	Elapsed Time: 18.44s
# 	Learning Rate: 0.002657527142592
#
# [i] Epoch 7
# 	Loss: 1.9655	Accuracy: 64.20%
# 	Elapsed Time: 18.55s
# 	Learning Rate: 0.00260437659974016
#
# [i] Epoch 8
# 	Loss: 1.9365	Accuracy: 67.40%
# 	Elapsed Time: 18.59s
# 	Learning Rate: 0.0025522890677453568
#
# [i] Epoch 9
# 	Loss: 1.9077	Accuracy: 68.60%
# 	Elapsed Time: 18.50s
# 	Learning Rate: 0.0025012432863904498
#
# [i] Epoch 10
# 	Loss: 1.8917	Accuracy: 69.20%
# 	Elapsed Time: 18.58s
# 	Learning Rate: 0.002451218420662641
#
# [i] Epoch 11
# 	Loss: 1.8709	Accuracy: 69.60%
# 	Elapsed Time: 19.61s
# 	Learning Rate: 0.002402194052249388
#
# [i] Epoch 12
# 	Loss: 1.8564	Accuracy: 70.80%
# 	Elapsed Time: 19.21s
# 	Learning Rate: 0.0023541501712044
#
# [i] Epoch 13
# 	Loss: 1.8491	Accuracy: 70.40%
# 	Elapsed Time: 18.71s
# 	Learning Rate: 0.002307067167780312
#
# [i] Epoch 14
# 	Loss: 1.8353	Accuracy: 72.80%
# 	Elapsed Time: 18.87s
# 	Learning Rate: 0.002260925824424706
#
# [i] Epoch 15
# 	Loss: 1.8274	Accuracy: 72.00%
# 	Elapsed Time: 18.69s
# 	Learning Rate: 0

# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 1.9490	 Val Accuracy: 61.00%
# [i] Epoch 1
# 	Loss: 2.2875	Accuracy: 16.00%
# 	Elapsed Time: 18.40s
# 	Learning Rate: 0.0028799999999999997
#
# [i] Epoch 2
# 	Loss: 2.2304	Accuracy: 25.40%
# 	Elapsed Time: 18.56s
# 	Learning Rate: 0.0027647999999999995
#
# [i] Epoch 3
# 	Loss: 2.1672	Accuracy: 40.40%
# 	Elapsed Time: 18.52s
# 	Learning Rate: 0.0026542079999999995
#
# [i] Epoch 4
# 	Loss: 2.1141	Accuracy: 50.60%
# 	Elapsed Time: 18.68s
# 	Learning Rate: 0.0025480396799999992
#
# [i] Epoch 5
# 	Loss: 2.0659	Accuracy: 56.40%
# 	Elapsed Time: 18.65s
# 	Learning Rate: 0.002446118092799999
#
# [i] Epoch 6
# 	Loss: 2.0288	Accuracy: 58.00%
# 	Elapsed Time: 18.70s
# 	Learning Rate: 0.002348273369087999
#
# [i] Epoch 7
# 	Loss: 1.9947	Accuracy: 60.20%
# 	Elapsed Time: 18.86s
# 	Learning Rate: 0.002254342434324479
#
# [i] Epoch 8
# 	Loss: 1.9710	Accuracy: 60.60%
# 	Elapsed Time: 18.68s
# 	Learning Rate: 0.0021641687369515
#
# [i] Epoch 9
# 	Loss: 1.9509	Accuracy: 62.80%
# 	Elapsed Time: 18.73s
# 	Learning Rate: 0.00207760198747344
#
# [i] Epoch 10
# 	Loss: 1.9361	Accuracy: 62.20%
# 	Elapsed Time: 18.83s
# 	Learning Rate: 0.0019944979079745025
#
# [i] Epoch 11
# 	Loss: 1.9264	Accuracy: 64.40%
# 	Elapsed Time: 18.64s
# 	Learning Rate: 0.0019147179916555223
#
# [i] Epoch 12
# 	Loss: 1.9154	Accuracy: 63.40%
# 	Elapsed Time: 18.64s
# 	Learning Rate: 0.0018381292719893013
#
# [i] Epoch 13
# 	Loss: 1.9054	Accuracy: 65.20%
# 	Elapsed Time: 18.71s
# 	Learning Rate: 0.0017646041011097292
#
# [i] Epoch 14
# 	Loss: 1.8969	Accuracy: 64.60%
# 	Elapsed Time: 18.69s
# 	Learning Rate: 0.00169401993706534
#
# [i] Epoch 15
# 	Loss: 1.8940	Accuracy: 64.60%
# 	Elapsed Time: 18.74s
# 	Learning Rate: 0.0016262591395827264
#
# [i] Epoch 16
# 	Loss: 1.8845	Accuracy: 65.20%
# 	Elapsed Time: 18.71s
# 	Learning Rate: 0.0015612087739994172
#
# [i] Epoch 17
# 	Loss: 1.8820	Accuracy: 66.20%
# 	Elapsed Time: 18.77s
# 	Learning Rate: 0.0014987604230394405
#
# [i] Epoch 18
# 	Loss: 1.8736	Accuracy: 66.20%
# 	Elapsed Time: 18.76s
# 	Learning Rate: 0.001438810006117863
#
# [i] Epoch 19
# 	Loss: 1.8746	Accuracy: 65.20%
# 	Elapsed Time: 18.70s
# 	Learning Rate: 0.0013812576058731484
#
# [i] Epoch 20
# 	Loss: 1.8685	Accuracy: 67.00%
# 	Elapsed Time: 18.77s
# 	Learning Rate: 0.0013260073016382224
#
# [i] Val Loss: 2.0182	 Val Accuracy: 57.00%
